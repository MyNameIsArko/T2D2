# %%
import math
import os
import random
import threading
import time
from copy import deepcopy
from dataclasses import dataclass, field
from typing import Tuple

import gymnasium as gym
import numpy as np
import torch
import torch.multiprocessing as mp
from torch import nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence, pad_sequence
import cv2
# from tensorboardX import SummaryWriter
# from torch.utils.tensorboard import SummaryWriter

# %%
game_name = 'Solaris-v5'

lr = 5e-5
eps = 1e-3
grad_norm = 40
batch_size = 64
learning_starts = 50000
save_interval = 500
target_net_update_interval = 2000
gamma = 0.99
prio_exponent = 0.9
importance_sampling_exponent = 0.6

training_steps = 100000
buffer_capacity = 3000000
max_episode_steps = 27000
actor_update_interval = 400
block_length = 400

num_actors = 8
base_eps = 0.5
alpha = 7
log_interval = 10

# sequence setting
burn_in_steps = 40
learning_steps = 40
forward_steps = 5
seq_len = burn_in_steps + learning_steps + forward_steps

# network setting
hidden_dim = 512

render = False
save_plot = True
test_epsilon = 0.001

# %%
class NoopResetEnv(gym.Wrapper):
    def __init__(self, env, noop_max=30):
        """start the game with no-op actions to provide random starting positions
        No-op is assumed to be action 0.
        """
        gym.Wrapper.__init__(self, env)
        self.noop_max = noop_max
        self.override_num_noops = None
        self.noop_action = 0
        assert env.unwrapped.get_action_meanings()[0] == 'NOOP'

    def reset(self, **kwargs):
        """ Do no-op action for a number of steps in [1, noop_max]."""
        self.env.reset(**kwargs)
        if self.override_num_noops is not None:
            noops = self.override_num_noops
        else:
            noops = np.random.randint(1, self.noop_max + 1) #pylint: disable=E1101
        assert noops > 0
        obs = None
        for _ in range(noops):
            obs, _, terminated, truncated, _ = self.env.step(self.noop_action)
            if terminated or truncated:
                obs = self.env.reset(**kwargs)
        return obs, {}

    def step(self, action):
        return self.env.step(action)



class WarpFrame(gym.ObservationWrapper):
    def __init__(self, env, width=84, height=84):
        """
        Warp frames to 84x84 as done in the Nature paper and later work.
        """
        super().__init__(env)
        self._width = width
        self._height = height

        self.observation_space = gym.spaces.Box(
            low=0,
            high=255,
            shape=(1, self._height, self._width),
            dtype=np.uint8,
        )

    def observation(self, obs):

        obs = cv2.resize(
            obs, (self._width, self._height), interpolation=cv2.INTER_AREA
        )

        obs = np.expand_dims(obs, 0)

        return obs


def create_env(env_name=game_name, noop_start=True, render=False):

    env = gym.make(f'ALE/{env_name}', obs_type='grayscale', frameskip=4, repeat_action_probability=0, full_action_space=False, render_mode='human' if render else 'rgb_array')

    env = WarpFrame(env)
    if noop_start:
        env = NoopResetEnv(env)

    return env

# %%
class PriorityTree:
    def __init__(self, capacity, prio_exponent, is_exponent):
        self.num_layers = 1
        while capacity > 2**(self.num_layers - 1):
            self.num_layers += 1
        
        self.ptree = np.zeros(2**self.num_layers - 1, dtype=np.float64)
        
        self.prio_exponent = prio_exponent
        self.is_exponent = is_exponent
    
    def update(self, idxes: np.ndarray, td_error: np.ndarray) -> None:
        priorities = td_error ** self.prio_exponent
        
        idxes = idxes + 2**(self.num_layers - 1) - 1
        self.ptree[idxes] = priorities
        
        for _ in range(self.num_layers - 1):
            idxes = (idxes - 1) // 2
            idxes = np.unique(idxes)
            self.ptree[idxes] = self.ptree[2 * idxes + 1] + self.ptree[2 * idxes + 2]
    
    def sample(self, num_samples: int) -> tuple[np.ndarray, np.ndarray]:
        p_sum = self.ptree[0]
        interval = p_sum / num_samples
        
        prefixsums = np.arange(0, p_sum, interval, dtype=np.float64) + np.random.uniform(0, interval, num_samples)
        
        idxes = np.zeros(num_samples, dtype=np.int64)
        for _ in range(self.num_layers-1):
            nodes = self.ptree[2 * idxes + 1]
            idxes = np.where(prefixsums < nodes, 2 * idxes + 1, 2 * idxes + 2)
            prefixsums = np.where(idxes%2 == 0, prefixsums - self.ptree[idxes-1], prefixsums)
        
        priorities = self.ptree[idxes]
        min_p = np.min(priorities)
        is_weigths = np.power(priorities/min_p, -self.is_exponent)
        
        idxes -= 2**(self.num_layers - 1) - 1
        
        return idxes, is_weigths

# %%
@dataclass
class Block:
    obs: np.array
    last_action: np.array
    last_reward: np.array
    action: np.array
    n_step_reward: np.array
    gamma: np.array
    hidden: np.array
    num_sequences: int
    burn_in_steps: np.array
    learning_steps: np.array
    forward_steps: np.array

# %%
class ReplayBuffer:
    def __init__(self, sample_queue_list, batch_queue, priority_queue, alpha=prio_exponent, beta=importance_sampling_exponent):
        self.buffer_capacity = buffer_capacity
        self.sequence_len = learning_steps
        self.num_sequences = buffer_capacity // self.sequence_len
        self.block_len = block_length
        self.num_blocks = self.buffer_capacity // self.block_len
        self.seq_pre_block = self.block_len // self.sequence_len
        
        self.block_ptr = 0
        
        self.priority_tree = PriorityTree(self.num_sequences, alpha, beta)
        
        self.batch_size = batch_size
        
        self.env_steps = 0
        
        self.num_episodes = 0
        self.episode_reward = 0
        
        self.training_steps = 0
        self.last_training_steps = 0
        self.sum_loss = 0
        
        self.lock = threading.Lock()
        
        self.size = 0
        self.last_size = 0
        
        self.buffer = [None] * self.num_blocks
        
        self.sample_queue_list = sample_queue_list
        self.batch_queue = batch_queue
        self.priority_queue = priority_queue
        
        
    def __len__(self):
        return self.size
    
    def run(self):
        background_thread = threading.Thread(target=self.add_data, daemon=True)
        background_thread.start()
        
        background_thread = threading.Thread(target=self.prepare_data, daemon=True)
        background_thread.start()
        
        background_thread = threading.Thread(target=self.update_data, daemon=True)
        background_thread.start()

        writer_thread = threading.Thread(target=self.write_stats, daemon=True)
        writer_thread.start()
        
        while True:
            print(f'Buffer size: {self.size}')
            print(f'Buffer update speed: {(self.size - self.last_size) / log_interval}/s')
            self.last_size = self.size
            print(f'Number of environment steps: {self.env_steps}')
            if self.num_episodes != 0:
                print(f'Average episode return: {self.episode_reward / self.num_episodes:.4f}')
                self.episode_reward = 0
                self.num_episodes = 0
            print(f'Number of training steps: {self.training_steps}')
            print(f'Training speed: {(self.training_steps - self.last_training_steps) / log_interval}/s')
            if self.training_steps != self.last_training_steps:
                print(f'Loss: {self.sum_loss/(self.training_steps-self.last_training_steps):.4f}')
                self.last_training_steps = self.training_steps
                self.sum_loss = 0
            self.last_env_steps = self.env_steps
            print()
            
            if self.training_steps == training_steps:
                break
            else:
                time.sleep(log_interval)
    
    def write_stats(self):
        # writer = SummaryWriter(f'logs/r2d2__{game_name}')
        os.makedirs(f'logs/r2d2/{game_name}', exist_ok=True)
        while True:
            # writer.add_scalar('buffer/size', self.size, self.env_steps)
            with open(f'logs/r2d2/{game_name}/buffer_size.txt', 'a') as f:
                f.write(f'{self.size} {self.env_steps}\n')
            
            # writer.add_scalar('buffer/update_speed', (self.size - self.last_size) / log_interval, self.env_steps)
            with open(f'logs/r2d2/{game_name}/buffer_update_speed.txt', 'a') as f:
                f.write(f'{(self.size - self.last_size) / log_interval} {self.env_steps}\n')
            
            # writer.add_scalar('environment/steps', self.env_steps, self.env_steps)
            with open(f'logs/r2d2/{game_name}/environment_steps.txt', 'a') as f:
                f.write(f'{self.env_steps}\n')

            if self.num_episodes != 0:
                # writer.add_scalar('episode/return', self.episode_reward / self.num_episodes, self.env_steps)
                with open(f'logs/r2d2/{game_name}/episode_return.txt', 'a') as f:
                    f.write(f'{self.episode_reward / self.num_episodes} {self.env_steps}\n')

            # writer.add_scalar('training/steps', self.training_steps, self.env_steps)
            with open(f'logs/r2d2/{game_name}/training_steps.txt', 'a') as f:
                f.write(f'{self.training_steps} {self.env_steps}\n')

            # writer.add_scalar('training/speed', (self.training_steps - self.last_training_steps) / log_interval, self.env_steps)
            with open(f'logs/r2d2/{game_name}/training_speed.txt', 'a') as f:
                f.write(f'{(self.training_steps - self.last_training_steps) / log_interval} {self.env_steps}\n')

            if self.training_steps != self.last_training_steps:
                # writer.add_scalar('training/loss', self.sum_loss/(self.training_steps-self.last_training_steps), self.env_steps)
                with open(f'logs/r2d2/{game_name}/training_loss.txt', 'a') as f:
                    f.write(f'{self.sum_loss/(self.training_steps-self.last_training_steps)} {self.env_steps}\n')

            time.sleep(log_interval)

    def prepare_data(self):
        while self.size < learning_starts:
            time.sleep(1)
        
        while True:
            if not self.batch_queue.full():
                data = self.sample_batch()
                self.batch_queue.put(data)
            else:
                time.sleep(0.1)
    
    def add_data(self):
        while True:
            for sample_queue in self.sample_queue_list:
                if not sample_queue.empty():
                    data = sample_queue.get_nowait()
                    self.add(*data)
    
    def update_data(self):
        while True:
            if not self.priority_queue.empty():
                data = self.priority_queue.get_nowait()
                self.update_priorities(*data)
            else:
                time.sleep(0.1)
    
    def add(self, block: Block, priority: np.array, episode_reward: float):
        with self.lock:
            idxes = np.arange(self.block_ptr * self.seq_pre_block, (self.block_ptr + 1) * self.seq_pre_block, dtype=np.int64)
            
            self.priority_tree.update(idxes, priority)
            
            if self.buffer[self.block_ptr] is not None:
                self.size -= np.sum(self.buffer[self.block_ptr].learning_steps).item()
            
            self.size += np.sum(block.learning_steps).item()
            
            self.buffer[self.block_ptr] = block
            
            self.env_steps += np.sum(block.learning_steps, dtype=np.int32)
            
            self.block_ptr = (self.block_ptr + 1) % self.num_blocks
            
            if episode_reward:
                self.episode_reward += episode_reward
                self.num_episodes += 1
    
    def sample_batch(self):
        batch_obs, batch_last_action, batch_last_reward, batch_hidden, batch_action, batch_reward, batch_gamma = [], [], [], [], [], [], []
        burn_in_steps, learning_steps, forward_steps = [], [], []

        with self.lock:

            idxes, is_weights = self.priority_tree.sample(self.batch_size)

            block_idxes = idxes // self.seq_pre_block
            sequence_idxes = idxes % self.seq_pre_block


            for block_idx, sequence_idx  in zip(block_idxes, sequence_idxes):

                block = self.buffer[block_idx]

                assert sequence_idx < block.num_sequences, 'index is {} but size is {}'.format(sequence_idx, self.seq_pre_block_buf[block_idx])

                burn_in_step = block.burn_in_steps[sequence_idx]
                learning_step = block.learning_steps[sequence_idx]
                forward_step = block.forward_steps[sequence_idx]
                
                start_idx = block.burn_in_steps[0] + np.sum(block.learning_steps[:sequence_idx])

                obs = block.obs[start_idx-burn_in_step:start_idx+learning_step+forward_step]
                last_action = block.last_action[start_idx-burn_in_step:start_idx+learning_step+forward_step]
                last_reward = block.last_reward[start_idx-burn_in_step:start_idx+learning_step+forward_step]
                obs, last_action, last_reward = torch.from_numpy(obs), torch.from_numpy(last_action), torch.from_numpy(last_reward)
                
                start_idx = np.sum(block.learning_steps[:sequence_idx])
                end_idx = start_idx + block.learning_steps[sequence_idx]
                action = block.action[start_idx:end_idx]
                reward = block.n_step_reward[start_idx:end_idx]
                gamma = block.gamma[start_idx:end_idx]
                hidden = block.hidden[sequence_idx]
                
                batch_obs.append(obs)
                batch_last_action.append(last_action)
                batch_last_reward.append(last_reward)
                batch_action.append(action)
                batch_reward.append(reward)
                batch_gamma.append(gamma)
                batch_hidden.append(hidden)

                burn_in_steps.append(burn_in_step)
                learning_steps.append(learning_step)
                forward_steps.append(forward_step)

            batch_obs = pad_sequence(batch_obs, batch_first=True)
            batch_last_action = pad_sequence(batch_last_action, batch_first=True)
            batch_last_reward = pad_sequence(batch_last_reward, batch_first=True)

            is_weights = np.repeat(is_weights, learning_steps)


            data = (
                batch_obs,
                batch_last_action,
                batch_last_reward,
                torch.from_numpy(np.stack(batch_hidden)).transpose(0, 1),

                torch.from_numpy(np.concatenate(batch_action)).unsqueeze(1),
                torch.from_numpy(np.concatenate(batch_reward)),
                torch.from_numpy(np.concatenate(batch_gamma)),

                torch.ByteTensor(burn_in_steps),
                torch.ByteTensor(learning_steps),
                torch.ByteTensor(forward_steps),

                idxes,
                torch.from_numpy(is_weights.astype(np.float32)),
                self.block_ptr,

                self.env_steps
            )

        return data

    def update_priorities(self, idxes: np.ndarray, td_errors: np.ndarray, old_ptr: int, loss: float):
        """Update priorities of sampled transitions"""
        with self.lock:

            # discard the idxes that already been replaced by new data in replay buffer during training
            if self.block_ptr > old_ptr:
                # range from [old_ptr, self.seq_ptr)
                mask = (idxes < old_ptr*self.seq_pre_block) | (idxes >= self.block_ptr*self.seq_pre_block)
                idxes = idxes[mask]
                td_errors = td_errors[mask]
            elif self.block_ptr < old_ptr:
                # range from [0, self.seq_ptr) & [old_ptr, self,capacity)
                mask = (idxes < old_ptr*self.seq_pre_block) & (idxes >= self.block_ptr*self.seq_pre_block)
                idxes = idxes[mask]
                td_errors = td_errors[mask]

            self.priority_tree.update(idxes, td_errors)

        self.training_steps += 1
        self.sum_loss += loss

# %%
@dataclass
class AgentState:
    obs: torch.tensor
    action_dim: int
    last_action: torch.tensor = field(init=False)
    last_reward: torch.tensor = torch.zeros((1, 1), dtype=torch.float32)
    hidden_state: tuple[torch.tensor, torch.tensor] | None = None

    def __post_init__(self):
        self.last_action = torch.zeros((1, self.action_dim), dtype=torch.float32)

    def update(self, obs, last_action, last_reward, hidden):
        self.obs = torch.from_numpy(obs).unsqueeze(0)
        self.last_action = torch.tensor([[1 if i == last_action else 0 for i in range(self.action_dim)]],
                                        dtype=torch.float32)
        self.last_reward = torch.tensor([[last_reward]], dtype=torch.float32)
        self.hidden_state = hidden

# %%
class Network(nn.Module):
    def __init__(self, observation_dim, action_dim, hidden_dim=hidden_dim):
        super().__init__()

        self.action_dim = action_dim
        self.obs_shape = observation_dim
        self.max_forward_steps = 5

        self.feature = nn.Sequential(
            nn.Conv2d(1, 32, 8, 4),
            nn.ReLU(True),
            nn.Conv2d(32, 64, 4, 2),
            nn.ReLU(True),
            nn.Conv2d(64, 64, 3, 1),
            nn.ReLU(True),
            nn.Flatten(),
            nn.Linear(3136, 512),
            nn.ReLU(True),
        )

        self.recurrent = nn.LSTM(512 + action_dim + 1, hidden_dim, batch_first=True)

        self.advantage = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(True),
            nn.Linear(hidden_dim, action_dim)
        )

        self.value = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(True),
            nn.Linear(hidden_dim, 1)
        )

    def forward(self, state: AgentState):
        latent = self.feature(state.obs / 255)
        recurrent_input = torch.cat([latent, state.last_action, state.last_reward], dim=1)
        
        _, recurrent_output = self.recurrent(recurrent_input, state.hidden_state)
        
        hidden = recurrent_output[0]
        
        adv = self.advantage(hidden)
        val = self.value(hidden)
        q_value = val + adv - adv.mean(1, keepdim=True)
        
        return q_value, recurrent_output

    def calculate_q_(self, obs, last_action, last_reward, hidden_state, burn_in_steps, learning_steps, forward_steps):
        # obs shape: (batch_size, seq_len, obs_shape)
        batch_size, max_seq_len, *_ = obs.size()

        obs = obs.reshape(-1, *self.obs_shape)
        last_action = last_action.view(-1, self.action_dim)
        last_reward = last_reward.view(-1, 1)
        latent = self.feature(obs)

        seq_len = burn_in_steps + learning_steps + forward_steps

        recurrent_input = torch.cat((latent, last_action, last_reward), dim=1)
        recurrent_input = recurrent_input.view(batch_size, max_seq_len, -1)

        recurrent_input = pack_padded_sequence(recurrent_input, seq_len, batch_first=True, enforce_sorted=False)

        self.recurrent.flatten_parameters()
        recurrent_output, _ = self.recurrent(recurrent_input, hidden_state)

        recurrent_output, _ = pad_packed_sequence(recurrent_output, batch_first=True)

        seq_start_idx = burn_in_steps + self.max_forward_steps
        forward_pad_steps = torch.minimum(self.max_forward_steps - forward_steps, learning_steps)

        hidden = []
        for hidden_seq, start_idx, end_idx, padding_length in zip(recurrent_output, seq_start_idx, seq_len, forward_pad_steps):
            hidden.append(hidden_seq[start_idx:end_idx])
            if padding_length > 0:
                hidden.append(hidden_seq[end_idx-1:end_idx].repeat(padding_length, 1))

        hidden = torch.cat(hidden)

        assert hidden.size(0) == torch.sum(learning_steps)

        adv = self.advantage(hidden)
        val = self.value(hidden)
        q_value = val + adv - adv.mean(1, keepdim=True)

        return q_value

    def calculate_q(self, obs, last_action, last_reward, hidden_state, burn_in_steps, learning_steps):
        # obs shape: (batch_size, seq_len, obs_shape)
        batch_size, max_seq_len, *_ = obs.size()

        obs = obs.reshape(-1, *self.obs_shape)
        last_action = last_action.view(-1, self.action_dim)
        last_reward = last_reward.view(-1, 1)

        latent = self.feature(obs)

        seq_len = burn_in_steps + learning_steps

        recurrent_input = torch.cat((latent, last_action, last_reward), dim=1)
        recurrent_input = recurrent_input.view(batch_size, max_seq_len, -1)
        recurrent_input = pack_padded_sequence(recurrent_input, seq_len, batch_first=True, enforce_sorted=False)

        # self.recurrent.flatten_parameters()
        recurrent_output, _ = self.recurrent(recurrent_input, hidden_state)

        recurrent_output, _ = pad_packed_sequence(recurrent_output, batch_first=True)

        hidden = torch.cat([output[burn_in:burn_in+learning] for output, burn_in, learning in zip(recurrent_output, burn_in_steps, learning_steps)], dim=0)

        adv = self.advantage(hidden)
        val = self.value(hidden)

        q_value = val + adv - adv.mean(1, keepdim=True)

        return q_value

# %%
def calculate_mixed_td_errors(td_error, learning_steps):
    
    start_idx = 0
    mixed_td_errors = np.empty(learning_steps.shape, dtype=td_error.dtype)
    for i, steps in enumerate(learning_steps):
        mixed_td_errors[i] = 0.9*td_error[start_idx:start_idx+steps].max() + 0.1*td_error[start_idx:start_idx+steps].mean()
        start_idx += steps
    
    return mixed_td_errors

class Learner:
    def __init__(self, batch_queue, priority_queue, model, grad_norm: int = grad_norm,
                lr: float = lr, eps:float = eps, game_name: str = game_name,
                target_net_update_interval: int = target_net_update_interval, save_interval: int = save_interval):

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.online_net = deepcopy(model)
        self.online_net.to(self.device)
        self.online_net.train()
        self.target_net = deepcopy(self.online_net)
        self.target_net.eval()
        self.optimizer = torch.optim.Adam(self.online_net.parameters(), lr=lr, eps=eps)
        self.loss_fn = nn.MSELoss(reduction='none')
        self.grad_norm = grad_norm
        self.batch_queue = batch_queue
        self.priority_queue = priority_queue
        self.num_updates = 0
        self.done = False

        self.target_net_update_interval = target_net_update_interval
        self.save_interval = save_interval

        self.batched_data = []

        self.shared_model = model

        self.game_name = game_name

    def store_weights(self):
        self.shared_model.load_state_dict(self.online_net.state_dict())

    def prepare_data(self):

        while True:
            if not self.batch_queue.empty() and len(self.batched_data) < 4:
                data = self.batch_queue.get_nowait()
                self.batched_data.append(data)
            else:
                time.sleep(0.1)

    def run(self):
        background_thread = threading.Thread(target=self.prepare_data, daemon=True)
        background_thread.start()
        time.sleep(2)

        start_time = time.time()
        while self.num_updates < training_steps:
            
            while not self.batched_data:
                time.sleep(1)
            data = self.batched_data.pop(0)

            batch_obs, batch_last_action, batch_last_reward, batch_hidden, batch_action, batch_n_step_reward, batch_n_step_gamma, burn_in_steps, learning_steps, forward_steps, idxes, is_weights, old_ptr, env_steps = data
            batch_obs, batch_last_action, batch_last_reward = batch_obs.to(self.device), batch_last_action.to(self.device), batch_last_reward.to(self.device)
            batch_hidden, batch_action = batch_hidden.to(self.device), batch_action.to(self.device)
            batch_n_step_reward, batch_n_step_gamma = batch_n_step_reward.to(self.device), batch_n_step_gamma.to(self.device)
            is_weights = is_weights.to(self.device)

            batch_obs, batch_last_action = batch_obs.float(), batch_last_action.float()
            batch_action = batch_action.long()
            burn_in_steps, learning_steps, forward_steps = burn_in_steps, learning_steps, forward_steps

            batch_hidden = (batch_hidden[:1], batch_hidden[1:])

            batch_obs = batch_obs / 255

            # double q learning
            with torch.no_grad():
                batch_action_ = self.online_net.calculate_q_(batch_obs, batch_last_action, batch_last_reward, batch_hidden, burn_in_steps, learning_steps, forward_steps).argmax(1).unsqueeze(1)
                batch_q_ = self.target_net.calculate_q_(batch_obs, batch_last_action, batch_last_reward, batch_hidden, burn_in_steps, learning_steps, forward_steps).gather(1, batch_action_).squeeze(1)
            
            target_q = self.value_rescale(batch_n_step_reward + batch_n_step_gamma * self.inverse_value_rescale(batch_q_))
            # target_q = batch_n_step_reward + batch_n_step_gamma * batch_q_

            batch_q = self.online_net.calculate_q(batch_obs, batch_last_action, batch_last_reward, batch_hidden, burn_in_steps, learning_steps).gather(1, batch_action).squeeze(1)
            
            loss = (is_weights * self.loss_fn(batch_q, target_q)).mean()

            
            td_errors = (target_q-batch_q).detach().clone().squeeze().abs().cpu().float().numpy()

            priorities = calculate_mixed_td_errors(td_errors, learning_steps.numpy())

            # automatic mixed precision training
            self.optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(self.online_net.parameters(), self.grad_norm)
            self.optimizer.step()

            self.num_updates += 1

            self.priority_queue.put((idxes, priorities, old_ptr, loss.item()))

            # store new weights in shared memory
            if self.num_updates % 4 == 0:
                self.store_weights()

            # update target net
            if self.num_updates % self.target_net_update_interval == 0:
                self.target_net.load_state_dict(self.online_net.state_dict())
            
            # save model 
            if self.num_updates % self.save_interval == 0:
                os.makedirs(f'models/r2d2/{game_name}', exist_ok=True)
                torch.save((self.online_net.state_dict(), self.num_updates, env_steps, (time.time()-start_time)/60), os.path.join(f'models/r2d2/{game_name}', '{}.pth'.format(self.num_updates)))

    @staticmethod
    def value_rescale(value, eps=1e-3):
        return value.sign()*((value.abs()+1).sqrt()-1) + eps*value

    @staticmethod
    def inverse_value_rescale(value, eps=1e-3):
        temp = ((1 + 4*eps*(value.abs()+1+eps)).sqrt() - 1) / (2*eps)
        return value.sign() * (temp.square() - 1)

# %%
class LocalBuffer:
    def __init__(self, action_dim: int, forward_steps: int = forward_steps,
                burn_in_steps = burn_in_steps, learning_steps: int = learning_steps, 
                gamma: float = gamma, hidden_dim: int = hidden_dim, block_length: int = block_length):
        
        self.action_dim = action_dim
        self.gamma = gamma
        self.hidden_dim = hidden_dim
        self.forward_steps = forward_steps
        self.learning_steps = learning_steps
        self.burn_in_steps = burn_in_steps
        self.block_length = block_length
        self.curr_burn_in_steps = 0
        
    def __len__(self):
        return self.size
    
    def reset(self, init_obs: np.ndarray):
        self.obs_buffer = [init_obs]
        self.last_action_buffer = [np.array([1 if i == 0 else 0 for i in range(self.action_dim)], dtype=bool)]
        self.last_reward_buffer = [0]
        self.hidden_buffer = [np.zeros((2, self.hidden_dim), dtype=np.float32)]
        self.action_buffer = []
        self.reward_buffer = []
        self.qval_buffer = []
        self.curr_burn_in_steps = 0
        self.size = 0
        self.sum_reward = 0
        self.done = False

    def add(self, action: int, reward: float, next_obs: np.ndarray, q_value: np.ndarray, hidden_state: np.ndarray):
        self.action_buffer.append(action)
        self.reward_buffer.append(reward)
        self.hidden_buffer.append(hidden_state)
        self.obs_buffer.append(next_obs)
        self.last_action_buffer.append(np.array([1 if i == action else 0 for i in range(self.action_dim)], dtype=bool))
        self.last_reward_buffer.append(reward)
        self.qval_buffer.append(q_value)
        self.sum_reward += reward
        self.size += 1
    
    def finish(self, last_qval: np.ndarray = None) -> Tuple:
        assert self.size <= self.block_length
        # assert len(self.last_action_buffer) == self.curr_burn_in_steps + self.size + 1

        num_sequences = math.ceil(self.size/self.learning_steps)

        max_forward_steps = min(self.size, self.forward_steps)
        n_step_gamma = [self.gamma**self.forward_steps] * (self.size-max_forward_steps)

        # last_qval is none means episode done 
        if last_qval is not None:
            self.qval_buffer.append(last_qval)
            n_step_gamma.extend([self.gamma**i for i in reversed(range(1, max_forward_steps+1))])
        else:
            self.done = True
            self.qval_buffer.append(np.zeros_like(self.qval_buffer[0]))
            n_step_gamma.extend([0 for _ in range(max_forward_steps)]) # set gamma to 0 so don't need 'done'

        n_step_gamma = np.array(n_step_gamma, dtype=np.float32)

        obs = np.stack(self.obs_buffer)
        last_action = np.stack(self.last_action_buffer)
        last_reward = np.array(self.last_reward_buffer, dtype=np.float32)

        hiddens = np.stack(self.hidden_buffer[slice(0, self.size, self.learning_steps)])

        actions = np.array(self.action_buffer, dtype=np.uint8)

        qval_buffer = np.concatenate(self.qval_buffer)
        reward_buffer = self.reward_buffer + [0 for _ in range(self.forward_steps-1)]
        n_step_reward = np.convolve(reward_buffer, 
                                    [self.gamma**(self.forward_steps-1-i) for i in range(self.forward_steps)],
                                    'valid').astype(np.float32)

        burn_in_steps = np.array([min(i*self.learning_steps+self.curr_burn_in_steps, self.burn_in_steps) for i in range(num_sequences)], dtype=np.uint8)
        learning_steps = np.array([min(self.learning_steps, self.size-i*self.learning_steps) for i in range(num_sequences)], dtype=np.uint8)
        forward_steps = np.array([min(self.forward_steps, self.size+1-np.sum(learning_steps[:i+1])) for i in range(num_sequences)], dtype=np.uint8)
        assert forward_steps[-1] == 1 and burn_in_steps[0] == self.curr_burn_in_steps
        # assert last_action.shape[0] == self.curr_burn_in_steps + np.sum(learning_steps) + 1

        max_qval = np.max(qval_buffer[max_forward_steps:self.size+1], axis=1)
        max_qval = np.pad(max_qval, (0, max_forward_steps-1), 'edge')
        target_qval = qval_buffer[np.arange(self.size), actions]

        td_errors = np.abs(n_step_reward + n_step_gamma * max_qval - target_qval, dtype=np.float32)
        priorities = np.zeros(self.block_length//self.learning_steps, dtype=np.float32)
        priorities[:num_sequences] = calculate_mixed_td_errors(td_errors, learning_steps)

        # save burn in information for next block
        self.obs_buffer = self.obs_buffer[-self.burn_in_steps-1:]
        self.last_action_buffer = self.last_action_buffer[-self.burn_in_steps-1:]
        self.last_reward_buffer = self.last_reward_buffer[-self.burn_in_steps-1:]
        self.hidden_buffer = self.hidden_buffer[-self.burn_in_steps-1:]
        self.action_buffer.clear()
        self.reward_buffer.clear()
        self.qval_buffer.clear()
        self.curr_burn_in_steps = len(self.obs_buffer)-1
        self.size = 0
        
        block = Block(obs, last_action, last_reward, actions, n_step_reward, n_step_gamma, hiddens, num_sequences, burn_in_steps, learning_steps, forward_steps)
        return [block, priorities, self.sum_reward if self.done else None]

# %%
class Actor:
    def __init__(self, epsilon: float, model, sample_queue,
                max_episode_steps: int = max_episode_steps, block_length: int = block_length):

        self.env = create_env(game_name)
        self.action_dim = self.env.action_space.n
        self.model = Network(self.env.observation_space.shape[0], self.action_dim)
        self.model.eval()
        self.local_buffer = LocalBuffer(self.action_dim)

        self.epsilon = epsilon
        self.shared_model = model
        self.sample_queue = sample_queue
        self.max_episode_steps = max_episode_steps
        self.block_length = block_length

    def run(self):
        
        actor_steps = 0

        while True:

            done = False
            agent_state = self.reset()
            episode_steps = 0

            while not done and episode_steps < self.max_episode_steps:
                
                with torch.no_grad():
                    q_value, hidden = self.model(agent_state)

                if random.random() < self.epsilon:
                    action = self.env.action_space.sample()
                else:
                    action = torch.argmax(q_value, 1).item()

                # apply action in env
                next_obs, reward, terminated, truncated, _ = self.env.step(action)
                done = terminated or truncated

                agent_state.update(next_obs, action, reward, hidden)

                episode_steps += 1
                actor_steps += 1

                self.local_buffer.add(action, reward, next_obs, q_value.numpy(), torch.cat(hidden).numpy())

                if done:
                    block = self.local_buffer.finish()
                    self.sample_queue.put(block)

                elif len(self.local_buffer) == self.block_length or episode_steps == self.max_episode_steps:
                    with torch.no_grad():
                        q_value, hidden = self.model(agent_state)

                    block = self.local_buffer.finish(q_value.numpy())

                    if self.epsilon > 0.01:
                        block[2] = None
                    self.sample_queue.put(block)

                if actor_steps % actor_update_interval == 0:
                    self.update_weights()

                
    def update_weights(self):
        self.model.load_state_dict(self.shared_model.state_dict())
    
    def reset(self):
        obs, _ = self.env.reset()
        self.local_buffer.reset(obs)

        state = AgentState(torch.from_numpy(obs).unsqueeze(0), self.action_dim)

        return state

# %%
def get_epsilon(actor_id: int, base_eps: float = base_eps, alpha: float = alpha, num_actors: int = num_actors):
    exponent = 1 + actor_id / (num_actors-1) * alpha
    return base_eps**exponent

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 assert False
#
# AssertionError:

# %%
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)
torch.set_num_threads(1)

env = create_env(game_name)
n_observations = env.observation_space.shape
n_actions = env.action_space.n
env.close()

model = Network(n_observations, n_actions)
model.share_memory()
sample_queue_list = [mp.Queue() for _ in range(num_actors)]
batch_queue = mp.Queue(num_actors)
priority_queue = mp.Queue(num_actors)

buffer = ReplayBuffer(sample_queue_list, batch_queue, priority_queue)
learner = Learner(batch_queue, priority_queue, model)
actors = [Actor(get_epsilon(i), model, sample_queue_list[i]) for i in range(num_actors)]

actor_procs = [mp.Process(target=actor.run) for actor in actors]
for proc in actor_procs:
    proc.start()

buffer_proc = mp.Process(target=buffer.run)
buffer_proc.start()

learner.run()

buffer_proc.join()

for proc in actor_procs:
    proc.terminate()
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Buffer size: 0
# Buffer update speed: 0.0/s
# Number of environment steps: 0
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 0
# Buffer update speed: 0.0/s
# Number of environment steps: 0
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 3200
# Buffer update speed: 320.0/s
# Number of environment steps: 3200
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 4000
# Buffer update speed: 80.0/s
# Number of environment steps: 4000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 6800
# Buffer update speed: 280.0/s
# Number of environment steps: 6800
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 9200
# Buffer update speed: 240.0/s
# Number of environment steps: 9200
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 10400
# Buffer update speed: 120.0/s
# Number of environment steps: 10400
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 12800
# Buffer update speed: 240.0/s
# Number of environment steps: 12800
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 14000
# Buffer update speed: 120.0/s
# Number of environment steps: 14000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 16000
# Buffer update speed: 200.0/s
# Number of environment steps: 16000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 18800
# Buffer update speed: 280.0/s
# Number of environment steps: 18800
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 20000
# Buffer update speed: 120.0/s
# Number of environment steps: 20000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 22400
# Buffer update speed: 240.0/s
# Number of environment steps: 22400
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 23630
# Buffer update speed: 123.0/s
# Number of environment steps: 23630
# Average episode return: 320.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 26430
# Buffer update speed: 280.0/s
# Number of environment steps: 26430
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 27630
# Buffer update speed: 120.0/s
# Number of environment steps: 27630
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 29782
# Buffer update speed: 215.2/s
# Number of environment steps: 29782
# Average episode return: 340.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 32582
# Buffer update speed: 280.0/s
# Number of environment steps: 32582
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 32982
# Buffer update speed: 40.0/s
# Number of environment steps: 32982
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 35782
# Buffer update speed: 280.0/s
# Number of environment steps: 35782
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 37782
# Buffer update speed: 200.0/s
# Number of environment steps: 37782
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 39782
# Buffer update speed: 200.0/s
# Number of environment steps: 39782
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 41382
# Buffer update speed: 160.0/s
# Number of environment steps: 41382
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 43382
# Buffer update speed: 200.0/s
# Number of environment steps: 43382
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 46182
# Buffer update speed: 280.0/s
# Number of environment steps: 46182
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 47782
# Buffer update speed: 160.0/s
# Number of environment steps: 47782
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 49382
# Buffer update speed: 160.0/s
# Number of environment steps: 49382
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 51382
# Buffer update speed: 200.0/s
# Number of environment steps: 51382
# Number of training steps: 6
# Training speed: 0.6/s
# Loss: 0.3361
#
# Buffer size: 52582
# Buffer update speed: 120.0/s
# Number of environment steps: 52582
# Number of training steps: 36
# Training speed: 3.0/s
# Loss: 0.3904
#
# Buffer size: 54982
# Buffer update speed: 240.0/s
# Number of environment steps: 54982
# Number of training steps: 60
# Training speed: 2.4/s
# Loss: 0.4047
#
# Buffer size: 56182
# Buffer update speed: 120.0/s
# Number of environment steps: 56182
# Number of training steps: 86
# Training speed: 2.6/s
# Loss: 0.4762
#
# Buffer size: 57782
# Buffer update speed: 160.0/s
# Number of environment steps: 57782
# Number of training steps: 119
# Training speed: 3.3/s
# Loss: 0.4671
#
# Buffer size: 59782
# Buffer update speed: 200.0/s
# Number of environment steps: 59782
# Number of training steps: 153
# Training speed: 3.4/s
# Loss: 0.4825
#
# Buffer size: 61308
# Buffer update speed: 152.6/s
# Number of environment steps: 61308
# Number of training steps: 184
# Training speed: 3.1/s
# Loss: 0.5347
#
# Buffer size: 62908
# Buffer update speed: 160.0/s
# Number of environment steps: 62908
# Number of training steps: 216
# Training speed: 3.2/s
# Loss: 0.5456
#
# Buffer size: 64508
# Buffer update speed: 160.0/s
# Number of environment steps: 64508
# Number of training steps: 241
# Training speed: 2.5/s
# Loss: 0.5371
#
# Buffer size: 66108
# Buffer update speed: 160.0/s
# Number of environment steps: 66108
# Number of training steps: 268
# Training speed: 2.7/s
# Loss: 0.6410
#
# Buffer size: 68554
# Buffer update speed: 244.6/s
# Number of environment steps: 68554
# Average episode return: 960.0000
# Number of training steps: 293
# Training speed: 2.5/s
# Loss: 0.5291
#
# Buffer size: 69754
# Buffer update speed: 120.0/s
# Number of environment steps: 69754
# Number of training steps: 316
# Training speed: 2.3/s
# Loss: 0.5377
#
# Buffer size: 71754
# Buffer update speed: 200.0/s
# Number of environment steps: 71754
# Number of training steps: 351
# Training speed: 3.5/s
# Loss: 0.4850
#
# Buffer size: 72554
# Buffer update speed: 80.0/s
# Number of environment steps: 72554
# Number of training steps: 381
# Training speed: 3.0/s
# Loss: 0.6194
#
# Buffer size: 75354
# Buffer update speed: 280.0/s
# Number of environment steps: 75354
# Number of training steps: 405
# Training speed: 2.4/s
# Loss: 0.6882
#
# Buffer size: 76154
# Buffer update speed: 80.0/s
# Number of environment steps: 76154
# Number of training steps: 432
# Training speed: 2.5/s
# Loss: 0.6776
#
# Buffer size: 78554
# Buffer update speed: 240.0/s
# Number of environment steps: 78554
# Number of training steps: 459
# Training speed: 2.6/s
# Loss: 0.5170
#
# Buffer size: 79754
# Buffer update speed: 120.0/s
# Number of environment steps: 79754
# Number of training steps: 485
# Training speed: 2.6/s
# Loss: 0.7276
#
# Buffer size: 81354
# Buffer update speed: 160.0/s
# Number of environment steps: 81354
# Number of training steps: 505
# Training speed: 1.9/s
# Loss: 0.5626
#
# Buffer size: 83354
# Buffer update speed: 200.0/s
# Number of environment steps: 83354
# Number of training steps: 529
# Training speed: 2.4/s
# Loss: 0.5985
#
# Buffer size: 84954
# Buffer update speed: 160.0/s
# Number of environment steps: 84954
# Number of training steps: 557
# Training speed: 2.8/s
# Loss: 0.5114
#
# Buffer size: 86154
# Buffer update speed: 120.0/s
# Number of environment steps: 86154
# Number of training steps: 586
# Training speed: 2.8/s
# Loss: 0.5499
#
# Buffer size: 88554
# Buffer update speed: 240.0/s
# Number of environment steps: 88554
# Number of training steps: 614
# Training speed: 2.8/s
# Loss: 0.4259
#
# Buffer size: 90554
# Buffer update speed: 200.0/s
# Number of environment steps: 90554
# Number of training steps: 645
# Training speed: 3.1/s
# Loss: 0.4587
#
# Buffer size: 91754
# Buffer update speed: 120.0/s
# Number of environment steps: 91754
# Number of training steps: 675
# Training speed: 2.9/s
# Loss: 0.4477
#
# Buffer size: 93754
# Buffer update speed: 200.0/s
# Number of environment steps: 93754
# Number of training steps: 704
# Training speed: 2.9/s
# Loss: 0.4629
#
# Buffer size: 95167
# Buffer update speed: 141.3/s
# Number of environment steps: 95167
# Number of training steps: 727
# Training speed: 2.3/s
# Loss: 0.4563
#
# Buffer size: 97580
# Buffer update speed: 241.3/s
# Number of environment steps: 97580
# Average episode return: 1166.6667
# Number of training steps: 753
# Training speed: 2.6/s
# Loss: 0.4496
#
# Buffer size: 98380
# Buffer update speed: 80.0/s
# Number of environment steps: 98380
# Number of training steps: 791
# Training speed: 3.8/s
# Loss: 0.4424
#
# Buffer size: 101180
# Buffer update speed: 280.0/s
# Number of environment steps: 101180
# Number of training steps: 813
# Training speed: 2.3/s
# Loss: 0.4303
#
# Buffer size: 101580
# Buffer update speed: 40.0/s
# Number of environment steps: 101580
# Number of training steps: 835
# Training speed: 2.1/s
# Loss: 0.3772
#
# Buffer size: 104703
# Buffer update speed: 312.3/s
# Number of environment steps: 104703
# Average episode return: 160.0000
# Number of training steps: 855
# Training speed: 2.0/s
# Loss: 0.3293
#
# Buffer size: 105103
# Buffer update speed: 40.0/s
# Number of environment steps: 105103
# Number of training steps: 879
# Training speed: 2.5/s
# Loss: 0.5045
#
# Buffer size: 107903
# Buffer update speed: 280.0/s
# Number of environment steps: 107903
# Number of training steps: 906
# Training speed: 2.6/s
# Loss: 0.5377
#
# Buffer size: 108703
# Buffer update speed: 80.0/s
# Number of environment steps: 108703
# Number of training steps: 927
# Training speed: 2.1/s
# Loss: 0.3391
#
# Buffer size: 111103
# Buffer update speed: 240.0/s
# Number of environment steps: 111103
# Number of training steps: 954
# Training speed: 2.7/s
# Loss: 0.4046
#
# Buffer size: 111903
# Buffer update speed: 80.0/s
# Number of environment steps: 111903
# Number of training steps: 982
# Training speed: 2.8/s
# Loss: 0.3516
#
# Buffer size: 114303
# Buffer update speed: 240.0/s
# Number of environment steps: 114303
# Number of training steps: 1008
# Training speed: 2.6/s
# Loss: 0.3775
#
# Buffer size: 115503
# Buffer update speed: 120.0/s
# Number of environment steps: 115503
# Number of training steps: 1037
# Training speed: 3.0/s
# Loss: 0.3588
#
# Buffer size: 117503
# Buffer update speed: 200.0/s
# Number of environment steps: 117503
# Number of training steps: 1068
# Training speed: 3.0/s
# Loss: 0.3757
#
# Buffer size: 118566
# Buffer update speed: 106.3/s
# Number of environment steps: 118566
# Average episode return: 320.0000
# Number of training steps: 1099
# Training speed: 3.1/s
# Loss: 0.3693
#
# Buffer size: 120677
# Buffer update speed: 211.1/s
# Number of environment steps: 120677
# Number of training steps: 1123
# Training speed: 2.4/s
# Loss: 0.4380
#
# Buffer size: 122277
# Buffer update speed: 160.0/s
# Number of environment steps: 122277
# Number of training steps: 1147
# Training speed: 2.4/s
# Loss: 0.4406
#
# Buffer size: 123877
# Buffer update speed: 160.0/s
# Number of environment steps: 123877
# Number of training steps: 1170
# Training speed: 2.3/s
# Loss: 0.3598
#
# Buffer size: 125877
# Buffer update speed: 200.0/s
# Number of environment steps: 125877
# Number of training steps: 1203
# Training speed: 3.3/s
# Loss: 0.3873
#
# Buffer size: 127477
# Buffer update speed: 160.0/s
# Number of environment steps: 127477
# Number of training steps: 1231
# Training speed: 2.7/s
# Loss: 0.4550
#
# Buffer size: 129077
# Buffer update speed: 160.0/s
# Number of environment steps: 129077
# Number of training steps: 1256
# Training speed: 2.5/s
# Loss: 0.4282
#
# Buffer size: 131225
# Buffer update speed: 214.8/s
# Number of environment steps: 131225
# Number of training steps: 1287
# Training speed: 3.1/s
# Loss: 0.4309
#
# Buffer size: 132425
# Buffer update speed: 120.0/s
# Number of environment steps: 132425
# Number of training steps: 1312
# Training speed: 2.5/s
# Loss: 0.4322
#
# Buffer size: 134868
# Buffer update speed: 244.3/s
# Number of environment steps: 134868
# Average episode return: 720.0000
# Number of training steps: 1334
# Training speed: 2.2/s
# Loss: 0.3735
#
# Buffer size: 135668
# Buffer update speed: 80.0/s
# Number of environment steps: 135668
# Number of training steps: 1364
# Training speed: 2.9/s
# Loss: 0.4507
#
# Buffer size: 138068
# Buffer update speed: 240.0/s
# Number of environment steps: 138068
# Number of training steps: 1397
# Training speed: 3.3/s
# Loss: 0.4470
#
# Buffer size: 138868
# Buffer update speed: 80.0/s
# Number of environment steps: 138868
# Number of training steps: 1417
# Training speed: 2.0/s
# Loss: 0.5123
#
# Buffer size: 141268
# Buffer update speed: 240.0/s
# Number of environment steps: 141268
# Number of training steps: 1440
# Training speed: 2.3/s
# Loss: 0.4239
#
# Buffer size: 142468
# Buffer update speed: 120.0/s
# Number of environment steps: 142468
# Number of training steps: 1466
# Training speed: 2.6/s
# Loss: 0.4584
#
# Buffer size: 144468
# Buffer update speed: 200.0/s
# Number of environment steps: 144468
# Number of training steps: 1490
# Training speed: 2.4/s
# Loss: 0.4779
#
# Buffer size: 145668
# Buffer update speed: 120.0/s
# Number of environment steps: 145668
# Number of training steps: 1512
# Training speed: 2.2/s
# Loss: 0.5433
#
# Buffer size: 148068
# Buffer update speed: 240.0/s
# Number of environment steps: 148068
# Number of training steps: 1543
# Training speed: 3.0/s
# Loss: 0.4576
#
# Buffer size: 149268
# Buffer update speed: 120.0/s
# Number of environment steps: 149268
# Number of training steps: 1568
# Training speed: 2.5/s
# Loss: 0.4524
#
# Buffer size: 151268
# Buffer update speed: 200.0/s
# Number of environment steps: 151268
# Number of training steps: 1604
# Training speed: 3.6/s
# Loss: 0.5297
#
# Buffer size: 152745
# Buffer update speed: 147.7/s
# Number of environment steps: 152745
# Average episode return: 80.0000
# Number of training steps: 1627
# Training speed: 2.3/s
# Loss: 0.4930
#
# Buffer size: 154745
# Buffer update speed: 200.0/s
# Number of environment steps: 154745
# Number of training steps: 1654
# Training speed: 2.7/s
# Loss: 0.5148
#
# Buffer size: 155945
# Buffer update speed: 120.0/s
# Number of environment steps: 155945
# Number of training steps: 1680
# Training speed: 2.6/s
# Loss: 0.5612
#
# Buffer size: 157545
# Buffer update speed: 160.0/s
# Number of environment steps: 157545
# Number of training steps: 1709
# Training speed: 2.9/s
# Loss: 0.5013
#
# Buffer size: 159145
# Buffer update speed: 160.0/s
# Number of environment steps: 159145
# Number of training steps: 1738
# Training speed: 2.9/s
# Loss: 0.4426
#
# Buffer size: 160862
# Buffer update speed: 171.7/s
# Number of environment steps: 160862
# Average episode return: 720.0000
# Number of training steps: 1757
# Training speed: 1.9/s
# Loss: 0.6107
#
# Buffer size: 162862
# Buffer update speed: 200.0/s
# Number of environment steps: 162862
# Number of training steps: 1784
# Training speed: 2.7/s
# Loss: 0.5673
#
# Buffer size: 164062
# Buffer update speed: 120.0/s
# Number of environment steps: 164062
# Number of training steps: 1809
# Training speed: 2.5/s
# Loss: 0.5011
#
# Buffer size: 166062
# Buffer update speed: 200.0/s
# Number of environment steps: 166062
# Number of training steps: 1845
# Training speed: 3.6/s
# Loss: 0.4563
#
# Buffer size: 167262
# Buffer update speed: 120.0/s
# Number of environment steps: 167262
# Number of training steps: 1878
# Training speed: 3.3/s
# Loss: 0.4133
#
# Buffer size: 169662
# Buffer update speed: 240.0/s
# Number of environment steps: 169662
# Number of training steps: 1913
# Training speed: 3.5/s
# Loss: 0.5552
#
# Buffer size: 171149
# Buffer update speed: 148.7/s
# Number of environment steps: 171149
# Average episode return: 3200.0000
# Number of training steps: 1931
# Training speed: 1.8/s
# Loss: 0.3834
#
# Buffer size: 172773
# Buffer update speed: 162.4/s
# Number of environment steps: 172773
# Average episode return: 80.0000
# Number of training steps: 1968
# Training speed: 3.9/s
# Loss: 0.5143
#
# Buffer size: 174773
# Buffer update speed: 200.0/s
# Number of environment steps: 174773
# Number of training steps: 1999
# Training speed: 2.9/s
# Loss: 0.5187
#
# Buffer size: 176773
# Buffer update speed: 200.0/s
# Number of environment steps: 176773
# Number of training steps: 2030
# Training speed: 3.1/s
# Loss: 0.4032
#
# Buffer size: 177973
# Buffer update speed: 120.0/s
# Number of environment steps: 177973
# Number of training steps: 2049
# Training speed: 1.9/s
# Loss: 0.4676
#
# Buffer size: 179573
# Buffer update speed: 160.0/s
# Number of environment steps: 179573
# Number of training steps: 2071
# Training speed: 2.2/s
# Loss: 0.4325
#
# Buffer size: 181259
# Buffer update speed: 168.6/s
# Number of environment steps: 181259
# Number of training steps: 2092
# Training speed: 2.1/s
# Loss: 0.3158
#
# Buffer size: 183259
# Buffer update speed: 200.0/s
# Number of environment steps: 183259
# Number of training steps: 2108
# Training speed: 1.6/s
# Loss: 0.4152
#
# Buffer size: 184797
# Buffer update speed: 153.8/s
# Number of environment steps: 184797
# Number of training steps: 2137
# Training speed: 2.9/s
# Loss: 0.4084
#
# Buffer size: 185997
# Buffer update speed: 120.0/s
# Number of environment steps: 185997
# Number of training steps: 2167
# Training speed: 3.0/s
# Loss: 0.4405
#
# Buffer size: 187997
# Buffer update speed: 200.0/s
# Number of environment steps: 187997
# Number of training steps: 2201
# Training speed: 3.4/s
# Loss: 0.4329
#
# Buffer size: 189597
# Buffer update speed: 160.0/s
# Number of environment steps: 189597
# Number of training steps: 2222
# Training speed: 2.1/s
# Loss: 0.4298
#
# Buffer size: 191597
# Buffer update speed: 200.0/s
# Number of environment steps: 191597
# Number of training steps: 2242
# Training speed: 1.9/s
# Loss: 0.4077
#
# Buffer size: 193197
# Buffer update speed: 160.0/s
# Number of environment steps: 193197
# Number of training steps: 2262
# Training speed: 2.0/s
# Loss: 0.4981
#
# Buffer size: 195155
# Buffer update speed: 195.8/s
# Number of environment steps: 195155
# Average episode return: 2120.0000
# Number of training steps: 2290
# Training speed: 2.8/s
# Loss: 0.3940
#
# Buffer size: 196755
# Buffer update speed: 160.0/s
# Number of environment steps: 196755
# Number of training steps: 2325
# Training speed: 3.4/s
# Loss: 0.4616
#
# Buffer size: 198355
# Buffer update speed: 160.0/s
# Number of environment steps: 198355
# Number of training steps: 2350
# Training speed: 2.5/s
# Loss: 0.4197
#
# Buffer size: 199955
# Buffer update speed: 160.0/s
# Number of environment steps: 199955
# Number of training steps: 2372
# Training speed: 2.2/s
# Loss: 0.4115
#
# Buffer size: 201555
# Buffer update speed: 160.0/s
# Number of environment steps: 201555
# Number of training steps: 2398
# Training speed: 2.6/s
# Loss: 0.4258
#
# Buffer size: 203555
# Buffer update speed: 200.0/s
# Number of environment steps: 203555
# Number of training steps: 2420
# Training speed: 2.2/s
# Loss: 0.3825
#
# Buffer size: 204633
# Buffer update speed: 107.8/s
# Number of environment steps: 204633
# Average episode return: 320.0000
# Number of training steps: 2446
# Training speed: 2.6/s
# Loss: 0.4220
#
# Buffer size: 207033
# Buffer update speed: 240.0/s
# Number of environment steps: 207033
# Number of training steps: 2481
# Training speed: 3.5/s
# Loss: 0.4233
#
# Buffer size: 208633
# Buffer update speed: 160.0/s
# Number of environment steps: 208633
# Number of training steps: 2502
# Training speed: 2.1/s
# Loss: 0.4202
#
# Buffer size: 209833
# Buffer update speed: 120.0/s
# Number of environment steps: 209833
# Number of training steps: 2524
# Training speed: 2.2/s
# Loss: 0.4298
#
# Buffer size: 211835
# Buffer update speed: 200.2/s
# Number of environment steps: 211835
# Average episode return: 480.0000
# Number of training steps: 2548
# Training speed: 2.4/s
#
# Loss: 0.3520
# Buffer size: 213847
# Buffer update speed: 201.2/s
# Number of environment steps: 213847
# Average episode return: 80.0000
# Number of training steps: 2581
# Training speed: 3.3/s
# Loss: 0.3940
#
# Buffer size: 214865
# Buffer update speed: 101.8/s
# Number of environment steps: 214865
# Average episode return: 80.0000
# Number of training steps: 2611
# Training speed: 3.0/s
# Loss: 0.4105
#
# Buffer size: 217665
# Buffer update speed: 280.0/s
# Number of environment steps: 217665
# Number of training steps: 2636
# Training speed: 2.5/s
# Loss: 0.3928
#
# Buffer size: 218465
# Buffer update speed: 80.0/s
# Number of environment steps: 218465
# Number of training steps: 2663
# Training speed: 2.7/s
# Loss: 0.4415
#
# Buffer size: 220465
# Buffer update speed: 200.0/s
# Number of environment steps: 220465
# Number of training steps: 2690
# Training speed: 2.7/s
# Loss: 0.4338
#
# Buffer size: 222465
# Buffer update speed: 200.0/s
# Number of environment steps: 222465
# Number of training steps: 2709
# Training speed: 1.9/s
# Loss: 0.3418
#
# Buffer size: 223897
# Buffer update speed: 143.2/s
# Number of environment steps: 223897
# Average episode return: 160.0000
# Number of training steps: 2739
# Training speed: 3.1/s
# Loss: 0.4220
#
# Buffer size: 225497
# Buffer update speed: 160.0/s
# Number of environment steps: 225497
# Number of training steps: 2772
# Training speed: 3.2/s
# Loss: 0.3964
#
# Buffer size: 227497
# Buffer update speed: 200.0/s
# Number of environment steps: 227497
# Number of training steps: 2812
# Training speed: 3.9/s
# Loss: 0.4433
#
# Buffer size: 228697
# Buffer update speed: 120.0/s
# Number of environment steps: 228697
# Number of training steps: 2840
# Training speed: 2.9/s
# Loss: 0.4856
#
# Buffer size: 231097
# Buffer update speed: 240.0/s
# Number of environment steps: 231097
# Number of training steps: 2866
# Training speed: 2.5/s
# Loss: 0.4102
#
# Buffer size: 231897
# Buffer update speed: 80.0/s
# Number of environment steps: 231897
# Number of training steps: 2889
# Training speed: 2.3/s
# Loss: 0.4127
#
# Buffer size: 235097
# Buffer update speed: 320.0/s
# Number of environment steps: 235097
# Number of training steps: 2915
# Training speed: 2.6/s
# Loss: 0.4177
#
# Buffer size: 235497
# Buffer update speed: 40.0/s
# Number of environment steps: 235497
# Number of training steps: 2947
# Training speed: 3.2/s
# Loss: 0.4802
#
# Buffer size: 238297
# Buffer update speed: 280.0/s
# Number of environment steps: 238297
# Number of training steps: 2980
# Training speed: 3.3/s
#
# Loss: 0.5207
# Buffer size: 238697
# Buffer update speed: 40.0/s
# Number of environment steps: 238697
# Number of training steps: 3001
# Training speed: 2.1/s
# Loss: 0.5502
#
# Buffer size: 241497
# Buffer update speed: 280.0/s
# Number of environment steps: 241497
# Number of training steps: 3029
# Training speed: 2.8/s
# Loss: 0.5453
#
# Buffer size: 242146
# Buffer update speed: 64.9/s
# Number of environment steps: 242146
# Average episode return: 2080.0000
# Number of training steps: 3058
# Training speed: 2.9/s
# Loss: 0.4919
#
# Buffer size: 244546
# Buffer update speed: 240.0/s
# Number of environment steps: 244546
# Number of training steps: 3080
# Training speed: 2.2/s
# Loss: 0.6149
#
# Buffer size: 245346
# Buffer update speed: 80.0/s
# Number of environment steps: 245346
# Number of training steps: 3107
# Training speed: 2.7/s
# Loss: 0.5384
#
# Buffer size: 247746
# Buffer update speed: 240.0/s
# Number of environment steps: 247746
# Number of training steps: 3142
# Training speed: 3.5/s
# Loss: 0.6383
#
# Buffer size: 248946
# Buffer update speed: 120.0/s
# Number of environment steps: 248946
# Number of training steps: 3166
# Training speed: 2.4/s
# Loss: 0.5787
#
# Buffer size: 250946
# Buffer update speed: 200.0/s
# Number of environment steps: 250946
# Number of training steps: 3197
# Training speed: 3.0/s
# Loss: 0.5097
#
# Buffer size: 252546
# Buffer update speed: 160.0/s
# Number of environment steps: 252546
# Number of training steps: 3234
# Training speed: 3.7/s
# Loss: 0.5669
#
# Buffer size: 254207
# Buffer update speed: 166.1/s
# Number of environment steps: 254207
# Average episode return: 1500.0000
# Number of training steps: 3272
# Training speed: 3.8/s
# Loss: 0.5178
#
# Buffer size: 255807
# Buffer update speed: 160.0/s
# Number of environment steps: 255807
# Number of training steps: 3302
# Training speed: 3.0/s
# Loss: 0.5871
#
# Buffer size: 257407
# Buffer update speed: 160.0/s
# Number of environment steps: 257407
# Number of training steps: 3340
# Training speed: 3.8/s
# Loss: 0.5806
#
# Buffer size: 259807
# Buffer update speed: 240.0/s
# Number of environment steps: 259807
# Number of training steps: 3377
# Training speed: 3.7/s
# Loss: 0.5685
#
# Buffer size: 260817
# Buffer update speed: 101.0/s
# Number of environment steps: 260817
# Average episode return: 100.0000
# Number of training steps: 3400
# Training speed: 2.3/s
# Loss: 0.6178
#
# Buffer size: 262417
# Buffer update speed: 160.0/s
# Number of environment steps: 262417
# Number of training steps: 3431
# Training speed: 3.0/s
# Loss: 0.6276
#
# Buffer size: 264017
# Buffer update speed: 160.0/s
# Number of environment steps: 264017
# Number of training steps: 3455
# Training speed: 2.4/s
# Loss: 0.5273
#
# Buffer size: 266454
# Buffer update speed: 243.7/s
# Number of environment steps: 266562
# Average episode return: 1190.0000
# Number of training steps: 3481
# Training speed: 2.6/s
# Loss: 0.5856
#
# Buffer size: 267362
# Buffer update speed: 80.0/s
# Number of environment steps: 267362
# Number of training steps: 3513
# Training speed: 3.1/s
# Loss: 0.5496
#
# Buffer size: 269362
# Buffer update speed: 200.0/s
# Number of environment steps: 269362
# Number of training steps: 3545
# Training speed: 3.1/s
# Loss: 0.6049
#
# Buffer size: 270562
# Buffer update speed: 120.0/s
# Number of environment steps: 270562
# Number of training steps: 3569
# Training speed: 2.4/s
# Loss: 0.5834
#
# Buffer size: 272562
# Buffer update speed: 200.0/s
# Number of environment steps: 272562
# Number of training steps: 3605
# Training speed: 3.5/s
# Loss: 0.5086
#
# Buffer size: 274162
# Buffer update speed: 160.0/s
# Number of environment steps: 274162
# Number of training steps: 3631
# Training speed: 2.6/s
# Loss: 0.5335
#
# Buffer size: 275362
# Buffer update speed: 120.0/s
# Number of environment steps: 275362
# Number of training steps: 3656
# Training speed: 2.5/s
# Loss: 0.5610
#
# Buffer size: 277362
# Buffer update speed: 200.0/s
# Number of environment steps: 277362
# Number of training steps: 3688
# Training speed: 3.1/s
# Loss: 0.5632
#
# Buffer size: 278962
# Buffer update speed: 160.0/s
# Number of environment steps: 278962
# Number of training steps: 3714
# Training speed: 2.7/s
# Loss: 0.5143
#
# Buffer size: 280962
# Buffer update speed: 200.0/s
# Number of environment steps: 280962
# Number of training steps: 3742
# Training speed: 2.7/s
# Loss: 0.5490
#
# Buffer size: 282162
# Buffer update speed: 120.0/s
# Number of environment steps: 282162
# Number of training steps: 3775
# Training speed: 3.3/s
# Loss: 0.5555
#
# Buffer size: 284562
# Buffer update speed: 240.0/s
# Number of environment steps: 284562
# Number of training steps: 3799
# Training speed: 2.4/s
# Loss: 0.6189
#
# Buffer size: 285631
# Buffer update speed: 106.9/s
# Number of environment steps: 285631
# Average episode return: 640.0000
# Number of training steps: 3817
# Training speed: 1.8/s
# Loss: 0.5095
#
# Buffer size: 287360
# Buffer update speed: 172.9/s
# Number of environment steps: 287360
# Average episode return: 1200.0000
# Number of training steps: 3851
# Training speed: 3.3/s
# Loss: 0.5937
#
# Buffer size: 289155
# Buffer update speed: 179.5/s
# Number of environment steps: 289155
# Average episode return: 80.0000
# Number of training steps: 3883
# Training speed: 3.2/s
# Loss: 0.5756
#
# Buffer size: 291155
# Buffer update speed: 200.0/s
# Number of environment steps: 291155
# Number of training steps: 3911
# Training speed: 2.8/s
# Loss: 0.5424
#
# Buffer size: 292755
# Buffer update speed: 160.0/s
# Number of environment steps: 292755
# Number of training steps: 3932
# Training speed: 2.1/s
# Loss: 0.4679
#
# Buffer size: 294355
# Buffer update speed: 160.0/s
# Number of environment steps: 294355
# Number of training steps: 3959
# Training speed: 2.8/s
# Loss: 0.5585
#
# Buffer size: 296355
# Buffer update speed: 200.0/s
# Number of environment steps: 296355
# Number of training steps: 3986
# Training speed: 2.6/s
# Loss: 0.5255
#
# Buffer size: 298755
# Buffer update speed: 240.0/s
# Number of environment steps: 298755Training speed: 2.4/s
# Number of training steps: 4010
#
# Loss: 0.5225
#
# Buffer size: 299419
# Buffer update speed: 66.4/s
# Number of environment steps: 299419
# Average episode return: 400.0000
# Number of training steps: 4032
# Training speed: 2.2/s
# Loss: 0.5185
#
# Buffer size: 301419
# Buffer update speed: 200.0/s
# Number of environment steps: 301419
# Number of training steps: 4050
# Training speed: 1.8/s
# Loss: 0.5747
#
# Buffer size: 302741
# Buffer update speed: 132.2/s
# Number of environment steps: 302741
# Average episode return: 1800.0000
# Number of training steps: 4075
# Training speed: 2.5/s
# Loss: 0.5079
#
# Buffer size: 304741
# Buffer update speed: 200.0/s
# Number of environment steps: 304741
# Number of training steps: 4110
# Training speed: 3.5/s
# Loss: 0.5103
#
# Buffer size: 306341
# Buffer update speed: 160.0/s
# Number of environment steps: 306341
# Number of training steps: 4144
# Training speed: 3.4/s
# Loss: 0.4726
#
# Buffer size: 307941
# Buffer update speed: 160.0/s
# Number of environment steps: 307941
# Number of training steps: 4172
# Training speed: 2.8/s
# Loss: 0.4608
#
# Buffer size: 309941
# Buffer update speed: 200.0/s
# Number of environment steps: 309941
# Number of training steps: 4200
# Training speed: 2.8/s
# Loss: 0.5457
#
# Buffer size: 311941
# Buffer update speed: 200.0/s
# Number of environment steps: 311941
# Number of training steps: 4225
# Training speed: 2.5/s
# Loss: 0.5075
#
# Buffer size: 313541
# Buffer update speed: 160.0/s
# Number of environment steps: 313541
# Number of training steps: 4259
# Training speed: 3.4/s
# Loss: 0.4631
#
# Buffer size: 314741
# Buffer update speed: 120.0/s
# Number of environment steps: 314741
# Number of training steps: 4294
# Training speed: 3.5/s
# Loss: 0.4738
#
# Buffer size: 317141
# Buffer update speed: 240.0/s
# Number of environment steps: 317141
# Number of training steps: 4319
# Training speed: 2.5/s
# Loss: 0.5617
#
# Buffer size: 318341
# Buffer update speed: 120.0/s
# Number of environment steps: 318341
# Number of training steps: 4343
# Training speed: 2.4/s
# Loss: 0.4701
#
# Buffer size: 319941
# Buffer update speed: 160.0/s
# Number of environment steps: 319941
# Number of training steps: 4374
# Training speed: 3.1/s
# Loss: 0.4438
#
# Buffer size: 321141
# Buffer update speed: 120.0/s
# Number of environment steps: 321141
# Number of training steps: 4399
# Training speed: 2.5/s
# Loss: 0.4547
#
# Buffer size: 323941
# Buffer update speed: 280.0/s
# Number of environment steps: 323941
# Number of training steps: 4421
# Training speed: 2.1/s
# Loss: 0.5175
#
# Buffer size: 324341
# Buffer update speed: 40.0/s
# Number of environment steps: 324341
# Number of training steps: 4441
# Training speed: 2.0/s
# Loss: 0.4900
#
# Buffer size: 327141
# Buffer update speed: 280.0/s
# Number of environment steps: 327141
# Number of training steps: 4459
# Training speed: 1.8/s
# Loss: 0.5521
#
# Buffer size: 327541
# Buffer update speed: 40.0/s
# Number of environment steps: 327541
# Number of training steps: 4478
# Training speed: 1.9/s
# Loss: 0.5036
#
# Buffer size: 330341
# Buffer update speed: 280.0/s
# Number of environment steps: 330341
# Number of training steps: 4504
# Training speed: 2.5/s
# Loss: 0.4924
#
# Buffer size: 331141
# Buffer update speed: 80.0/s
# Number of environment steps: 331141
# Number of training steps: 4536
# Training speed: 3.2/s
# Loss: 0.5144
#
# Buffer size: 333541
# Buffer update speed: 240.0/s
# Number of environment steps: 333541
# Number of training steps: 4555
# Training speed: 1.9/s
# Loss: 0.4989
#
# Buffer size: 334741
# Buffer update speed: 120.0/s
# Number of environment steps: 334741
# Number of training steps: 4572
# Training speed: 1.7/s
# Loss: 0.5666
#
# Buffer size: 337141
# Buffer update speed: 240.0/s
# Number of environment steps: 337141
# Number of training steps: 4600
# Training speed: 2.8/s
# Loss: 0.5507
#
# Buffer size: 338244
# Buffer update speed: 110.3/s
# Number of environment steps: 338244
# Number of training steps: 4632
# Training speed: 3.2/s
# Loss: 0.4831
#
# Buffer size: 340244
# Buffer update speed: 200.0/s
# Number of environment steps: 340244
# Number of training steps: 4670
# Training speed: 3.8/s
# Loss: 0.5260
#
# Buffer size: 341444
# Buffer update speed: 120.0/s
# Number of environment steps: 341444
# Number of training steps: 4700
# Training speed: 3.0/s
# Loss: 0.5310
#
# Buffer size: 343328
# Buffer update speed: 188.4/s
# Number of environment steps: 343328
# Average episode return: 40.0000
# Number of training steps: 4731
# Training speed: 3.1/s
# Loss: 0.4909
#
# Buffer size: 345328
# Buffer update speed: 200.0/s
# Number of environment steps: 345328
# Number of training steps: 4757
# Training speed: 2.6/s
# Loss: 0.4946
#
# Buffer size: 346928
# Buffer update speed: 160.0/s
# Number of environment steps: 346928
# Number of training steps: 4789
# Training speed: 3.2/s
# Loss: 0.4795
#
# Buffer size: 348928
# Buffer update speed: 200.0/s
# Number of environment steps: 348928
# Number of training steps: 4809
# Training speed: 2.0/s
# Loss: 0.4931
#
# Buffer size: 350042
# Buffer update speed: 111.4/s
# Number of environment steps: 350042
# Number of training steps: 4825
# Training speed: 1.6/s
# Loss: 0.4671
#
# Buffer size: 351642
# Buffer update speed: 160.0/s
# Number of environment steps: 351642
# Number of training steps: 4853
# Training speed: 2.8/s
# Loss: 0.4656
#
# Buffer size: 353242
# Buffer update speed: 160.0/s
# Number of environment steps: 353242
# Number of training steps: 4884
# Training speed: 3.1/s
# Loss: 0.4284
#
# Buffer size: 355242
# Buffer update speed: 200.0/s
# Number of environment steps: 355242
# Number of training steps: 4912
# Training speed: 2.8/s
# Loss: 0.4894
#
# Buffer size: 357242
# Buffer update speed: 200.0/s
# Number of environment steps: 357242
# Number of training steps: 4932
# Training speed: 2.0/s
# Loss: 0.5226
#
# Buffer size: 358442
# Buffer update speed: 120.0/s
# Number of environment steps: 358442
# Number of training steps: 4967
# Training speed: 3.5/s
# Loss: 0.5114
#
# Buffer size: 360042
# Buffer update speed: 160.0/s
# Number of environment steps: 360042
# Number of training steps: 5000
# Training speed: 3.3/s
# Loss: 0.5307
#
# Buffer size: 361642
# Buffer update speed: 160.0/s
# Number of environment steps: 361642
# Number of training steps: 5027
# Training speed: 2.7/s
# Loss: 0.4686
#
# Buffer size: 363242
# Buffer update speed: 160.0/s
# Number of environment steps: 363242
# Number of training steps: 5059
# Training speed: 3.2/s
# Loss: 0.5409
#
# Buffer size: 364997
# Buffer update speed: 175.5/s
# Number of environment steps: 364997
# Average episode return: 3160.0000
# Number of training steps: 5094
# Training speed: 3.5/s
# Loss: 0.4694
#
# Buffer size: 366997
# Buffer update speed: 200.0/s
# Number of environment steps: 366997
# Number of training steps: 5125
# Training speed: 3.1/s
# Loss: 0.4447
#
# Buffer size: 368197
# Buffer update speed: 120.0/s
# Number of environment steps: 368197
# Number of training steps: 5162
# Training speed: 3.7/s
# Loss: 0.5422
#
# Buffer size: 370597
# Buffer update speed: 240.0/s
# Number of environment steps: 370597
# Number of training steps: 5191
# Training speed: 2.9/s
# Loss: 0.5592
#
# Buffer size: 371397
# Buffer update speed: 80.0/s
# Number of environment steps: 371397
# Number of training steps: 5217
# Training speed: 2.6/s
# Loss: 0.5283
#
# Buffer size: 374252
# Buffer update speed: 285.5/s
# Number of environment steps: 374252
# Average episode return: 640.0000
# Number of training steps: 5240
# Training speed: 2.3/s
# Loss: 0.5184
#
# Buffer size: 375052
# Buffer update speed: 80.0/s
# Number of environment steps: 375052
# Number of training steps: 5271
# Training speed: 3.1/s
# Loss: 0.4929
#
# Buffer size: 377452
# Buffer update speed: 240.0/s
# Number of environment steps: 377452
# Number of training steps: 5301
# Training speed: 3.1/s
# Loss: 0.5856
#
# Buffer size: 378652
# Buffer update speed: 120.0/s
# Number of environment steps: 378652
# Number of training steps: 5330
# Training speed: 2.8/s
# Loss: 0.6179
#
# Buffer size: 381052
# Buffer update speed: 240.0/s
# Number of environment steps: 381052
# Number of training steps: 5360
# Training speed: 3.0/s
# Loss: 0.6339
#
# Buffer size: 382652
# Buffer update speed: 160.0/s
# Number of environment steps: 382652
# Number of training steps: 5390
# Training speed: 3.0/s
# Loss: 0.5228
#
# Buffer size: 384652
# Buffer update speed: 200.0/s
# Number of environment steps: 384652
# Number of training steps: 5409
# Training speed: 1.9/s
# Loss: 0.5813
#
# Buffer size: 385852
# Buffer update speed: 120.0/s
# Number of environment steps: 385852
# Number of training steps: 5428
# Training speed: 2.0/s
# Loss: 0.5358
#
# Buffer size: 387549
# Buffer update speed: 169.7/s
# Number of environment steps: 387549
# Average episode return: 1140.0000
# Number of training steps: 5452
# Training speed: 2.3/s
# Loss: 0.5836
#
# Buffer size: 389534
# Buffer update speed: 198.5/s
# Number of environment steps: 389534
# Number of training steps: 5477
# Training speed: 2.5/s
# Loss: 0.5560
#
# Buffer size: 390334
# Buffer update speed: 80.0/s
# Number of environment steps: 390334
# Number of training steps: 5501
# Training speed: 2.4/s
# Loss: 0.5325
#
# Buffer size: 392734
# Buffer update speed: 240.0/s
# Number of environment steps: 392734
# Number of training steps: 5528
# Training speed: 2.7/s
# Loss: 0.5633
#
# Buffer size: 393925
# Buffer update speed: 119.1/s
# Number of environment steps: 393925
# Average episode return: 1180.0000
# Number of training steps: 5556
# Training speed: 2.8/s
# Loss: 0.6162
#
# Buffer size: 395925
# Buffer update speed: 200.0/s
# Number of environment steps: 395925
# Number of training steps: 5575
# Training speed: 1.9/s
# Loss: 0.5774
#
# Buffer size: 397125
# Buffer update speed: 120.0/s
# Number of environment steps: 397125
# Number of training steps: 5602
# Training speed: 2.7/s
# Loss: 0.5998
#
# Buffer size: 399125
# Buffer update speed: 200.0/s
# Number of environment steps: 399125
# Number of training steps: 5633
# Training speed: 3.1/s
# Loss: 0.5465
#
# Buffer size: 400325
# Buffer update speed: 120.0/s
# Number of environment steps: 400325
# Number of training steps: 5654
# Training speed: 2.1/s
# Loss: 0.5710
#
# Buffer size: 402725
# Buffer update speed: 240.0/s
# Number of environment steps: 402725
# Number of training steps: 5690
# Training speed: 3.5/s
# Loss: 0.5941
#
# Buffer size: 403525
# Buffer update speed: 80.0/s
# Number of environment steps: 403525
# Number of training steps: 5713
# Training speed: 2.3/s
# Loss: 0.5550
#
# Buffer size: 406302
# Buffer update speed: 277.7/s
# Number of environment steps: 406302
# Average episode return: 1780.0000
# Number of training steps: 5745
# Training speed: 3.2/s
# Loss: 0.6222
#
# Buffer size: 407102
# Buffer update speed: 80.0/s
# Number of environment steps: 407102
# Number of training steps: 5770
# Training speed: 2.5/s
# Loss: 0.5934
#
# Buffer size: 409102
# Buffer update speed: 200.0/s
# Number of environment steps: 409102
# Number of training steps: 5801
# Training speed: 3.1/s
# Loss: 0.5424
#
# Buffer size: 410623
# Buffer update speed: 152.1/s
# Number of environment steps: 410623
# Average episode return: 1500.0000
# Number of training steps: 5829
# Training speed: 2.8/s
# Loss: 0.5030
#
# Buffer size: 413023
# Buffer update speed: 240.0/s
# Number of environment steps: 413023
# Number of training steps: 5860
# Training speed: 3.0/s
# Loss: 0.5064
#
# Buffer size: 413823
# Buffer update speed: 80.0/s
# Number of environment steps: 413823
# Number of training steps: 5880
# Training speed: 1.9/s
# Loss: 0.4708
#
# Buffer size: 416223
# Buffer update speed: 240.0/s
# Number of environment steps: 416223
# Number of training steps: 5902
# Training speed: 2.2/s
# Loss: 0.6223
#
# Buffer size: 416974
# Buffer update speed: 75.1/s
# Number of environment steps: 416974
# Average episode return: 1460.0000
# Number of training steps: 5929
# Training speed: 2.6/s
# Loss: 0.5851
#
# Buffer size: 420211
# Buffer update speed: 323.7/s
# Number of environment steps: 420211
# Number of training steps: 5955
# Training speed: 2.6/s
# Loss: 0.5911
#
# Buffer size: 420211
# Buffer update speed: 0.0/s
# Number of environment steps: 420211
# Number of training steps: 5982
# Training speed: 2.7/s
# Loss: 0.5594
#
# Buffer size: 423411
# Buffer update speed: 320.0/s
# Number of environment steps: 423411
# Number of training steps: 6008
# Training speed: 2.6/s
# Loss: 0.5183
#
# Buffer size: 423811
# Buffer update speed: 40.0/s
# Number of environment steps: 423811
# Number of training steps: 6036
# Training speed: 2.7/s
# Loss: 0.5543
#
# Buffer size: 426611
# Buffer update speed: 280.0/s
# Number of environment steps: 426611
# Number of training steps: 6065
# Training speed: 2.9/s
# Loss: 0.5555
#
# Buffer size: 427811
# Buffer update speed: 120.0/s
# Number of environment steps: 427811
# Number of training steps: 6094
# Training speed: 2.8/s
# Loss: 0.5280
#
# Buffer size: 430211
# Buffer update speed: 240.0/s
# Number of environment steps: 430211
# Number of training steps: 6115
# Training speed: 2.1/s
# Loss: 0.4999
#
# Buffer size: 431005
# Buffer update speed: 79.4/s
# Number of environment steps: 431005
# Average episode return: 1140.0000
# Number of training steps: 6141
# Training speed: 2.6/s
# Loss: 0.5579
#
# Buffer size: 433405
# Buffer update speed: 240.0/s
# Number of environment steps: 433405
# Number of training steps: 6165
# Training speed: 2.4/s
# Loss: 0.4476
#
# Buffer size: 434205
# Buffer update speed: 80.0/s
# Number of environment steps: 434205
# Number of training steps: 6197
# Training speed: 3.2/s
# Loss: 0.5457
#
# Buffer size: 436605
# Buffer update speed: 240.0/s
# Number of environment steps: 436605
# Number of training steps: 6223
# Training speed: 2.5/s
# Loss: 0.5466
#
# Buffer size: 438205
#
# Buffer update speed: 160.0/sNumber of environment steps: 438205
# Number of training steps: 6242
# Training speed: 1.9/s
# Loss: 0.4979
#
# Buffer size: 439805
# Buffer update speed: 160.0/s
# Number of environment steps: 439805
# Number of training steps: 6266
# Training speed: 2.4/s
# Loss: 0.5712
#
# Buffer size: 441805
# Buffer update speed: 200.0/s
# Number of environment steps: 441805
# Number of training steps: 6293
# Training speed: 2.7/s
# Loss: 0.5137
#
# Buffer size: 443405
# Buffer update speed: 160.0/s
# Number of environment steps: 443405
# Number of training steps: 6321
# Training speed: 2.7/s
# Loss: 0.5573
#
# Buffer size: 444605
# Buffer update speed: 120.0/s
# Number of environment steps: 444605
# Number of training steps: 6352
# Training speed: 3.1/s
# Loss: 0.4678
#
# Buffer size: 447405
# Buffer update speed: 280.0/s
# Number of environment steps: 447405
# Number of training steps: 6379
# Training speed: 2.7/s
# Loss: 0.5325
#
# Buffer size: 447805
# Buffer update speed: 40.0/s
# Number of environment steps: 447805
# Number of training steps: 6399
# Training speed: 2.0/s
# Loss: 0.5125
#
# Buffer size: 450605
# Buffer update speed: 280.0/s
# Number of environment steps: 450605
# Number of training steps: 6423
# Training speed: 2.4/s
# Loss: 0.5440
#
# Buffer size: 451804
# Buffer update speed: 119.9/s
# Number of environment steps: 451804
# Number of training steps: 6445
# Training speed: 2.2/s
# Loss: 0.4495
#
# Buffer size: 453804
# Buffer update speed: 200.0/s
# Number of environment steps: 453804
# Number of training steps: 6470
# Training speed: 2.4/s
# Loss: 0.5621
#
# Buffer size: 456069
# Buffer update speed: 226.5/s
# Number of environment steps: 456069
# Average episode return: 1020.0000
# Number of training steps: 6499
# Training speed: 2.9/s
# Loss: 0.5234
#
# Buffer size: 456869
# Buffer update speed: 80.0/s
# Number of environment steps: 456869
# Number of training steps: 6529
# Training speed: 3.0/s
# Loss: 0.5400
#
# Buffer size: 458869
# Buffer update speed: 200.0/s
# Number of environment steps: 458869
# Number of training steps: 6555
# Training speed: 2.6/s
# Loss: 0.5551
#
# Buffer size: 460069
# Buffer update speed: 120.0/s
# Number of environment steps: 460069
# Number of training steps: 6575
# Training speed: 1.9/s
# Loss: 0.4609
#
# Buffer size: 462069
# Buffer update speed: 200.0/s
# Number of environment steps: 462069
# Number of training steps: 6596
# Training speed: 2.1/s
# Loss: 0.5273
#
# Buffer size: 463190
# Buffer update speed: 112.1/s
# Number of environment steps: 463190
# Average episode return: 320.0000
# Number of training steps: 6630
# Training speed: 3.4/s
# Loss: 0.5331
#
# Buffer size: 465590
# Buffer update speed: 240.0/s
# Number of environment steps: 465590
# Number of training steps: 6657
# Training speed: 2.7/s
# Loss: 0.6067
#
# Buffer size: 466390
# Buffer update speed: 80.0/s
# Number of environment steps: 466390
# Number of training steps: 6688
# Training speed: 3.1/s
# Loss: 0.5785
#
# Buffer size: 469190
# Buffer update speed: 280.0/s
# Number of environment steps: 469190
# Number of training steps: 6723
# Training speed: 3.5/s
# Loss: 0.5865
#
# Buffer size: 469990
# Buffer update speed: 80.0/s
# Number of environment steps: 469990
# Number of training steps: 6749
# Training speed: 2.6/s
# Loss: 0.5440
#
# Buffer size: 472390
# Buffer update speed: 240.0/s
# Number of environment steps: 472390
# Number of training steps: 6787
# Training speed: 3.8/s
# Loss: 0.5327
#
# Buffer size: 473190
# Buffer update speed: 80.0/s
# Number of environment steps: 473190
# Number of training steps: 6816
# Training speed: 2.9/s
# Loss: 0.5233
#
# Buffer size: 475990
# Buffer update speed: 280.0/s
# Number of environment steps: 475990
# Number of training steps: 6850
# Training speed: 3.3/s
# Loss: 0.5974
#
# Buffer size: 476420
# Buffer update speed: 43.0/s
# Number of environment steps: 476420
# Average episode return: 320.0000
# Number of training steps: 6874
# Training speed: 2.4/s
# Loss: 0.5488
#
# Buffer size: 479220
# Buffer update speed: 280.0/s
# Number of environment steps: 479220
# Number of training steps: 6892
# Training speed: 1.8/s
# Loss: 0.5480
#
# Buffer size: 480810
# Buffer update speed: 159.0/s
# Number of environment steps: 480810
# Average episode return: 230.0000
# Number of training steps: 6920
# Training speed: 2.8/s
# Loss: 0.5194
#
# Buffer size: 482410
# Buffer update speed: 160.0/s
# Number of environment steps: 482410
# Number of training steps: 6948
# Training speed: 2.8/s
# Loss: 0.5238
#
# Buffer size: 484003
# Buffer update speed: 159.3/s
# Number of environment steps: 484003
# Average episode return: 80.0000
# Number of training steps: 6979
# Training speed: 3.0/s
# Loss: 0.5466
#
# Buffer size: 485603
# Buffer update speed: 160.0/s
# Number of environment steps: 485603
# Number of training steps: 7004
# Training speed: 2.5/s
# Loss: 0.4850
#
# Buffer size: 487283
# Buffer update speed: 168.0/s
# Number of environment steps: 487283
# Average episode return: 5240.0000
# Number of training steps: 7031
# Training speed: 2.7/s
# Loss: 0.5686
#
# Buffer size: 488883
# Buffer update speed: 160.0/s
# Number of environment steps: 488883
# Number of training steps: 7051
# Training speed: 2.0/s
# Loss: 0.5582
#
# Buffer size: 491283
# Buffer update speed: 240.0/s
# Number of environment steps: 491283
# Number of training steps: 7079
# Training speed: 2.8/s
# Loss: 0.6569
#
# Buffer size: 492883
# Buffer update speed: 160.0/s
# Number of environment steps: 492883
# Number of training steps: 7112
# Training speed: 3.3/s
# Loss: 0.5461
#
# Buffer size: 494430
# Buffer update speed: 154.7/s
# Number of environment steps: 494430
# Number of training steps: 7145
# Training speed: 3.3/s
# Loss: 0.5603
#
# Buffer size: 496030
# Buffer update speed: 160.0/s
# Number of environment steps: 496030
# Number of training steps: 7183
# Training speed: 3.8/s
# Loss: 0.5286
#
# Buffer size: 498212
# Buffer update speed: 218.2/s
# Number of environment steps: 498212
# Number of training steps: 7216
# Training speed: 3.3/s
# Loss: 0.6397
#
# Buffer size: 499012
# Buffer update speed: 80.0/s
# Number of environment steps: 499012
# Number of training steps: 7245
# Training speed: 2.9/s
# Loss: 0.6020
#
# Buffer size: 501412
# Buffer update speed: 240.0/s
# Number of environment steps: 501412
# Number of training steps: 7273
# Training speed: 2.8/s
# Loss: 0.5593
#
# Buffer size: 502612
# Buffer update speed: 120.0/s
# Number of environment steps: 502612
# Number of training steps: 7306
# Training speed: 3.3/s
# Loss: 0.5769
#
# Buffer size: 504612
# Buffer update speed: 200.0/s
# Number of environment steps: 504612
# Number of training steps: 7337
# Training speed: 3.1/s
# Loss: 0.5543
#
# Buffer size: 506212
# Buffer update speed: 160.0/s
# Number of environment steps: 506212
# Number of training steps: 7365
# Training speed: 2.8/s
# Loss: 0.5081
#
# Buffer size: 508212
# Buffer update speed: 200.0/s
# Number of environment steps: 508212
# Number of training steps: 7390
# Training speed: 2.5/s
# Loss: 0.5383
#
# Buffer size: 509412
# Buffer update speed: 120.0/s
# Number of environment steps: 509412
# Number of training steps: 7421
# Training speed: 3.1/s
# Loss: 0.4936
#
# Buffer size: 511395
# Buffer update speed: 198.3/s
# Number of environment steps: 511395
# Average episode return: 380.0000
# Number of training steps: 7447
# Training speed: 2.6/s
# Loss: 0.5811
#
# Buffer size: 512995
# Buffer update speed: 160.0/s
# Number of environment steps: 512995
# Number of training steps: 7464
# Training speed: 1.7/s
# Loss: 0.6171
#
# Buffer size: 514995
# Buffer update speed: 200.0/s
# Number of environment steps: 514995
# Number of training steps: 7500
# Training speed: 3.6/s
# Loss: 0.5901
#
# Buffer size: 516195
# Buffer update speed: 120.0/s
# Number of environment steps: 516195
# Number of training steps: 7533
# Training speed: 3.3/s
# Loss: 0.5148
#
# Buffer size: 518315
# Buffer update speed: 212.0/s
# Number of environment steps: 518315
# Average episode return: 560.0000
# Number of training steps: 7553
# Training speed: 2.0/s
# Loss: 0.4986
#
# Buffer size: 519915
# Buffer update speed: 160.0/s
# Number of environment steps: 519915
# Number of training steps: 7586
# Training speed: 3.3/s
# Loss: 0.5594
#
# Buffer size: 521515
# Buffer update speed: 160.0/s
# Number of environment steps: 521515
# Number of training steps: 7615
# Training speed: 2.9/s
# Loss: 0.5579
#
# Buffer size: 523115
# Buffer update speed: 160.0/s
# Number of environment steps: 523115
# Number of training steps: 7641
# Training speed: 2.6/s
# Loss: 0.5261
#
# Buffer size: 525115
# Buffer update speed: 200.0/s
# Number of environment steps: 525115
# Number of training steps: 7666
# Training speed: 2.5/s
# Loss: 0.5824
#
# Buffer size: 527397
# Buffer update speed: 228.2/s
# Number of environment steps: 527397
# Number of training steps: 7697
# Training speed: 3.0/s
# Loss: 0.5302
#
# Buffer size: 528597
# Buffer update speed: 120.0/s
# Number of environment steps: 528597
# Number of training steps: 7723
# Training speed: 2.6/s
# Loss: 0.5041
#
# Buffer size: 530197
# ...
# Training speed: 2.5/s
# Loss: 0.7503
#
# Buffer size: 1590935
# Buffer update speed: 240.0/s
# Number of environment steps: 1590935
# Number of training steps: 24675
# Training speed: 2.8/s
#
# Loss: 0.7914
# Buffer size: 1592135
# Buffer update speed: 120.0/s
# Number of environment steps: 1592135
# Number of training steps: 24706
# Training speed: 3.1/s
# Loss: 0.6760
#
# Buffer size: 1594135
# Buffer update speed: 200.0/s
# Number of environment steps: 1594135
# Number of training steps: 24729
# Training speed: 2.3/s
# Loss: 0.6272
#
# Buffer size: 1594935
# Buffer update speed: 80.0/s
# Number of environment steps: 1594935
# Number of training steps: 24752
# Training speed: 2.3/s
# Loss: 0.7784
#
# Buffer size: 1597447
# Buffer update speed: 251.2/s
# Number of environment steps: 1597447
# Average episode return: 240.0000
# Number of training steps: 24776
# Training speed: 2.4/s
# Loss: 0.8508
#
# Buffer size: 1599047
# Buffer update speed: 160.0/s
# Number of environment steps: 1599047
# Number of training steps: 24806
# Training speed: 3.0/s
# Loss: 0.7885
#
# Buffer size: 1600656
# Buffer update speed: 160.9/s
# Number of environment steps: 1600656
# Average episode return: 240.0000
# Number of training steps: 24837
# Training speed: 3.1/s
# Loss: 0.7638
#
# Buffer size: 1602458
# Buffer update speed: 180.2/s
# Number of environment steps: 1602458
# Average episode return: 1740.0000
# Number of training steps: 24855
# Training speed: 1.8/s
# Loss: 0.7437
#
# Buffer size: 1603658
# Buffer update speed: 120.0/s
# Number of environment steps: 1603658
# Number of training steps: 24887
# Training speed: 3.1/s
# Loss: 0.6838
#
# Buffer size: 1605258
# Buffer update speed: 160.0/s
# Number of environment steps: 1605258
# Number of training steps: 24915
# Training speed: 2.7/s
# Loss: 0.6868
#
# Buffer size: 1607258
# Buffer update speed: 200.0/s
# Number of environment steps: 1607258
# Number of training steps: 24942
# Training speed: 2.7/s
# Loss: 0.7455
#
# Buffer size: 1608858
# Buffer update speed: 160.0/s
# Number of environment steps: 1608858
# Number of training steps: 24967
# Training speed: 2.5/s
# Loss: 0.7541
#
# Buffer size: 1610588
# Buffer update speed: 173.0/s
# Number of environment steps: 1610588
# Average episode return: 1820.0000
# Number of training steps: 24988
# Training speed: 2.0/s
# Loss: 0.7782
#
# Buffer size: 1612905
# Buffer update speed: 231.7/s
# Number of environment steps: 1612905
# Average episode return: 1940.0000
# Number of training steps: 25018
# Training speed: 3.0/s
# Loss: 0.6206
#
# Buffer size: 1614105
# Buffer update speed: 120.0/s
# Number of environment steps: 1614105
# Number of training steps: 25049
# Training speed: 3.1/s
# Loss: 0.7841
#
# Buffer size: 1616505
# Buffer update speed: 240.0/s
# Number of environment steps: 1616505
# Number of training steps: 25084
# Training speed: 3.5/s
# Loss: 0.6874
#
# Buffer size: 1617305
# Buffer update speed: 80.0/s
# Number of environment steps: 1617305
# Number of training steps: 25114
# Training speed: 3.0/s
# Loss: 0.7163
#
# Buffer size: 1619705
# Buffer update speed: 240.0/s
# Number of environment steps: 1619705
# Number of training steps: 25136
# Training speed: 2.2/s
# Loss: 0.7673
#
# Buffer size: 1620105
# Buffer update speed: 40.0/s
# Number of environment steps: 1620105
# Number of training steps: 25156
# Training speed: 2.0/s
# Loss: 0.6787
#
# Buffer size: 1622505
# Buffer update speed: 240.0/s
# Number of environment steps: 1622505
# Number of training steps: 25182
# Training speed: 2.6/s
# Loss: 0.7067
#
# Buffer size: 1623705
# Buffer update speed: 120.0/s
# Number of environment steps: 1623705
# Number of training steps: 25208
# Training speed: 2.6/s
# Loss: 0.6657
#
# Buffer size: 1626105
# Buffer update speed: 240.0/s
# Number of environment steps: 1626105
# Number of training steps: 25242
# Training speed: 3.3/s
# Loss: 0.7580
#
# Buffer size: 1626505
# Buffer update speed: 40.0/s
# Number of environment steps: 1626505
# Number of training steps: 25259
# Training speed: 1.7/s
# Loss: 0.7313
#
# Buffer size: 1629305
# Buffer update speed: 280.0/s
# Number of environment steps: 1629305
# Number of training steps: 25277
# Training speed: 1.8/s
# Loss: 0.5949
#
# Buffer size: 1630105
# Buffer update speed: 80.0/s
# Number of environment steps: 1630105
# Number of training steps: 25303
# Training speed: 2.6/s
# Loss: 0.7057
#
# Buffer size: 1632905
# Buffer update speed: 280.0/s
# Number of environment steps: 1632905
# Number of training steps: 25328
# Training speed: 2.4/s
# Loss: 0.6938
#
# Buffer size: 1633305
# Buffer update speed: 40.0/s
# Number of environment steps: 1633305
# Number of training steps: 25348
# Training speed: 2.0/s
# Loss: 0.7184
#
# Buffer size: 1635705
# Buffer update speed: 240.0/s
# Number of environment steps: 1635705
# Number of training steps: 25369
# Training speed: 2.1/s
# Loss: 0.6327
#
# Buffer size: 1636505
# Buffer update speed: 80.0/s
# Number of environment steps: 1636505
# Number of training steps: 25399
# Training speed: 3.0/s
# Loss: 0.6329
#
# Buffer size: 1638905
# Buffer update speed: 240.0/s
# Number of environment steps: 1638905
# Number of training steps: 25430
# Training speed: 3.1/s
# Loss: 0.7757
#
# Buffer size: 1639735
# Buffer update speed: 83.0/s
# Number of environment steps: 1639735
# Average episode return: 4180.0000
# Number of training steps: 25458
# Training speed: 2.8/s
# Loss: 0.7934
#
# Buffer size: 1642135
# Buffer update speed: 240.0/s
# Number of environment steps: 1642135
# Number of training steps: 25476
# Training speed: 1.8/s
# Loss: 0.6836
#
# Buffer size: 1642935
# Buffer update speed: 80.0/s
# Number of environment steps: 1642935
# Number of training steps: 25500
# Training speed: 2.4/s
# Loss: 0.6664
#
# Buffer size: 1645735
# Buffer update speed: 280.0/s
# Number of environment steps: 1645735
# Number of training steps: 25524
# Training speed: 2.4/s
# Loss: 0.7516
#
# Buffer size: 1646535
# Buffer update speed: 80.0/s
# Number of environment steps: 1646535
# Number of training steps: 25556
# Training speed: 3.2/s
# Loss: 0.7886
#
# Buffer size: 1648935
# Buffer update speed: 240.0/s
# Number of environment steps: 1648935
# Number of training steps: 25582
# Training speed: 2.6/s
# Loss: 0.7745
#
# Buffer size: 1649735
# Buffer update speed: 80.0/s
# Number of environment steps: 1649735
# Number of training steps: 25603
# Loss: 0.7059Training speed: 2.1/s
#
#
# Buffer size: 1651735
# Buffer update speed: 200.0/s
# Number of environment steps: 1651735
# Number of training steps: 25628
# Training speed: 2.5/s
# Loss: 0.5738
#
# Buffer size: 1652935
# Buffer update speed: 120.0/s
# Number of environment steps: 1652935
# Number of training steps: 25654
# Training speed: 2.6/s
# Loss: 0.5641
#
# Buffer size: 1655335
# Buffer update speed: 240.0/s
# Number of environment steps: 1655335
# Number of training steps: 25680
# Training speed: 2.6/s
# Loss: 0.7291
#
# Buffer size: 1657335
# Buffer update speed: 200.0/s
# Number of environment steps: 1657335
# Number of training steps: 25708
# Training speed: 2.8/s
# Loss: 0.7673
#
# Buffer size: 1658135
# Buffer update speed: 80.0/s
# Number of environment steps: 1658135
# Number of training steps: 25742
# Training speed: 3.4/s
# Loss: 0.7737
#
# Buffer size: 1660535
# Buffer update speed: 240.0/s
# Number of environment steps: 1660535
# Number of training steps: 25767
# Training speed: 2.5/s
# Loss: 0.8179
#
# Buffer size: 1661335
# Buffer update speed: 80.0/s
# Number of environment steps: 1661335
# Number of training steps: 25793
# Training speed: 2.6/s
# Loss: 0.7147
#
# Buffer size: 1662954
# Buffer update speed: 161.9/s
#
# Number of environment steps: 1662954Average episode return: 1700.0000
# Number of training steps: 25819
# Training speed: 2.6/s
# Loss: 0.6465
#
# Buffer size: 1664691
# Buffer update speed: 173.7/s
# Number of environment steps: 1664691
# Average episode return: 1040.0000
# Number of training steps: 25837
# Training speed: 1.8/s
# Loss: 0.7758
#
# Buffer size: 1666308
# Buffer update speed: 161.7/s
# Number of environment steps: 1666308
# Average episode return: 1540.0000
# Number of training steps: 25864
# Training speed: 2.7/s
# Loss: 0.6937
#
# Buffer size: 1668308
# Buffer update speed: 200.0/s
# Number of environment steps: 1668308
# Number of training steps: 25882
# Training speed: 1.8/s
# Loss: 0.7882
#
# Buffer size: 1669508
# Buffer update speed: 120.0/s
# Number of environment steps: 1669508
# Number of training steps: 25902
# Training speed: 2.1/s
# Loss: 0.6185
#
# Buffer size: 1671508
# Buffer update speed: 200.0/s
# Number of environment steps: 1671508
# Number of training steps: 25923
# Training speed: 2.0/s
# Loss: 0.6269
#
# Buffer size: 1672708
# Buffer update speed: 120.0/s
# Number of environment steps: 1672708
# Number of training steps: 25954
# Training speed: 3.1/s
# Loss: 0.7954
#
# Buffer size: 1674308
# Buffer update speed: 160.0/s
# Number of environment steps: 1674308
# Number of training steps: 25983
# Training speed: 2.9/s
# Loss: 0.6653
#
# Buffer size: 1675908
# Buffer update speed: 160.0/s
# Number of environment steps: 1675908
# Number of training steps: 26013
# Training speed: 3.0/s
# Loss: 0.7813
#
# Buffer size: 1677656
# Buffer update speed: 174.8/s
# Number of environment steps: 1677656
# Average episode return: 2340.0000
# Number of training steps: 26035
# Training speed: 2.2/s
# Loss: 0.8170
#
# Buffer size: 1679256
# Buffer update speed: 160.0/s
# Number of environment steps: 1679256
# Number of training steps: 26058
# Training speed: 2.3/s
# Loss: 0.7201
#
# Buffer size: 1680856
# Buffer update speed: 160.0/s
# Number of environment steps: 1680856
# Number of training steps: 26087
# Training speed: 2.9/s
# Loss: 0.6393
#
# Buffer size: 1682856
# Buffer update speed: 200.0/s
# Number of environment steps: 1682856
# Number of training steps: 26108
# Training speed: 2.1/s
# Loss: 0.6876
#
# Buffer size: 1684056
# Buffer update speed: 120.0/s
# Number of environment steps: 1684056
# Number of training steps: 26134
# Training speed: 2.6/s
# Loss: 0.6853
#
# Buffer size: 1685256
# Buffer update speed: 120.0/s
# Number of environment steps: 1685256
# Number of training steps: 26149
# Training speed: 1.5/s
# Loss: 0.7777
#
# Buffer size: 1687256
# Buffer update speed: 200.0/s
# Number of environment steps: 1687256
# Number of training steps: 26169
# Training speed: 2.0/s
# Loss: 0.5799
#
# Buffer size: 1688456
# Buffer update speed: 120.0/s
# Number of environment steps: 1688456
# Number of training steps: 26192
# Training speed: 2.3/s
# Loss: 0.6304
#
# Buffer size: 1690676
# Buffer update speed: 222.0/s
# Number of environment steps: 1690676
# Average episode return: 3350.0000
# Number of training steps: 26217
# Training speed: 2.5/s
# Loss: 0.6836
#
# Buffer size: 1692079
# Buffer update speed: 140.3/s
# Number of environment steps: 1692079
# Average episode return: 80.0000
# Number of training steps: 26240
# Training speed: 2.3/s
# Loss: 0.5784
#
# Buffer size: 1693679
# Buffer update speed: 160.0/s
# Number of environment steps: 1693679
# Number of training steps: 26274
# Training speed: 3.4/s
# Loss: 0.5949
#
# Buffer size: 1695185
# Buffer update speed: 150.6/s
# Number of environment steps: 1695185
# Average episode return: 2200.0000
# Number of training steps: 26300
# Training speed: 2.6/s
# Loss: 0.7139
#
# Buffer size: 1696385
# Buffer update speed: 120.0/s
# Number of environment steps: 1696385
# Number of training steps: 26326
# Training speed: 2.6/s
# Loss: 0.6903
#
# Buffer size: 1698385
# Buffer update speed: 200.0/s
# Number of environment steps: 1698385
# Number of training steps: 26346
# Training speed: 2.0/s
# Loss: 0.5288
#
# Buffer size: 1699585
# Buffer update speed: 120.0/s
# Number of environment steps: 1699585
# Number of training steps: 26374
# Training speed: 2.8/s
# Loss: 0.7002
#
# Buffer size: 1701585
# Buffer update speed: 200.0/s
# Number of environment steps: 1701585
# Number of training steps: 26395
# Training speed: 2.1/s
# Loss: 0.5859
#
# Buffer size: 1702785
# Buffer update speed: 120.0/s
# Number of environment steps: 1702785
# Number of training steps: 26422
# Training speed: 2.7/s
# Loss: 0.5148
#
# Buffer size: 1704785
# Buffer update speed: 200.0/s
# Number of environment steps: 1704785
# Number of training steps: 26445
# Training speed: 2.3/s
# Loss: 0.6386
#
# Buffer size: 1705985
# Buffer update speed: 120.0/s
# Number of environment steps: 1705985
# Number of training steps: 26450
# Training speed: 0.5/s
# Loss: 0.8154
#
# Buffer size: 1706785
# Buffer update speed: 80.0/s
# Number of environment steps: 1706785
# Number of training steps: 26451
# Training speed: 0.1/s
# Loss: 0.4297
#
# Buffer size: 1708785
# Buffer update speed: 200.0/s
# Number of environment steps: 1708785
# Number of training steps: 26453
# Training speed: 0.2/s
# Loss: 0.4969
#
# Buffer size: 1709585
# Buffer update speed: 80.0/s
# Number of environment steps: 1709585
# Number of training steps: 26454
# Training speed: 0.1/s
# Loss: 0.6143
#
# Buffer size: 1711585
# Buffer update speed: 200.0/s
# Number of environment steps: 1711585
# Number of training steps: 26457
# Training speed: 0.3/s
# Loss: 0.6576
#
# Buffer size: 1712785
# Buffer update speed: 120.0/s
# Number of environment steps: 1712785
# Number of training steps: 26458
# Training speed: 0.1/s
# Loss: 0.2834
#
# Buffer size: 1714385
# Buffer update speed: 160.0/s
# Number of environment steps: 1714385
# Number of training steps: 26462
# Training speed: 0.4/s
# Loss: 0.6559
#
# Buffer size: 1715985
# Buffer update speed: 160.0/s
# Number of environment steps: 1715985
# Number of training steps: 26463
# Training speed: 0.1/s
# Loss: 0.7363
#
# Buffer size: 1717605
# Buffer update speed: 162.0/s
# Number of environment steps: 1717605
# Average episode return: 3460.0000
# Number of training steps: 26464
# Training speed: 0.1/s
# Loss: 0.7158
#
# Buffer size: 1719205
# Buffer update speed: 160.0/s
# Number of environment steps: 1719205
# Number of training steps: 26465
# Training speed: 0.1/s
# Loss: 0.4672
#
# Buffer size: 1719605
# Buffer update speed: 40.0/s
# Number of environment steps: 1719605
# Number of training steps: 26466
# Training speed: 0.1/s
# Loss: 0.4332
#
# Buffer size: 1720805
# Buffer update speed: 160.0/s
# Number of environment steps: 1721205
# Number of training steps: 26466
# Training speed: 0.0/s
#
# Buffer size: 1722405
# Buffer update speed: 120.0/s
# Number of environment steps: 1722405
# Number of training steps: 26466
# Training speed: 0.0/s
#
# Buffer size: 1724005
# Buffer update speed: 160.0/s
# Number of environment steps: 1724005
# Number of training steps: 26467
# Training speed: 0.1/s
# Loss: 0.5580
#
# Buffer size: 1725605
# Buffer update speed: 160.0/s
# Number of environment steps: 1725605
# Number of training steps: 26467
# Training speed: 0.0/s
#
# Buffer size: 1725605
# Buffer update speed: 0.0/s
# Number of environment steps: 1725605
# Number of training steps: 26468
# Training speed: 0.1/s
# Loss: 0.8326
#
# Buffer size: 1728405
# Buffer update speed: 280.0/s
# Number of environment steps: 1728405
# Number of training steps: 26468
# Training speed: 0.0/s
#
# Buffer size: 1728805
# Buffer update speed: 40.0/s
# Number of environment steps: 1728805
# Number of training steps: 26468
# Training speed: 0.0/s
#
# Buffer size: 1728805
# Buffer update speed: 0.0/s
# Number of environment steps: 1728805
# Number of training steps: 26468
# Training speed: 0.0/s
#
# Buffer size: 1728805
# Buffer update speed: 0.0/s
# Number of environment steps: 1728805
# Number of training steps: 26469
# Training speed: 0.1/s
# Loss: 0.1258
#
# Buffer size: 1728805
# Buffer update speed: 0.0/s
# Number of environment steps: 1728805
# Number of training steps: 26469
# Training speed: 0.0/s
#
# Buffer size: 1728805
# Buffer update speed: 0.0/s
# Number of environment steps: 1728805
# Number of training steps: 26469
# Training speed: 0.0/s
#
# Buffer size: 1728805
# Buffer update speed: 0.0/s
# Number of environment steps: 1728805
# Number of training steps: 26470
# Training speed: 0.1/s
# Loss: 0.6783
#
# Buffer size: 1730005
# Buffer update speed: 160.0/s
# Number of environment steps: 1730405
# Number of training steps: 26470
# Training speed: 0.0/s
#
# Buffer size: 1732040
# Buffer update speed: 163.5/s
# Number of environment steps: 1732040
# Average episode return: 1580.0000
# Number of training steps: 26470
# Training speed: 0.0/s
#
# Buffer size: 1732040
# Buffer update speed: 0.0/s
# Number of environment steps: 1732040
# Number of training steps: 26470
# Training speed: 0.0/s
#
# Buffer size: 1733640
# Buffer update speed: 160.0/s
# Number of environment steps: 1733640
# Number of training steps: 26470
# Training speed: 0.0/s
#
# Buffer size: 1733640
# Buffer update speed: 0.0/s
# Number of environment steps: 1733640
# Number of training steps: 26470
# Training speed: 0.0/s
#
# Buffer size: 1733640
# Buffer update speed: 0.0/s
# Number of environment steps: 1733640
# Number of training steps: 26471
# Training speed: 0.1/s
# Loss: 0.7203
#
# Buffer size: 1733640
# Buffer update speed: 0.0/s
# Number of environment steps: 1733640
# Number of training steps: 26471
# Training speed: 0.0/s

# %% [markdown]
# ### 3h training

# %% [markdown]
# # Test model

# %%
checkpoint = torch.load('models/r2d2/Solaris-v5/Solaris-v518000.pth', map_location='cpu')
checkpoint
# Out:
# (OrderedDict([('feature.0.weight',
#                tensor([[[[-0.0028,  0.0660, -0.1031,  ...,  0.0311, -0.0046,  0.0987],
#                          [-0.0178,  0.0267, -0.0409,  ..., -0.0775, -0.0417,  0.0155],
#                          [ 0.0430,  0.0688, -0.0878,  ...,  0.1134, -0.0088,  0.1083],
#                          ...,
#                          [ 0.0062, -0.0743,  0.0240,  ..., -0.0593,  0.0880,  0.0893],
#                          [-0.0511, -0.0103,  0.0761,  ...,  0.0207,  0.0948, -0.0623],
#                          [ 0.0266, -0.0955, -0.0855,  ...,  0.0535, -0.0683,  0.0439]]],
#
#
#                        [[[ 0.0813, -0.0041,  0.0174,  ...,  0.1319, -0.0872, -0.0389],
#                          [ 0.0664,  0.1208,  0.1280,  ..., -0.0942,  0.0255, -0.0665],
#                          [-0.1036,  0.1224,  0.1097,  ..., -0.0139, -0.0131, -0.0523],
#                          0.0979, -0.0340,  0.0513,  0.0386, -0.0621, -0.0437, -0.0713,  0.0366,
#                          0.0843, -0.0140,  0.0244, -0.0067,  0.0257, -0.0457,  0.0381, -0.0359,
#                         -0.0162,  0.0325, -0.0374,  0.0802,  0.0125, -0.0083,  0.0299, -0.0160,
#                          0.0105,  0.0142,  0.0176,  0.0777,  0.0317, -0.0345, -0.0026,  0.0427,
#                          0.0163,  0.0216,  0.0120,  0.0685, -0.0329,  0.0980,  0.0849,  0.0971,
#                          0.0785,  0.0113,  0.0393, -0.0184, -0.0179,  0.0168, -0.0310, -0.0158,
#                         -0.0529,  0.0393,  0.0682,  0.0927, -0.0210, -0.0617, -0.0213, -0.0309,
#                         -0.0460, -0.0485,  0.0962, -0.0085,  0.0239,  0.0595, -0.0514, -0.0368,
#                          0.0756, -0.0356, -0.0217, -0.0274,  0.0935,  0.0966,  0.0015,  0.1105,
#                         -0.0544,  0.0288, -0.0459,  0.0069,  0.0643,  0.0645,  0.0435,  0.0138]])),
#               ('value.2.bias', tensor([0.0612]))]),
#  18000,
#  1176721,
#  117.15812560717265)

# %%
env = create_env(game_name, render=True)
n_observations = env.observation_space.shape
n_actions = env.action_space.n
model = Network(n_observations, n_actions)
model.load_state_dict(checkpoint[0])
obs, _ = env.reset()
state = AgentState(torch.from_numpy(obs).unsqueeze(0), n_actions)
done = False
total_reward = 0
while not done:
    with torch.no_grad():
        q_value, hidden = model(state)
        q_value[:, 0] = -np.inf  # no-op
    action = torch.argmax(q_value, 1).item()
    obs, reward, terminated, truncated, _, = env.step(action)
    done = terminated or truncated
    total_reward += reward
    state.update(obs, action, reward, hidden)
env.close()
print(total_reward)
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 15
#      13     q_value[:, 0] = -np.inf  # no-op
#      14 action = torch.argmax(q_value, 1).item()
# ---> 15 obs, reward, terminated, truncated, _, = env.step(action)
#      16 done = terminated or truncated
#      17 total_reward += reward
#
# Cell In[3], line 28, in NoopResetEnv.step(self, action)
#      27 def step(self, action):
# ---> 28     return self.env.step(action)
#
# File ~/.miniforge3/envs/studia/lib/python3.10/site-packages/gymnasium/core.py:522, in ObservationWrapper.step(self, action)
#     518 def step(
#     519     self, action: ActType
#     520 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     521     """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
# --> 522     observation, reward, terminated, truncated, info = self.env.step(action)
#     523     return self.observation(observation), reward, terminated, truncated, info
#
# File ~/.miniforge3/envs/studia/lib/python3.10/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/.miniforge3/envs/studia/lib/python3.10/site-packages/gymnasium/wrappers/env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File ~/.miniforge3/envs/studia/lib/python3.10/site-packages/shimmy/atari_env.py:294, in AtariEnv.step(self, action_ind)
#     292 reward = 0.0
#     293 for _ in range(frameskip):
# --> 294     reward += self.ale.act(action)
#     295 is_terminal = self.ale.game_over(with_truncation=False)
#     296 is_truncated = self.ale.game_truncated()
#
# KeyboardInterrupt:
