# %%
import math
import os
import random
import threading
import time
from copy import deepcopy
from dataclasses import dataclass, field
from typing import Tuple

import gymnasium as gym
import numpy as np
import torch
import torch.multiprocessing as mp
from torch import nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence, pad_sequence
import cv2
# from tensorboardX import SummaryWriter
# from torch.utils.tensorboard import SummaryWriter

# %%
game_name = 'DonkeyKong-v5'

lr = 1e-4 
eps = 1e-3 
grad_norm = 40 
batch_size = 64 
learning_starts = 50000 
save_interval = 500 
target_net_update_interval = 2000 
gamma = 0.997 
prio_exponent = 0.9 
importance_sampling_exponent = 0.6 

training_steps = 150000 
buffer_capacity = 2000000 
max_episode_steps = 27000 
actor_update_interval = 400 
block_length = 400 

num_actors = 8 
base_eps = 0.4 
alpha = 7 
log_interval = 10 

# sequence setting
burn_in_steps = 40   
learning_steps = 40   
forward_steps = 5   
seq_len = burn_in_steps + learning_steps + forward_steps   

# network setting
hidden_dim = 512   

render = False   
save_plot = True   
test_epsilon = 0.001

# %%
class NoopResetEnv(gym.Wrapper):
    def __init__(self, env, noop_max=30):
        """start the game with no-op actions to provide random starting positions
        No-op is assumed to be action 0.
        """
        gym.Wrapper.__init__(self, env)
        self.noop_max = noop_max
        self.override_num_noops = None
        self.noop_action = 0
        assert env.unwrapped.get_action_meanings()[0] == 'NOOP'

    def reset(self, **kwargs):
        """ Do no-op action for a number of steps in [1, noop_max]."""
        self.env.reset(**kwargs)
        if self.override_num_noops is not None:
            noops = self.override_num_noops
        else:
            noops = np.random.randint(1, self.noop_max + 1) #pylint: disable=E1101
        assert noops > 0
        obs = None
        for _ in range(noops):
            obs, _, terminated, truncated, _ = self.env.step(self.noop_action)
            if terminated or truncated:
                obs = self.env.reset(**kwargs)
        return obs, {}

    def step(self, action):
        return self.env.step(action)



class WarpFrame(gym.ObservationWrapper):
    def __init__(self, env, width=84, height=84):
        """
        Warp frames to 84x84 as done in the Nature paper and later work.
        """
        super().__init__(env)
        self._width = width
        self._height = height

        self.observation_space = gym.spaces.Box(
            low=0,
            high=255,
            shape=(1, self._height, self._width),
            dtype=np.uint8,
        )

    def observation(self, obs):

        obs = cv2.resize(
            obs, (self._width, self._height), interpolation=cv2.INTER_AREA
        )

        obs = np.expand_dims(obs, 0)

        return obs


def create_env(env_name=game_name, noop_start=True, render=False):

    env = gym.make(f'ALE/{env_name}', obs_type='grayscale', frameskip=4, repeat_action_probability=0, full_action_space=False, render_mode='human' if render else 'rgb_array')

    env = WarpFrame(env)
    if noop_start:
        env = NoopResetEnv(env)

    return env

# %%
class PriorityTree:
    def __init__(self, capacity, prio_exponent, is_exponent):
        self.num_layers = 1
        while capacity > 2**(self.num_layers - 1):
            self.num_layers += 1
        
        self.ptree = np.zeros(2**self.num_layers - 1, dtype=np.float64)
        
        self.prio_exponent = prio_exponent
        self.is_exponent = is_exponent
    
    def update(self, idxes: np.ndarray, td_error: np.ndarray) -> None:
        priorities = td_error ** self.prio_exponent
        
        idxes = idxes + 2**(self.num_layers - 1) - 1
        self.ptree[idxes] = priorities
        
        for _ in range(self.num_layers - 1):
            idxes = (idxes - 1) // 2
            idxes = np.unique(idxes)
            self.ptree[idxes] = self.ptree[2 * idxes + 1] + self.ptree[2 * idxes + 2]
    
    def sample(self, num_samples: int) -> tuple[np.ndarray, np.ndarray]:
        p_sum = self.ptree[0]
        interval = p_sum / num_samples
        
        prefixsums = np.arange(0, p_sum, interval, dtype=np.float64) + np.random.uniform(0, interval, num_samples)
        
        idxes = np.zeros(num_samples, dtype=np.int64)
        for _ in range(self.num_layers-1):
            nodes = self.ptree[2 * idxes + 1]
            idxes = np.where(prefixsums < nodes, 2 * idxes + 1, 2 * idxes + 2)
            prefixsums = np.where(idxes%2 == 0, prefixsums - self.ptree[idxes-1], prefixsums)
        
        priorities = self.ptree[idxes]
        min_p = np.min(priorities)
        is_weigths = np.power(priorities/min_p, -self.is_exponent)
        
        idxes -= 2**(self.num_layers - 1) - 1
        
        return idxes, is_weigths

# %%
@dataclass
class Block:
    obs: np.array
    last_action: np.array
    last_reward: np.array
    action: np.array
    n_step_reward: np.array
    gamma: np.array
    hidden: np.array
    num_sequences: int
    burn_in_steps: np.array
    learning_steps: np.array
    forward_steps: np.array

# %%
class ReplayBuffer:
    def __init__(self, sample_queue_list, batch_queue, priority_queue, alpha=prio_exponent, beta=importance_sampling_exponent):
        self.buffer_capacity = buffer_capacity
        self.sequence_len = learning_steps
        self.num_sequences = buffer_capacity // self.sequence_len
        self.block_len = block_length
        self.num_blocks = self.buffer_capacity // self.block_len
        self.seq_pre_block = self.block_len // self.sequence_len
        
        self.block_ptr = 0
        
        self.priority_tree = PriorityTree(self.num_sequences, alpha, beta)
        
        self.batch_size = batch_size
        
        self.env_steps = 0
        
        self.num_episodes = 0
        self.episode_reward = 0
        
        self.training_steps = 0
        self.last_training_steps = 0
        self.sum_loss = 0
        
        self.lock = threading.Lock()
        
        self.size = 0
        self.last_size = 0
        
        self.buffer = [None] * self.num_blocks
        
        self.sample_queue_list = sample_queue_list
        self.batch_queue = batch_queue
        self.priority_queue = priority_queue
        
        
    def __len__(self):
        return self.size
    
    def run(self):
        background_thread = threading.Thread(target=self.add_data, daemon=True)
        background_thread.start()
        
        background_thread = threading.Thread(target=self.prepare_data, daemon=True)
        background_thread.start()
        
        background_thread = threading.Thread(target=self.update_data, daemon=True)
        background_thread.start()

        writer_thread = threading.Thread(target=self.write_stats, daemon=True)
        writer_thread.start()
        
        while True:
            print(f'Buffer size: {self.size}')
            print(f'Buffer update speed: {(self.size - self.last_size) / log_interval}/s')
            self.last_size = self.size
            print(f'Number of environment steps: {self.env_steps}')
            if self.num_episodes != 0:
                print(f'Average episode return: {self.episode_reward / self.num_episodes:.4f}')
                self.episode_reward = 0
                self.num_episodes = 0
            print(f'Number of training steps: {self.training_steps}')
            print(f'Training speed: {(self.training_steps - self.last_training_steps) / log_interval}/s')
            if self.training_steps != self.last_training_steps:
                print(f'Loss: {self.sum_loss/(self.training_steps-self.last_training_steps):.4f}')
                self.last_training_steps = self.training_steps
                self.sum_loss = 0
            self.last_env_steps = self.env_steps
            print()
            
            if self.training_steps == training_steps:
                break
            else:
                time.sleep(log_interval)
    
    def write_stats(self):
        # writer = SummaryWriter(f'logs/r2d2__{game_name}')
        os.makedirs(f'logs/r2d2/{game_name}', exist_ok=True)
        while True:
            # writer.add_scalar('buffer/size', self.size, self.env_steps)
            with open(f'logs/r2d2/{game_name}/buffer_size.txt', 'a') as f:
                f.write(f'{self.size} {self.env_steps}\n')
            
            # writer.add_scalar('buffer/update_speed', (self.size - self.last_size) / log_interval, self.env_steps)
            with open(f'logs/r2d2/{game_name}/buffer_update_speed.txt', 'a') as f:
                f.write(f'{(self.size - self.last_size) / log_interval} {self.env_steps}\n')
            
            # writer.add_scalar('environment/steps', self.env_steps, self.env_steps)
            with open(f'logs/r2d2/{game_name}/environment_steps.txt', 'a') as f:
                f.write(f'{self.env_steps}\n')

            if self.num_episodes != 0:
                # writer.add_scalar('episode/return', self.episode_reward / self.num_episodes, self.env_steps)
                with open(f'logs/r2d2/{game_name}/episode_return.txt', 'a') as f:
                    f.write(f'{self.episode_reward / self.num_episodes} {self.env_steps}\n')

            # writer.add_scalar('training/steps', self.training_steps, self.env_steps)
            with open(f'logs/r2d2/{game_name}/training_steps.txt', 'a') as f:
                f.write(f'{self.training_steps} {self.env_steps}\n')

            # writer.add_scalar('training/speed', (self.training_steps - self.last_training_steps) / log_interval, self.env_steps)
            with open(f'logs/r2d2/{game_name}/training_speed.txt', 'a') as f:
                f.write(f'{(self.training_steps - self.last_training_steps) / log_interval} {self.env_steps}\n')

            if self.training_steps != self.last_training_steps:
                # writer.add_scalar('training/loss', self.sum_loss/(self.training_steps-self.last_training_steps), self.env_steps)
                with open(f'logs/r2d2/{game_name}/training_loss.txt', 'a') as f:
                    f.write(f'{self.sum_loss/(self.training_steps-self.last_training_steps)} {self.env_steps}\n')

            time.sleep(log_interval)

    def prepare_data(self):
        while self.size < learning_starts:
            time.sleep(1)
        
        while True:
            if not self.batch_queue.full():
                data = self.sample_batch()
                self.batch_queue.put(data)
            else:
                time.sleep(0.1)
    
    def add_data(self):
        while True:
            for sample_queue in self.sample_queue_list:
                if not sample_queue.empty():
                    data = sample_queue.get_nowait()
                    self.add(*data)
    
    def update_data(self):
        while True:
            if not self.priority_queue.empty():
                data = self.priority_queue.get_nowait()
                self.update_priorities(*data)
            else:
                time.sleep(0.1)
    
    def add(self, block: Block, priority: np.array, episode_reward: float):
        with self.lock:
            idxes = np.arange(self.block_ptr * self.seq_pre_block, (self.block_ptr + 1) * self.seq_pre_block, dtype=np.int64)
            
            self.priority_tree.update(idxes, priority)
            
            if self.buffer[self.block_ptr] is not None:
                self.size -= np.sum(self.buffer[self.block_ptr].learning_steps).item()
            
            self.size += np.sum(block.learning_steps).item()
            
            self.buffer[self.block_ptr] = block
            
            self.env_steps += np.sum(block.learning_steps, dtype=np.int32)
            
            self.block_ptr = (self.block_ptr + 1) % self.num_blocks
            
            if episode_reward:
                self.episode_reward += episode_reward
                self.num_episodes += 1
    
    def sample_batch(self):
        batch_obs, batch_last_action, batch_last_reward, batch_hidden, batch_action, batch_reward, batch_gamma = [], [], [], [], [], [], []
        burn_in_steps, learning_steps, forward_steps = [], [], []

        with self.lock:

            idxes, is_weights = self.priority_tree.sample(self.batch_size)

            block_idxes = idxes // self.seq_pre_block
            sequence_idxes = idxes % self.seq_pre_block


            for block_idx, sequence_idx  in zip(block_idxes, sequence_idxes):

                block = self.buffer[block_idx]

                assert sequence_idx < block.num_sequences, 'index is {} but size is {}'.format(sequence_idx, self.seq_pre_block_buf[block_idx])

                burn_in_step = block.burn_in_steps[sequence_idx]
                learning_step = block.learning_steps[sequence_idx]
                forward_step = block.forward_steps[sequence_idx]
                
                start_idx = block.burn_in_steps[0] + np.sum(block.learning_steps[:sequence_idx])

                obs = block.obs[start_idx-burn_in_step:start_idx+learning_step+forward_step]
                last_action = block.last_action[start_idx-burn_in_step:start_idx+learning_step+forward_step]
                last_reward = block.last_reward[start_idx-burn_in_step:start_idx+learning_step+forward_step]
                obs, last_action, last_reward = torch.from_numpy(obs), torch.from_numpy(last_action), torch.from_numpy(last_reward)
                
                start_idx = np.sum(block.learning_steps[:sequence_idx])
                end_idx = start_idx + block.learning_steps[sequence_idx]
                action = block.action[start_idx:end_idx]
                reward = block.n_step_reward[start_idx:end_idx]
                gamma = block.gamma[start_idx:end_idx]
                hidden = block.hidden[sequence_idx]
                
                batch_obs.append(obs)
                batch_last_action.append(last_action)
                batch_last_reward.append(last_reward)
                batch_action.append(action)
                batch_reward.append(reward)
                batch_gamma.append(gamma)
                batch_hidden.append(hidden)

                burn_in_steps.append(burn_in_step)
                learning_steps.append(learning_step)
                forward_steps.append(forward_step)

            batch_obs = pad_sequence(batch_obs, batch_first=True)
            batch_last_action = pad_sequence(batch_last_action, batch_first=True)
            batch_last_reward = pad_sequence(batch_last_reward, batch_first=True)

            is_weights = np.repeat(is_weights, learning_steps)


            data = (
                batch_obs,
                batch_last_action,
                batch_last_reward,
                torch.from_numpy(np.stack(batch_hidden)).transpose(0, 1),

                torch.from_numpy(np.concatenate(batch_action)).unsqueeze(1),
                torch.from_numpy(np.concatenate(batch_reward)),
                torch.from_numpy(np.concatenate(batch_gamma)),

                torch.ByteTensor(burn_in_steps),
                torch.ByteTensor(learning_steps),
                torch.ByteTensor(forward_steps),

                idxes,
                torch.from_numpy(is_weights.astype(np.float32)),
                self.block_ptr,

                self.env_steps
            )

        return data

    def update_priorities(self, idxes: np.ndarray, td_errors: np.ndarray, old_ptr: int, loss: float):
        """Update priorities of sampled transitions"""
        with self.lock:

            # discard the idxes that already been replaced by new data in replay buffer during training
            if self.block_ptr > old_ptr:
                # range from [old_ptr, self.seq_ptr)
                mask = (idxes < old_ptr*self.seq_pre_block) | (idxes >= self.block_ptr*self.seq_pre_block)
                idxes = idxes[mask]
                td_errors = td_errors[mask]
            elif self.block_ptr < old_ptr:
                # range from [0, self.seq_ptr) & [old_ptr, self,capacity)
                mask = (idxes < old_ptr*self.seq_pre_block) & (idxes >= self.block_ptr*self.seq_pre_block)
                idxes = idxes[mask]
                td_errors = td_errors[mask]

            self.priority_tree.update(idxes, td_errors)

        self.training_steps += 1
        self.sum_loss += loss

# %%
@dataclass
class AgentState:
    obs: torch.tensor
    action_dim: int
    last_action: torch.tensor = field(init=False)
    last_reward: torch.tensor = torch.zeros((1, 1), dtype=torch.float32)
    hidden_state: tuple[torch.tensor, torch.tensor] | None = None

    def __post_init__(self):
        self.last_action = torch.zeros((1, self.action_dim), dtype=torch.float32)

    def update(self, obs, last_action, last_reward, hidden):
        self.obs = torch.from_numpy(obs).unsqueeze(0)
        self.last_action = torch.tensor([[1 if i == last_action else 0 for i in range(self.action_dim)]],
                                        dtype=torch.float32)
        self.last_reward = torch.tensor([[last_reward]], dtype=torch.float32)
        self.hidden_state = hidden

# %%
class Network(nn.Module):
    def __init__(self, observation_dim, action_dim, hidden_dim=hidden_dim):
        super().__init__()

        self.action_dim = action_dim
        self.obs_shape = observation_dim
        self.max_forward_steps = 5

        self.feature = nn.Sequential(
            nn.Conv2d(1, 32, 8, 4),
            nn.ReLU(True),
            nn.Conv2d(32, 64, 4, 2),
            nn.ReLU(True),
            nn.Conv2d(64, 64, 3, 1),
            nn.ReLU(True),
            nn.Flatten(),
            nn.Linear(3136, 512),
            nn.ReLU(True),
        )

        self.recurrent = nn.LSTM(512 + action_dim + 1, hidden_dim, batch_first=True)

        self.advantage = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(True),
            nn.Linear(hidden_dim, action_dim)
        )

        self.value = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(True),
            nn.Linear(hidden_dim, 1)
        )

    def forward(self, state: AgentState):
        latent = self.feature(state.obs / 255)
        recurrent_input = torch.cat([latent, state.last_action, state.last_reward], dim=1)
        
        _, recurrent_output = self.recurrent(recurrent_input, state.hidden_state)
        
        hidden = recurrent_output[0]
        
        adv = self.advantage(hidden)
        val = self.value(hidden)
        q_value = val + adv - adv.mean(1, keepdim=True)
        
        return q_value, recurrent_output

    def calculate_q_(self, obs, last_action, last_reward, hidden_state, burn_in_steps, learning_steps, forward_steps):
        # obs shape: (batch_size, seq_len, obs_shape)
        batch_size, max_seq_len, *_ = obs.size()

        obs = obs.reshape(-1, *self.obs_shape)
        last_action = last_action.view(-1, self.action_dim)
        last_reward = last_reward.view(-1, 1)
        latent = self.feature(obs)

        seq_len = burn_in_steps + learning_steps + forward_steps

        recurrent_input = torch.cat((latent, last_action, last_reward), dim=1)
        recurrent_input = recurrent_input.view(batch_size, max_seq_len, -1)

        recurrent_input = pack_padded_sequence(recurrent_input, seq_len, batch_first=True, enforce_sorted=False)

        self.recurrent.flatten_parameters()
        recurrent_output, _ = self.recurrent(recurrent_input, hidden_state)

        recurrent_output, _ = pad_packed_sequence(recurrent_output, batch_first=True)

        seq_start_idx = burn_in_steps + self.max_forward_steps
        forward_pad_steps = torch.minimum(self.max_forward_steps - forward_steps, learning_steps)

        hidden = []
        for hidden_seq, start_idx, end_idx, padding_length in zip(recurrent_output, seq_start_idx, seq_len, forward_pad_steps):
            hidden.append(hidden_seq[start_idx:end_idx])
            if padding_length > 0:
                hidden.append(hidden_seq[end_idx-1:end_idx].repeat(padding_length, 1))

        hidden = torch.cat(hidden)

        assert hidden.size(0) == torch.sum(learning_steps)

        adv = self.advantage(hidden)
        val = self.value(hidden)
        q_value = val + adv - adv.mean(1, keepdim=True)

        return q_value

    def calculate_q(self, obs, last_action, last_reward, hidden_state, burn_in_steps, learning_steps):
        # obs shape: (batch_size, seq_len, obs_shape)
        batch_size, max_seq_len, *_ = obs.size()

        obs = obs.reshape(-1, *self.obs_shape)
        last_action = last_action.view(-1, self.action_dim)
        last_reward = last_reward.view(-1, 1)

        latent = self.feature(obs)

        seq_len = burn_in_steps + learning_steps

        recurrent_input = torch.cat((latent, last_action, last_reward), dim=1)
        recurrent_input = recurrent_input.view(batch_size, max_seq_len, -1)
        recurrent_input = pack_padded_sequence(recurrent_input, seq_len, batch_first=True, enforce_sorted=False)

        # self.recurrent.flatten_parameters()
        recurrent_output, _ = self.recurrent(recurrent_input, hidden_state)

        recurrent_output, _ = pad_packed_sequence(recurrent_output, batch_first=True)

        hidden = torch.cat([output[burn_in:burn_in+learning] for output, burn_in, learning in zip(recurrent_output, burn_in_steps, learning_steps)], dim=0)

        adv = self.advantage(hidden)
        val = self.value(hidden)

        q_value = val + adv - adv.mean(1, keepdim=True)

        return q_value

# %%
def calculate_mixed_td_errors(td_error, learning_steps):
    
    start_idx = 0
    mixed_td_errors = np.empty(learning_steps.shape, dtype=td_error.dtype)
    for i, steps in enumerate(learning_steps):
        mixed_td_errors[i] = 0.9*td_error[start_idx:start_idx+steps].max() + 0.1*td_error[start_idx:start_idx+steps].mean()
        start_idx += steps
    
    return mixed_td_errors

class Learner:
    def __init__(self, batch_queue, priority_queue, model, grad_norm: int = grad_norm,
                lr: float = lr, eps:float = eps, game_name: str = game_name,
                target_net_update_interval: int = target_net_update_interval, save_interval: int = save_interval):

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.online_net = deepcopy(model)
        self.online_net.to(self.device)
        self.online_net.train()
        self.target_net = deepcopy(self.online_net)
        self.target_net.eval()
        self.optimizer = torch.optim.Adam(self.online_net.parameters(), lr=lr, eps=eps)
        self.loss_fn = nn.MSELoss(reduction='none')
        self.grad_norm = grad_norm
        self.batch_queue = batch_queue
        self.priority_queue = priority_queue
        self.num_updates = 0
        self.done = False

        self.target_net_update_interval = target_net_update_interval
        self.save_interval = save_interval

        self.batched_data = []

        self.shared_model = model

        self.game_name = game_name

    def store_weights(self):
        self.shared_model.load_state_dict(self.online_net.state_dict())

    def prepare_data(self):

        while True:
            if not self.batch_queue.empty() and len(self.batched_data) < 4:
                data = self.batch_queue.get_nowait()
                self.batched_data.append(data)
            else:
                time.sleep(0.1)

    def run(self):
        background_thread = threading.Thread(target=self.prepare_data, daemon=True)
        background_thread.start()
        time.sleep(2)

        start_time = time.time()
        while self.num_updates < training_steps:
            
            while not self.batched_data:
                time.sleep(1)
            data = self.batched_data.pop(0)

            batch_obs, batch_last_action, batch_last_reward, batch_hidden, batch_action, batch_n_step_reward, batch_n_step_gamma, burn_in_steps, learning_steps, forward_steps, idxes, is_weights, old_ptr, env_steps = data
            batch_obs, batch_last_action, batch_last_reward = batch_obs.to(self.device), batch_last_action.to(self.device), batch_last_reward.to(self.device)
            batch_hidden, batch_action = batch_hidden.to(self.device), batch_action.to(self.device)
            batch_n_step_reward, batch_n_step_gamma = batch_n_step_reward.to(self.device), batch_n_step_gamma.to(self.device)
            is_weights = is_weights.to(self.device)

            batch_obs, batch_last_action = batch_obs.float(), batch_last_action.float()
            batch_action = batch_action.long()
            burn_in_steps, learning_steps, forward_steps = burn_in_steps, learning_steps, forward_steps

            batch_hidden = (batch_hidden[:1], batch_hidden[1:])

            batch_obs = batch_obs / 255

            # double q learning
            with torch.no_grad():
                batch_action_ = self.online_net.calculate_q_(batch_obs, batch_last_action, batch_last_reward, batch_hidden, burn_in_steps, learning_steps, forward_steps).argmax(1).unsqueeze(1)
                batch_q_ = self.target_net.calculate_q_(batch_obs, batch_last_action, batch_last_reward, batch_hidden, burn_in_steps, learning_steps, forward_steps).gather(1, batch_action_).squeeze(1)
            
            target_q = self.value_rescale(batch_n_step_reward + batch_n_step_gamma * self.inverse_value_rescale(batch_q_))
            # target_q = batch_n_step_reward + batch_n_step_gamma * batch_q_

            batch_q = self.online_net.calculate_q(batch_obs, batch_last_action, batch_last_reward, batch_hidden, burn_in_steps, learning_steps).gather(1, batch_action).squeeze(1)
            
            loss = (is_weights * self.loss_fn(batch_q, target_q)).mean()

            
            td_errors = (target_q-batch_q).detach().clone().squeeze().abs().cpu().float().numpy()

            priorities = calculate_mixed_td_errors(td_errors, learning_steps.numpy())

            # automatic mixed precision training
            self.optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(self.online_net.parameters(), self.grad_norm)
            self.optimizer.step()

            self.num_updates += 1

            self.priority_queue.put((idxes, priorities, old_ptr, loss.item()))

            # store new weights in shared memory
            if self.num_updates % 4 == 0:
                self.store_weights()

            # update target net
            if self.num_updates % self.target_net_update_interval == 0:
                self.target_net.load_state_dict(self.online_net.state_dict())
            
            # save model 
            if self.num_updates % self.save_interval == 0:
                os.makedirs(f'models/r2d2/{game_name}', exist_ok=True)
                torch.save((self.online_net.state_dict(), self.num_updates, env_steps, (time.time()-start_time)/60), os.path.join(f'models/r2d2/{game_name}', '{}.pth'.format(self.num_updates)))

    @staticmethod
    def value_rescale(value, eps=1e-3):
        return value.sign()*((value.abs()+1).sqrt()-1) + eps*value

    @staticmethod
    def inverse_value_rescale(value, eps=1e-3):
        temp = ((1 + 4*eps*(value.abs()+1+eps)).sqrt() - 1) / (2*eps)
        return value.sign() * (temp.square() - 1)

# %%
class LocalBuffer:
    def __init__(self, action_dim: int, forward_steps: int = forward_steps,
                burn_in_steps = burn_in_steps, learning_steps: int = learning_steps, 
                gamma: float = gamma, hidden_dim: int = hidden_dim, block_length: int = block_length):
        
        self.action_dim = action_dim
        self.gamma = gamma
        self.hidden_dim = hidden_dim
        self.forward_steps = forward_steps
        self.learning_steps = learning_steps
        self.burn_in_steps = burn_in_steps
        self.block_length = block_length
        self.curr_burn_in_steps = 0
        
    def __len__(self):
        return self.size
    
    def reset(self, init_obs: np.ndarray):
        self.obs_buffer = [init_obs]
        self.last_action_buffer = [np.array([1 if i == 0 else 0 for i in range(self.action_dim)], dtype=bool)]
        self.last_reward_buffer = [0]
        self.hidden_buffer = [np.zeros((2, self.hidden_dim), dtype=np.float32)]
        self.action_buffer = []
        self.reward_buffer = []
        self.qval_buffer = []
        self.curr_burn_in_steps = 0
        self.size = 0
        self.sum_reward = 0
        self.done = False

    def add(self, action: int, reward: float, next_obs: np.ndarray, q_value: np.ndarray, hidden_state: np.ndarray):
        self.action_buffer.append(action)
        self.reward_buffer.append(reward)
        self.hidden_buffer.append(hidden_state)
        self.obs_buffer.append(next_obs)
        self.last_action_buffer.append(np.array([1 if i == action else 0 for i in range(self.action_dim)], dtype=bool))
        self.last_reward_buffer.append(reward)
        self.qval_buffer.append(q_value)
        self.sum_reward += reward
        self.size += 1
    
    def finish(self, last_qval: np.ndarray = None) -> Tuple:
        assert self.size <= self.block_length
        # assert len(self.last_action_buffer) == self.curr_burn_in_steps + self.size + 1

        num_sequences = math.ceil(self.size/self.learning_steps)

        max_forward_steps = min(self.size, self.forward_steps)
        n_step_gamma = [self.gamma**self.forward_steps] * (self.size-max_forward_steps)

        # last_qval is none means episode done 
        if last_qval is not None:
            self.qval_buffer.append(last_qval)
            n_step_gamma.extend([self.gamma**i for i in reversed(range(1, max_forward_steps+1))])
        else:
            self.done = True
            self.qval_buffer.append(np.zeros_like(self.qval_buffer[0]))
            n_step_gamma.extend([0 for _ in range(max_forward_steps)]) # set gamma to 0 so don't need 'done'

        n_step_gamma = np.array(n_step_gamma, dtype=np.float32)

        obs = np.stack(self.obs_buffer)
        last_action = np.stack(self.last_action_buffer)
        last_reward = np.array(self.last_reward_buffer, dtype=np.float32)

        hiddens = np.stack(self.hidden_buffer[slice(0, self.size, self.learning_steps)])

        actions = np.array(self.action_buffer, dtype=np.uint8)

        qval_buffer = np.concatenate(self.qval_buffer)
        reward_buffer = self.reward_buffer + [0 for _ in range(self.forward_steps-1)]
        n_step_reward = np.convolve(reward_buffer, 
                                    [self.gamma**(self.forward_steps-1-i) for i in range(self.forward_steps)],
                                    'valid').astype(np.float32)

        burn_in_steps = np.array([min(i*self.learning_steps+self.curr_burn_in_steps, self.burn_in_steps) for i in range(num_sequences)], dtype=np.uint8)
        learning_steps = np.array([min(self.learning_steps, self.size-i*self.learning_steps) for i in range(num_sequences)], dtype=np.uint8)
        forward_steps = np.array([min(self.forward_steps, self.size+1-np.sum(learning_steps[:i+1])) for i in range(num_sequences)], dtype=np.uint8)
        assert forward_steps[-1] == 1 and burn_in_steps[0] == self.curr_burn_in_steps
        # assert last_action.shape[0] == self.curr_burn_in_steps + np.sum(learning_steps) + 1

        max_qval = np.max(qval_buffer[max_forward_steps:self.size+1], axis=1)
        max_qval = np.pad(max_qval, (0, max_forward_steps-1), 'edge')
        target_qval = qval_buffer[np.arange(self.size), actions]

        td_errors = np.abs(n_step_reward + n_step_gamma * max_qval - target_qval, dtype=np.float32)
        priorities = np.zeros(self.block_length//self.learning_steps, dtype=np.float32)
        priorities[:num_sequences] = calculate_mixed_td_errors(td_errors, learning_steps)

        # save burn in information for next block
        self.obs_buffer = self.obs_buffer[-self.burn_in_steps-1:]
        self.last_action_buffer = self.last_action_buffer[-self.burn_in_steps-1:]
        self.last_reward_buffer = self.last_reward_buffer[-self.burn_in_steps-1:]
        self.hidden_buffer = self.hidden_buffer[-self.burn_in_steps-1:]
        self.action_buffer.clear()
        self.reward_buffer.clear()
        self.qval_buffer.clear()
        self.curr_burn_in_steps = len(self.obs_buffer)-1
        self.size = 0
        
        block = Block(obs, last_action, last_reward, actions, n_step_reward, n_step_gamma, hiddens, num_sequences, burn_in_steps, learning_steps, forward_steps)
        return [block, priorities, self.sum_reward if self.done else None]

# %%
class Actor:
    def __init__(self, epsilon: float, model, sample_queue,
                max_episode_steps: int = max_episode_steps, block_length: int = block_length):

        self.env = create_env(game_name)
        self.action_dim = self.env.action_space.n
        self.model = Network(self.env.observation_space.shape[0], self.action_dim)
        self.model.eval()
        self.local_buffer = LocalBuffer(self.action_dim)

        self.epsilon = epsilon
        self.shared_model = model
        self.sample_queue = sample_queue
        self.max_episode_steps = max_episode_steps
        self.block_length = block_length

    def run(self):
        
        actor_steps = 0

        while True:

            done = False
            agent_state = self.reset()
            episode_steps = 0

            while not done and episode_steps < self.max_episode_steps:
                
                with torch.no_grad():
                    q_value, hidden = self.model(agent_state)

                if random.random() < self.epsilon:
                    action = self.env.action_space.sample()
                else:
                    action = torch.argmax(q_value, 1).item()

                # apply action in env
                next_obs, reward, terminated, truncated, _ = self.env.step(action)
                done = terminated or truncated

                agent_state.update(next_obs, action, reward, hidden)

                episode_steps += 1
                actor_steps += 1

                self.local_buffer.add(action, reward, next_obs, q_value.numpy(), torch.cat(hidden).numpy())

                if done:
                    block = self.local_buffer.finish()
                    self.sample_queue.put(block)

                elif len(self.local_buffer) == self.block_length or episode_steps == self.max_episode_steps:
                    with torch.no_grad():
                        q_value, hidden = self.model(agent_state)

                    block = self.local_buffer.finish(q_value.numpy())

                    if self.epsilon > 0.01:
                        block[2] = None
                    self.sample_queue.put(block)

                if actor_steps % actor_update_interval == 0:
                    self.update_weights()

                
    def update_weights(self):
        self.model.load_state_dict(self.shared_model.state_dict())
    
    def reset(self):
        obs, _ = self.env.reset()
        self.local_buffer.reset(obs)

        state = AgentState(torch.from_numpy(obs).unsqueeze(0), self.action_dim)

        return state

# %%
def get_epsilon(actor_id: int, base_eps: float = base_eps, alpha: float = alpha, num_actors: int = num_actors):
    exponent = 1 + actor_id / (num_actors-1) * alpha
    return base_eps**exponent

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 assert False
#
# AssertionError:

# %%
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)
torch.set_num_threads(1)

env = create_env(game_name)
n_observations = env.observation_space.shape
n_actions = env.action_space.n
env.close()

model = Network(n_observations, n_actions)
model.share_memory()
sample_queue_list = [mp.Queue() for _ in range(num_actors)]
batch_queue = mp.Queue(num_actors)
priority_queue = mp.Queue(num_actors)

buffer = ReplayBuffer(sample_queue_list, batch_queue, priority_queue)
learner = Learner(batch_queue, priority_queue, model)
actors = [Actor(get_epsilon(i), model, sample_queue_list[i]) for i in range(num_actors)]

actor_procs = [mp.Process(target=actor.run) for actor in actors]
for proc in actor_procs:
    proc.start()

buffer_proc = mp.Process(target=buffer.run)
buffer_proc.start()

learner.run()

buffer_proc.join()

for proc in actor_procs:
    proc.terminate()
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Buffer size: 0
# Buffer update speed: 0.0/s
# Number of environment steps: 0
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 0
# Buffer update speed: 0.0/s
# Number of environment steps: 0
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 3200
# Buffer update speed: 320.0/s
# Number of environment steps: 3200
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 4791
# Buffer update speed: 159.1/s
# Number of environment steps: 4791
# Average episode return: 150.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 6436
# Buffer update speed: 164.5/s
# Number of environment steps: 6436
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 9636
# Buffer update speed: 320.0/s
# Number of environment steps: 9636
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 10989
# Buffer update speed: 135.3/s
# Number of environment steps: 10989
# Average episode return: 100.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 13382
# Buffer update speed: 239.3/s
# Number of environment steps: 13382
# Average episode return: 100.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 15782
# Buffer update speed: 240.0/s
# Number of environment steps: 15782
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 17407
# Buffer update speed: 202.5/s
# Number of environment steps: 17807
# Average episode return: 150.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 19290
# Buffer update speed: 148.3/s
# Number of environment steps: 19290
# Average episode return: 200.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 22033
# Buffer update speed: 274.3/s
# Number of environment steps: 22033
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 24042
# Buffer update speed: 200.9/s
# Number of environment steps: 24042
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 26499
# Buffer update speed: 245.7/s
# Number of environment steps: 26499
# Average episode return: 200.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 27699
# Buffer update speed: 120.0/s
# Number of environment steps: 27699
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 30417
# Buffer update speed: 271.8/s
# Number of environment steps: 30417
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 33284
# Buffer update speed: 286.7/s
# Number of environment steps: 33284
# Average episode return: 100.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 34783
# Buffer update speed: 149.9/s
# Number of environment steps: 34783
# Average episode return: 200.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 36783
# Buffer update speed: 200.0/s
# Number of environment steps: 36783
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 39601
# Buffer update speed: 281.8/s
# Number of environment steps: 39601
# Average episode return: 200.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 41887
# Buffer update speed: 228.6/s
# Number of environment steps: 41887
# Average episode return: 200.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 43487
# Buffer update speed: 160.0/s
# Number of environment steps: 43487
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 46314
# Buffer update speed: 282.7/s
# Number of environment steps: 46314
# Average episode return: 200.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 49114
# Buffer update speed: 280.0/s
# Number of environment steps: 49114
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 50242
# Buffer update speed: 112.8/s
# Number of environment steps: 50242
# Average episode return: 300.0000
# Number of training steps: 0
# Training speed: 0.0/s
#
# Buffer size: 53043
# Buffer update speed: 280.1/s
# Number of environment steps: 53043
# Number of training steps: 12
# Training speed: 1.2/s
# Loss: 1.0418
#
# Buffer size: 53802
# Buffer update speed: 75.9/s
# Number of environment steps: 53802
# Average episode return: 300.0000
# Number of training steps: 39
# Training speed: 2.7/s
# Loss: 0.2871
#
# Buffer size: 56152
# Buffer update speed: 235.0/s
# Number of environment steps: 56152
# Number of training steps: 64
# Training speed: 2.5/s
# Loss: 0.4141
#
# Buffer size: 57969
# Buffer update speed: 181.7/s
# Number of environment steps: 57969
# Number of training steps: 89
# Training speed: 2.5/s
# Loss: 0.4057
#
# Buffer size: 59876
# Buffer update speed: 190.7/s
# Number of environment steps: 59876
# Average episode return: 100.0000
# Number of training steps: 110
# Training speed: 2.1/s
# Loss: 0.3949
#
# Buffer size: 61883
# Buffer update speed: 200.7/s
# Number of environment steps: 61883
# Average episode return: 100.0000
# Number of training steps: 133
# Training speed: 2.3/s
# Loss: 0.2775
#
# Buffer size: 63550
# Buffer update speed: 166.7/s
# Number of environment steps: 63550
# Number of training steps: 158
# Training speed: 2.5/s
# Loss: 0.3222
#
# Buffer size: 66157
# Buffer update speed: 260.7/s
# Number of environment steps: 66157
# Number of training steps: 188
# Training speed: 3.0/s
# Loss: 0.3282
#
# Buffer size: 67406
# Buffer update speed: 124.9/s
# Number of environment steps: 67406
# Number of training steps: 219
# Training speed: 3.1/s
# Loss: 0.3352
#
# Buffer size: 69693
# Buffer update speed: 228.7/s
# Number of environment steps: 69693
# Average episode return: 150.0000
# Number of training steps: 252
# Training speed: 3.3/s
# Loss: 0.4146
#
# Buffer size: 71494
# Buffer update speed: 180.1/s
# Number of environment steps: 71494
# Number of training steps: 278
# Training speed: 2.6/s
# Loss: 0.4018
#
# Buffer size: 73539
# Buffer update speed: 204.5/s
# Number of environment steps: 73539
# Number of training steps: 310
# Training speed: 3.1/s
# Loss: 0.3457
#
# Buffer size: 75889
# Buffer update speed: 235.0/s
# Number of environment steps: 75889
# Average episode return: 150.0000
# Number of training steps: 331
# Training speed: 2.1/s
# Loss: 0.3972
#
# Buffer size: 77489
# Buffer update speed: 160.0/s
# Number of environment steps: 77489
# Number of training steps: 360
# Training speed: 2.9/s
# Loss: 0.3627
#
# Buffer size: 79552
# Buffer update speed: 206.3/s
# Number of environment steps: 79552
# Number of training steps: 378
# Training speed: 1.8/s
# Loss: 0.5208
#
# Buffer size: 80506
# Buffer update speed: 95.4/s
# Number of environment steps: 80506
# Average episode return: 100.0000
# Number of training steps: 406
# Training speed: 2.8/s
# Loss: 0.3745
#
# Buffer size: 83710
# Buffer update speed: 320.4/s
# Number of environment steps: 83710
# Average episode return: 100.0000
# Number of training steps: 436
# Training speed: 3.0/s
# Loss: 0.4571
#
# Buffer size: 84847
# Buffer update speed: 113.7/s
# Number of environment steps: 84847
# Number of training steps: 459
# Training speed: 2.3/s
# Loss: 0.4757
#
# Buffer size: 87128
# Buffer update speed: 228.1/s
# Number of environment steps: 87128
# Number of training steps: 483
# Training speed: 2.4/s
# Loss: 0.3712
#
# Buffer size: 89345
# Buffer update speed: 221.7/s
# Number of environment steps: 89345
# Average episode return: 100.0000
# Number of training steps: 506
# Training speed: 2.3/s
# Loss: 0.3891
#
# Buffer size: 90188
# Buffer update speed: 84.3/s
# Number of environment steps: 90188
# Number of training steps: 541
# Training speed: 3.5/s
# Loss: 0.3227
#
# Buffer size: 92574
# Buffer update speed: 238.6/s
# Number of environment steps: 92574
# Average episode return: 100.0000
# Number of training steps: 562
# Training speed: 2.1/s
# Loss: 0.3598
#
# Buffer size: 94141
# Buffer update speed: 156.7/s
# Number of environment steps: 94141
# Number of training steps: 596
# Training speed: 3.4/s
# Loss: 0.4072
#
# Buffer size: 96147
# Buffer update speed: 200.6/s
# Number of environment steps: 96147
# Number of training steps: 622
# Training speed: 2.6/s
# Loss: 0.3368
#
# Buffer size: 97974
# Buffer update speed: 182.7/s
# Number of environment steps: 97974
# Number of training steps: 652
# Training speed: 3.0/s
# Loss: 0.3196
#
# Buffer size: 99540
# Buffer update speed: 156.6/s
# Number of environment steps: 99540
# Number of training steps: 676
# Training speed: 2.4/s
# Loss: 0.3034
#
# Buffer size: 101818
# Buffer update speed: 227.8/s
# Number of environment steps: 101818
# Number of training steps: 707
# Training speed: 3.1/s
# Loss: 0.4030
#
# Buffer size: 103917
# Buffer update speed: 209.9/s
# Number of environment steps: 103917
# Number of training steps: 731
# Training speed: 2.4/s
# Loss: 0.3217
#
# Buffer size: 104909
# Buffer update speed: 99.2/s
# Number of environment steps: 104909
# Number of training steps: 758
# Training speed: 2.7/s
# Loss: 0.2679
#
# Buffer size: 107462
# Buffer update speed: 255.3/s
# Number of environment steps: 107462
# Average episode return: 100.0000
# Number of training steps: 788
# Training speed: 3.0/s
# Loss: 0.2633
#
# Buffer size: 109663
# Buffer update speed: 220.1/s
# Number of environment steps: 109663
# Average episode return: 200.0000
# Number of training steps: 810
# Training speed: 2.3/s
# Loss: 0.2279
#
# Buffer size: 110985
# Buffer update speed: 132.2/s
# Number of environment steps: 110985
# Average episode return: 100.0000
# Number of training steps: 841
# Training speed: 3.1/s
# Loss: 0.3692
#
# Buffer size: 112940
# Buffer update speed: 195.5/s
# Number of environment steps: 112940
# Average episode return: 166.6667
# Number of training steps: 870
# Training speed: 2.8/s
# Loss: 0.2859
#
# Buffer size: 114618
# Buffer update speed: 167.8/s
# Number of environment steps: 114618
# Number of training steps: 896
# Training speed: 2.6/s
# Loss: 0.3142
#
# Buffer size: 117611
# Buffer update speed: 299.3/s
# Number of environment steps: 117611
# Average episode return: 200.0000
# Number of training steps: 917
# Training speed: 2.1/s
# Loss: 0.3848
#
# Buffer size: 118964
# Buffer update speed: 135.3/s
# Number of environment steps: 118964
# Average episode return: 220.0000
# Number of training steps: 937
# Training speed: 2.0/s
# Loss: 0.2908
#
# Buffer size: 121477
# Buffer update speed: 251.3/s
# Number of environment steps: 121477
# Average episode return: 200.0000
# Number of training steps: 970
# Training speed: 3.3/s
# Loss: 0.3752
#
# Buffer size: 123045
# Buffer update speed: 156.8/s
# Number of environment steps: 123045
# Number of training steps: 990
# Training speed: 2.0/s
# Loss: 0.3649
#
# Buffer size: 124717
# Buffer update speed: 167.2/s
# Number of environment steps: 124717
# Average episode return: 200.0000
# Number of training steps: 1014
# Training speed: 2.4/s
# Loss: 0.3302
#
# Buffer size: 126480
# Buffer update speed: 176.3/s
# Number of environment steps: 126480
# Average episode return: 300.0000
# Number of training steps: 1039
# Training speed: 2.4/s
# Loss: 0.3281
#
# Buffer size: 128353
# Buffer update speed: 187.3/s
# Number of environment steps: 128353
# Average episode return: 200.0000
# Number of training steps: 1063
# Training speed: 2.5/s
# Loss: 0.3525
#
# Buffer size: 130146
# Buffer update speed: 179.3/s
# Number of environment steps: 130146
# Average episode return: 133.3333
# Number of training steps: 1096
# Training speed: 3.2/s
# Loss: 0.4229
#
# Buffer size: 132216
# Buffer update speed: 207.0/s
# Number of environment steps: 132216
# Average episode return: 100.0000
# Number of training steps: 1124
# Training speed: 2.8/s
# Loss: 0.3430
#
# Buffer size: 133872
# Buffer update speed: 165.6/s
# Number of environment steps: 133872
# Average episode return: 100.0000
# Number of training steps: 1142
# Training speed: 1.8/s
# Loss: 0.4275
#
# Buffer size: 136086
# Buffer update speed: 221.4/s
# Number of environment steps: 136086
# Average episode return: 200.0000
# Number of training steps: 1179
# Training speed: 3.7/s
# Loss: 0.3943
#
# Buffer size: 137659
# Buffer update speed: 157.3/s
# Number of environment steps: 137659
# Average episode return: 233.3333
# Number of training steps: 1208
# Training speed: 2.8/s
# Loss: 0.4411
#
# Buffer size: 139698
# Buffer update speed: 203.9/s
# Number of environment steps: 139698
# Number of training steps: 1230
# Training speed: 2.2/s
# Loss: 0.3503
#
# Buffer size: 140898
# Buffer update speed: 120.0/s
# Number of environment steps: 140898
# Number of training steps: 1254
# Training speed: 2.5/s
# Loss: 0.4176
#
# Buffer size: 144195
# Buffer update speed: 329.7/s
# Number of environment steps: 144195
# Average episode return: 100.0000
# Number of training steps: 1285
# Training speed: 3.0/s
# Loss: 0.4616
#
# Buffer size: 144870
# Buffer update speed: 67.5/s
# Number of environment steps: 144870
# Number of training steps: 1316
# Training speed: 3.1/s
# Loss: 0.3978
#
# Buffer size: 147270
# Buffer update speed: 240.0/s
# Number of environment steps: 147270
# Number of training steps: 1353
# Training speed: 3.7/s
# Loss: 0.4357
#
# Buffer size: 149513
# Buffer update speed: 224.3/s
# Number of environment steps: 149513
# Average episode return: 150.0000
# Number of training steps: 1380
# Training speed: 2.7/s
# Loss: 0.3783
#
# Buffer size: 150608
# Buffer update speed: 109.5/s
# Number of environment steps: 150608
# Average episode return: 150.0000
# Number of training steps: 1398
# Training speed: 1.8/s
# Loss: 0.4171
#
# Buffer size: 152724
# Buffer update speed: 211.6/s
# Number of environment steps: 152724
# Average episode return: 200.0000
# Number of training steps: 1434
# Training speed: 3.6/s
# Loss: 0.3880
#
# Buffer size: 155023
# Buffer update speed: 229.9/s
# Number of environment steps: 155023
# Average episode return: 166.6667
# Number of training steps: 1454
# Training speed: 2.0/s
# Loss: 0.4359
#
# Buffer size: 156519
# Buffer update speed: 149.6/s
# Number of environment steps: 156519
# Average episode return: 150.0000
# Number of training steps: 1478
# Training speed: 2.4/s
# Loss: 0.4157
#
# Buffer size: 158936
# Buffer update speed: 241.7/s
# Number of environment steps: 158936
# Average episode return: 100.0000
# Number of training steps: 1504
# Training speed: 2.6/s
# Loss: 0.4099
#
# Buffer size: 160238
# Buffer update speed: 130.2/s
# Number of environment steps: 160238
# Number of training steps: 1523
# Training speed: 1.9/s
# Loss: 0.4089
#
# Buffer size: 162544
# Buffer update speed: 230.6/s
# Number of environment steps: 162544
# Number of training steps: 1552
# Training speed: 2.9/s
# Loss: 0.4653
#
# Buffer size: 164447
# Buffer update speed: 190.3/s
# Number of environment steps: 164447
# Average episode return: 200.0000
# Number of training steps: 1573
# Training speed: 2.1/s
# Loss: 0.3895
#
# Buffer size: 165749
# Buffer update speed: 130.2/s
# Number of environment steps: 165749
# Number of training steps: 1597
# Training speed: 2.4/s
# Loss: 0.4224
#
# Buffer size: 168339
# Buffer update speed: 259.0/s
# Number of environment steps: 168339
# Number of training steps: 1633
# Training speed: 3.6/s
# Loss: 0.3437
#
# Buffer size: 169628
# Buffer update speed: 128.9/s
# Number of environment steps: 169628
# Average episode return: 100.0000
# Number of training steps: 1666
# Training speed: 3.3/s
# Loss: 0.2717
#
# Buffer size: 172742
# Buffer update speed: 311.4/s
# Number of environment steps: 172742
# Average episode return: 200.0000
# Number of training steps: 1698
# Training speed: 3.2/s
# Loss: 0.4334
#
# Buffer size: 173644
# Buffer update speed: 90.2/s
# Number of environment steps: 173644
# Average episode return: 100.0000
# Number of training steps: 1721
# Training speed: 2.4/s
# Loss: 0.4071
#
# Buffer size: 176299
# Buffer update speed: 265.5/s
# Number of environment steps: 176299
# Average episode return: 100.0000
# Number of training steps: 1754
# Training speed: 3.2/s
# Loss: 0.3663
#
# Buffer size: 177617
# Buffer update speed: 131.8/s
# Number of environment steps: 177617
# Average episode return: 150.0000
# Number of training steps: 1774
# Training speed: 2.0/s
# Loss: 0.3949
#
# Buffer size: 179405
# Buffer update speed: 178.8/s
# Number of environment steps: 179405
# Average episode return: 150.0000
# Number of training steps: 1796
# Training speed: 2.2/s
# Loss: 0.3245
#
# Buffer size: 181771
# Buffer update speed: 236.6/s
# Number of environment steps: 181771
# Average episode return: 300.0000
# Number of training steps: 1823
# Training speed: 2.7/s
# Loss: 0.4523
#
# Buffer size: 182916
# Buffer update speed: 114.5/s
# Number of environment steps: 182916
# Average episode return: 400.0000
# Number of training steps: 1842
# Training speed: 1.8/s
# Loss: 0.3704
#
# Buffer size: 185607
# Buffer update speed: 269.1/s
# Number of environment steps: 185607
# Average episode return: 100.0000
# Number of training steps: 1864
# Training speed: 2.2/s
# Loss: 0.4000
#
# Buffer size: 186807
# Buffer update speed: 120.0/s
# Number of environment steps: 186807
# Number of training steps: 1885
# Training speed: 2.1/s
# Loss: 0.3626
#
# Buffer size: 189758
# Buffer update speed: 295.1/s
# Number of environment steps: 189758
# Average episode return: 150.0000
# Number of training steps: 1905
# Training speed: 2.0/s
# Loss: 0.4377
#
# Buffer size: 191400
# Buffer update speed: 164.2/s
# Number of environment steps: 191400
# Average episode return: 220.0000
# Number of training steps: 1922
# Training speed: 1.7/s
# Loss: 0.3417
#
# Buffer size: 192713
# Buffer update speed: 131.3/s
# Number of environment steps: 192713
# Average episode return: 100.0000
# Number of training steps: 1957
# Training speed: 3.5/s
# Loss: 0.4054
#
# Buffer size: 194713
# Buffer update speed: 200.0/s
# Number of environment steps: 194713
# Number of training steps: 1976
# Training speed: 2.0/s
# Loss: 0.3386
#
# Buffer size: 196609
# Buffer update speed: 189.6/s
# Number of environment steps: 196609
# Average episode return: 200.0000
# Number of training steps: 1996
# Training speed: 1.9/s
# Loss: 0.3739
#
# Buffer size: 198490
# Buffer update speed: 188.1/s
# Number of environment steps: 198490
# Average episode return: 250.0000
# Number of training steps: 2022
# Training speed: 2.6/s
# Loss: 0.3683
#
# Buffer size: 199872
# Buffer update speed: 138.2/s
# Number of environment steps: 199872
# Average episode return: 100.0000
# Number of training steps: 2045
# Training speed: 2.3/s
# Loss: 0.3111
#
# Buffer size: 202447
# Buffer update speed: 257.5/s
# Number of environment steps: 202447
# Number of training steps: 2069Average episode return: 200.0000
#
# Training speed: 2.4/s
# Loss: 0.4203
#
# Buffer size: 204047
# Buffer update speed: 160.0/s
# Number of environment steps: 204047
# Number of training steps: 2093
# Training speed: 2.4/s
# Loss: 0.4918
#
# Buffer size: 206181
# Buffer update speed: 213.4/s
# Number of environment steps: 206181
# Average episode return: 150.0000
# Number of training steps: 2126
# Training speed: 3.3/s
# Loss: 0.3727
#
# Buffer size: 208343
# Buffer update speed: 216.2/s
# Number of environment steps: 208343
# Average episode return: 133.3333
# Number of training steps: 2154
# Training speed: 2.8/s
# Loss: 0.3713
#
# Buffer size: 210093
# Buffer update speed: 175.0/s
# Number of environment steps: 210093
# Number of training steps: 2178
# Training speed: 2.4/s
# Loss: 0.3019
#
# Buffer size: 212042
# Buffer update speed: 194.9/s
# Number of environment steps: 212042
# Average episode return: 166.6667
# Number of training steps: 2201
# Training speed: 2.3/s
# Loss: 0.3757
#
# Buffer size: 214349
# Buffer update speed: 230.7/s
# Number of environment steps: 214349
# Average episode return: 150.0000
# Number of training steps: 2218
# Training speed: 1.7/s
# Loss: 0.2558
#
# Buffer size: 215949
# Buffer update speed: 160.0/s
# Number of environment steps: 215949
# Number of training steps: 2239
# Training speed: 2.1/s
# Loss: 0.3696
#
# Buffer size: 217616
# Buffer update speed: 166.7/s
# Number of environment steps: 217616
# Number of training steps: 2271
# Training speed: 3.2/s
# Loss: 0.3698
#
# Buffer size: 219411
# Buffer update speed: 179.5/s
# Number of environment steps: 219411
# Average episode return: 200.0000
# Number of training steps: 2300
# Training speed: 3.0/s
# Loss: 0.2874
#
# Buffer size: 221565
# Buffer update speed: 215.4/s
# Number of environment steps: 221565
# Average episode return: 100.0000
# Number of training steps: 2323
# Training speed: 2.2/s
# Loss: 0.3715
#
# Buffer size: 223165
# Buffer update speed: 160.0/s
# Number of environment steps: 223165
# Number of training steps: 2355
# Training speed: 3.2/s
# Loss: 0.4120
#
# Buffer size: 225268
# Buffer update speed: 210.3/s
# Number of environment steps: 225268
# Average episode return: 175.0000
# Number of training steps: 2379
# Training speed: 2.4/s
# Loss: 0.3548
#
# Buffer size: 226238
# Buffer update speed: 97.0/s
# Number of environment steps: 226238
# Average episode return: 300.0000
# Number of training steps: 2409
# Training speed: 2.9/s
# Loss: 0.3822
#
# Buffer size: 228864
# Buffer update speed: 262.6/s
# Number of environment steps: 228864
# Average episode return: 200.0000
# Number of training steps: 2435
# Training speed: 2.6/s
# Loss: 0.4017
#
# Buffer size: 230775
# Buffer update speed: 191.1/s
# Number of environment steps: 230775
# Average episode return: 200.0000
# Number of training steps: 2467
# Training speed: 3.0/s
# Loss: 0.3847
#
# Buffer size: 232427
# Buffer update speed: 165.2/s
# Number of environment steps: 232427
# Average episode return: 100.0000
# Number of training steps: 2496
# Training speed: 2.9/s
# Loss: 0.3395
#
# Buffer size: 234094
# Buffer update speed: 166.7/s
# Number of environment steps: 234094
# Number of training steps: 2525
# Training speed: 2.9/s
# Loss: 0.3967
#
# Buffer size: 235848
# Buffer update speed: 175.4/s
# Number of environment steps: 235848
# Average episode return: 166.6667
# Number of training steps: 2555
# Training speed: 3.0/s
# Loss: 0.3641
#
# Buffer size: 237589
# Buffer update speed: 174.1/s
# Number of environment steps: 237589
# Average episode return: 150.0000
# Number of training steps: 2576
#
# Training speed: 2.1/s
# Loss: 0.4119
# Buffer size: 239237
# Buffer update speed: 164.8/s
# Number of environment steps: 239237
# Average episode return: 100.0000
# Number of training steps: 2604
# Training speed: 2.8/s
# Loss: 0.4110
#
# Buffer size: 242755
# Buffer update speed: 351.8/s
# Number of environment steps: 242755
# Average episode return: 125.0000
# Number of training steps: 2626
# Training speed: 2.2/s
# Loss: 0.3283
#
# Buffer size: 243078
# Buffer update speed: 32.3/s
# Number of environment steps: 243078
# Average episode return: 100.0000
# Number of training steps: 2652
# Training speed: 2.6/s
# Loss: 0.4025
#
# Buffer size: 245555
# Buffer update speed: 247.7/s
# Number of environment steps: 245555
# Average episode return: 100.0000
# Number of training steps: 2684
# Training speed: 3.2/s
# Loss: 0.4061
#
# Buffer size: 248024
# Buffer update speed: 246.9/s
# Number of environment steps: 248024
# Average episode return: 233.3333
# Number of training steps: 2708
# Training speed: 2.4/s
# Loss: 0.3658
#
# Buffer size: 248967
# Buffer update speed: 94.3/s
# Number of environment steps: 248967
# Average episode return: 250.0000
# Number of training steps: 2733
# Training speed: 2.5/s
# Loss: 0.3343
#
# Buffer size: 251315
# Buffer update speed: 274.8/s
# Number of environment steps: 251715
# Average episode return: 150.0000
# Number of training steps: 2758
# Training speed: 2.5/s
# Loss: 0.4311
#
# Buffer size: 252429
# Buffer update speed: 71.4/s
# Number of environment steps: 252429
# Average episode return: 250.0000
# Number of training steps: 2787
# Training speed: 2.9/s
# Loss: 0.3953
#
# Buffer size: 254515
# Buffer update speed: 208.6/s
# Number of environment steps: 254515
# Average episode return: 200.0000
# Number of training steps: 2812
# Training speed: 2.5/s
# Loss: 0.3719
#
# Buffer size: 256607
# Buffer update speed: 209.2/s
# Number of environment steps: 256607
# Average episode return: 200.0000
# Number of training steps: 2830
# Training speed: 1.8/s
# Loss: 0.4513
#
# Buffer size: 258418
# Buffer update speed: 181.1/s
# Number of environment steps: 258418
# Average episode return: 200.0000
# Number of training steps: 2851
# Training speed: 2.1/s
# Loss: 0.3927
#
# Buffer size: 260543
# Buffer update speed: 212.5/s
# Number of environment steps: 260543
# Average episode return: 200.0000
# Number of training steps: 2880
# Training speed: 2.9/s
# Loss: 0.3976
#
# Buffer size: 261907
# Buffer update speed: 136.4/s
# Number of environment steps: 261907
# Average episode return: 200.0000
# Number of training steps: 2905
# Training speed: 2.5/s
# Loss: 0.3783
#
# Buffer size: 264399
# Buffer update speed: 249.2/s
# Number of environment steps: 264399
# Average episode return: 100.0000
# Number of training steps: 2931
# Training speed: 2.6/s
# Loss: 0.4320
#
# Buffer size: 266264
# Buffer update speed: 186.5/s
# Number of environment steps: 266264
# Average episode return: 233.3333
# Number of training steps: 2951
# Training speed: 2.0/s
# Loss: 0.4215
#
# Buffer size: 267558
# Buffer update speed: 129.4/s
# Number of environment steps: 267558
# Average episode return: 150.0000
# Number of training steps: 2980
# Training speed: 2.9/s
# Loss: 0.4277
#
# Buffer size: 270078
# Buffer update speed: 252.0/s
# Number of environment steps: 270078
# Average episode return: 250.0000
# Number of training steps: 3006
# Training speed: 2.6/s
# Loss: 0.4200
#
# Buffer size: 271731
# Buffer update speed: 165.3/s
# Number of environment steps: 271731
# Average episode return: 200.0000
# Number of training steps: 3030
# Training speed: 2.5/s
# Loss: 0.3575
#
# Buffer size: 273783
# Buffer update speed: 205.2/s
# Number of environment steps: 273783
# Average episode return: 166.6667
# Number of training steps: 3056
# Training speed: 2.5/s
# Loss: 0.4008
#
# Buffer size: 276170
# Buffer update speed: 238.7/s
# Number of environment steps: 276170
# Average episode return: 100.0000
# Number of training steps: 3076
# Training speed: 2.0/s
# Loss: 0.4228
#
# Buffer size: 276923
# Buffer update speed: 75.3/s
# Number of environment steps: 276923
# Average episode return: 150.0000
# Number of training steps: 3107
# Training speed: 3.1/s
# Loss: 0.4378
#
# Buffer size: 279854
# Buffer update speed: 293.1/s
# Number of environment steps: 279854
# Average episode return: 233.3333
# Number of training steps: 3133
# Training speed: 2.6/s
# Loss: 0.3889
#
# Buffer size: 281232
# Buffer update speed: 137.8/s
# Number of environment steps: 281232
# Average episode return: 200.0000
# Number of training steps: 3155
# Training speed: 2.2/s
# Loss: 0.4376
#
# Buffer size: 284238
# Buffer update speed: 300.6/s
# Number of environment steps: 284238
# Average episode return: 166.6667
# Number of training steps: 3179
# Training speed: 2.5/s
# Loss: 0.4771
#
# Buffer size: 284600
# Buffer update speed: 36.2/s
# Number of environment steps: 284600
# Number of training steps: 3204
# Training speed: 2.4/s
# Loss: 0.4993
#
# Buffer size: 286999
# Buffer update speed: 239.9/s
# Number of environment steps: 286999
# Average episode return: 300.0000
# Number of training steps: 3225
# Training speed: 2.1/s
# Loss: 0.4608
#
# Buffer size: 288208
# Buffer update speed: 120.9/s
# Number of environment steps: 288208
# Average episode return: 200.0000
# Number of training steps: 3254
# Training speed: 2.9/s
# Loss: 0.4347
#
# Buffer size: 289965
# Buffer update speed: 175.7/s
# Number of environment steps: 289965
# Average episode return: 200.0000
# Number of training steps: 3278
# Training speed: 2.4/s
# Loss: 0.3634
#
# Buffer size: 292057
# Buffer update speed: 209.2/s
# Number of environment steps: 292057
# Average episode return: 150.0000
# Number of training steps: 3298
# Training speed: 2.0/s
# Loss: 0.3499
#
# Buffer size: 293826
# Buffer update speed: 176.9/s
# Number of environment steps: 293826
# Average episode return: 125.0000
# Number of training steps: 3319
# Training speed: 2.1/s
# Loss: 0.3777
#
# Buffer size: 295134
# Buffer update speed: 130.8/s
# Number of environment steps: 295134
# Number of training steps: 3350
# Training speed: 3.1/s
# Loss: 0.3911
#
# Buffer size: 297597
# Buffer update speed: 246.3/s
# Number of environment steps: 297597
# Average episode return: 300.0000
# Number of training steps: 3375
# Training speed: 2.5/s
# Loss: 0.4707
#
# Buffer size: 299525
# Buffer update speed: 192.8/s
# Number of environment steps: 299525
# Average episode return: 200.0000
# Number of training steps: 3394
# Training speed: 1.9/s
# Loss: 0.5004
#
# Buffer size: 301368
# Buffer update speed: 184.3/s
# Number of environment steps: 301368
# Average episode return: 150.0000
# Number of training steps: 3417
# Training speed: 2.3/s
# Loss: 0.3214
#
# Buffer size: 303548
# Buffer update speed: 218.0/s
# Number of environment steps: 303548
# Average episode return: 250.0000
# Number of training steps: 3442
# Training speed: 2.5/s
# Loss: 0.4232
#
# Buffer size: 305099
# Buffer update speed: 155.1/s
# Number of environment steps: 305099
# Average episode return: 150.0000
# Number of training steps: 3468
# Training speed: 2.6/s
# Loss: 0.3389
#
# Buffer size: 307499
# Buffer update speed: 240.0/s
# Number of environment steps: 307499
# Average episode return: 233.3333
# Number of training steps: 3504
# Training speed: 3.6/s
# Loss: 0.4520
#
# Buffer size: 308507
# Buffer update speed: 100.8/s
# Number of environment steps: 308507
# Average episode return: 200.0000
# Number of training steps: 3529
# Training speed: 2.5/s
# Loss: 0.4397
#
# Buffer size: 311014
# Buffer update speed: 250.7/s
# Number of environment steps: 311014
# Average episode return: 100.0000
# Number of training steps: 3552
# Training speed: 2.3/s
# Loss: 0.4131
#
# Buffer size: 312319
# Buffer update speed: 130.5/s
# Number of environment steps: 312319
# Average episode return: 300.0000
# Number of training steps: 3578
# Training speed: 2.6/s
# Loss: 0.4311
#
# Buffer size: 314502
# Buffer update speed: 218.3/s
# Number of environment steps: 314502
# Average episode return: 233.3333
# Number of training steps: 3609
# Training speed: 3.1/s
# Loss: 0.4036
#
# Buffer size: 315798
# Buffer update speed: 129.6/s
# Number of environment steps: 315798
# Average episode return: 200.0000
# Number of training steps: 3636
# Training speed: 2.6/s
# Loss: 0.4523
#
# Buffer size: 318255
# Buffer update speed: 245.7/s
# Number of environment steps: 318255
# Average episode return: 400.0000
# Number of training steps: 3660
# Training speed: 2.4/s
# Loss: 0.4603
#
# Buffer size: 319642
# Buffer update speed: 138.7/s
# Number of environment steps: 319642
# Average episode return: 300.0000
# Number of training steps: 3695
# Training speed: 3.5/s
# Loss: 0.4315
#
# Buffer size: 322470
# Buffer update speed: 282.8/s
# Number of environment steps: 322470
# Average episode return: 240.0000
# Number of training steps: 3724
# Training speed: 2.9/s
# Loss: 0.5038
#
# Buffer size: 322870
# Buffer update speed: 40.0/s
# Number of environment steps: 322870
# Number of training steps: 3753
# Training speed: 2.9/s
# Loss: 0.4200
#
# Buffer size: 326127
# Buffer update speed: 325.7/s
# Number of environment steps: 326127
# Average episode return: 300.0000
# Number of training steps: 3778
# Training speed: 2.5/s
# Loss: 0.3435
#
# Buffer size: 327023
# Buffer update speed: 89.6/s
# Number of environment steps: 327023
# Average episode return: 100.0000
# Number of training steps: 3803
# Training speed: 2.5/s
# Loss: 0.4431
#
# Buffer size: 329270
# Buffer update speed: 224.7/s
# Number of environment steps: 329270
# Average episode return: 275.0000
# Number of training steps: 3830
# Training speed: 2.7/s
# Loss: 0.3959
#
# Buffer size: 331106
# Buffer update speed: 183.6/s
# Number of environment steps: 331106
# Average episode return: 100.0000
# Number of training steps: 3854
# Training speed: 2.4/s
# Loss: 0.4154
#
# Buffer size: 332754
# Buffer update speed: 164.8/s
# Number of environment steps: 332754
# Average episode return: 300.0000
# Number of training steps: 3881
# Training speed: 2.7/s
# Loss: 0.3836
#
# Buffer size: 335321
# Buffer update speed: 256.7/s
# Number of environment steps: 335321
# Average episode return: 300.0000
# Number of training steps: 3909
# Training speed: 2.8/s
# Loss: 0.4469
#
# Buffer size: 336013
# Buffer update speed: 69.2/s
# Number of environment steps: 336013
# Average episode return: 166.6667
# Number of training steps: 3935
# Training speed: 2.6/s
# Loss: 0.4687
#
# Buffer size: 339371
# Buffer update speed: 335.8/s
# Number of environment steps: 339371
# Average episode return: 100.0000
# Number of training steps: 3962
# Training speed: 2.7/s
# Loss: 0.5465
#
# Buffer size: 340218
# Buffer update speed: 84.7/s
# Number of environment steps: 340218
# Average episode return: 100.0000
# Number of training steps: 3985
# Training speed: 2.3/s
# Loss: 0.4223
#
# Buffer size: 342872
# Buffer update speed: 265.4/s
# Number of environment steps: 342872
# Average episode return: 233.3333
# Number of training steps: 4015
# Training speed: 3.0/s
# Loss: 0.4570
#
# Buffer size: 344650
# Buffer update speed: 177.8/s
# Number of environment steps: 344650
# Average episode return: 200.0000
# Number of training steps: 4037
# Training speed: 2.2/s
# Loss: 0.4515
#
# Buffer size: 346493
# Buffer update speed: 184.3/s
# Number of environment steps: 346493
# Average episode return: 200.0000
# Number of training steps: 4065
# Training speed: 2.8/s
# Loss: 0.3712
#
# Buffer size: 348130
# Buffer update speed: 163.7/s
# Number of environment steps: 348130
# Average episode return: 166.6667
# Number of training steps: 4098
# Training speed: 3.4/s
# Loss: 0.4166
#
# Buffer size: 350638
# Buffer update speed: 250.8/s
# Number of environment steps: 350638
# Average episode return: 200.0000
# Number of training steps: 4123
# Training speed: 2.4/s
# Loss: 0.4473
#
# Buffer size: 352543
# Buffer update speed: 190.5/s
# Number of environment steps: 352543
# Average episode return: 150.0000
# Number of training steps: 4145
# Training speed: 2.3/s
# Loss: 0.2702
#
# Buffer size: 354102
# Buffer update speed: 155.9/s
# Number of environment steps: 354102
# Average episode return: 250.0000
# Number of training steps: 4168
# Training speed: 2.3/s
# Loss: 0.3250
#
# Buffer size: 356294
# Buffer update speed: 219.2/s
# Number of environment steps: 356294
# Average episode return: 250.0000
# Number of training steps: 4187
# Training speed: 1.8/s
# Loss: 0.3412
#
# Buffer size: 357704
# Buffer update speed: 141.0/s
# Number of environment steps: 357704
# Average episode return: 100.0000
# Number of training steps: 4207
# Training speed: 2.0/s
# Loss: 0.3371
#
# Buffer size: 360163
# Buffer update speed: 245.9/s
# Number of environment steps: 360163
# Average episode return: 166.6667
# Number of training steps: 4233
# Training speed: 2.6/s
# Loss: 0.2903
#
# Buffer size: 361763
# Buffer update speed: 160.0/s
# Number of environment steps: 361763
# Number of training steps: 4262
# Training speed: 2.9/s
# Loss: 0.3104
#
# Buffer size: 364436
# Buffer update speed: 267.3/s
# Number of environment steps: 364436
# Average episode return: 200.0000
# Number of training steps: 4288
# Training speed: 2.5/s
# Loss: 0.2972
#
# Buffer size: 365678
# Buffer update speed: 124.2/s
# Number of environment steps: 365678
# Average episode return: 100.0000
# Number of training steps: 4321
# Training speed: 3.3/s
# Loss: 0.2906
#
# Buffer size: 367175
# Buffer update speed: 149.7/s
# Number of environment steps: 367175
# Average episode return: 100.0000
# Number of training steps: 4347
# Training speed: 2.5/s
# Loss: 0.2571
#
# Buffer size: 370149
# Buffer update speed: 297.4/s
# Number of environment steps: 370149
# Average episode return: 150.0000
# Number of training steps: 4374
# Training speed: 2.7/s
# Loss: 0.3082
#
# Buffer size: 370949
# Buffer update speed: 80.0/s
# Number of environment steps: 370949
# Number of training steps: 4406
# Training speed: 3.2/s
# Loss: 0.2438
#
# Buffer size: 373336
# Buffer update speed: 238.7/s
# Number of environment steps: 373336
# Average episode return: 300.0000
# Number of training steps: 4427
# Training speed: 2.0/s
# Loss: 0.2410
#
# Buffer size: 375379
# Buffer update speed: 204.3/s
# Number of environment steps: 375379
# Average episode return: 125.0000
# Number of training steps: 4455
# Training speed: 2.8/s
# Loss: 0.2715
#
# Buffer size: 376647
# Buffer update speed: 126.8/s
# Number of environment steps: 376647
# Average episode return: 100.0000
# Number of training steps: 4484
# Training speed: 2.9/s
# Loss: 0.2398
#
# Buffer size: 379019
# Buffer update speed: 237.2/s
# Number of environment steps: 379019
# Average episode return: 100.0000
# Number of training steps: 4505
# Training speed: 2.1/s
# Loss: 0.2254
#
# Buffer size: 380592
# Buffer update speed: 157.3/s
# Number of environment steps: 380592
# Number of training steps: 4532
# Training speed: 2.7/s
# Loss: 0.2409
#
# Buffer size: 382978
# Buffer update speed: 238.6/s
# Number of environment steps: 382978
# Number of training steps: 4557
# Training speed: 2.5/s
# Loss: 0.2203
#
# Buffer size: 384437
# Buffer update speed: 145.9/s
# Number of environment steps: 384437
# Number of training steps: 4585
# Training speed: 2.8/s
# Loss: 0.2032
#
# Buffer size: 385996
# Buffer update speed: 192.1/s
# Number of environment steps: 386358
# Number of training steps: 4605
# Training speed: 2.0/s
# Loss: 0.2337
#
# Buffer size: 388401
# Buffer update speed: 204.3/s
# Number of environment steps: 388401
# Number of training steps: 4629
# Training speed: 2.3/s
# Loss: 0.2570
#
# Buffer size: 389852
# Buffer update speed: 145.1/s
# Number of environment steps: 389852
# Average episode return: 100.0000
# Number of training steps: 4652
# Training speed: 2.3/s
# Loss: 0.2347
#
# Buffer size: 391648
# Buffer update speed: 179.6/s
# Number of environment steps: 391648
# Number of training steps: 4670
# Training speed: 1.8/s
# Loss: 0.1912
#
# Buffer size: 393492
# Buffer update speed: 184.4/s
# Number of environment steps: 393492
# Number of training steps: 4688
# Training speed: 1.7/s
# Loss: 0.1896
#
# Buffer size: 395497
# Buffer update speed: 200.5/s
# Number of environment steps: 395497
# Number of training steps: 4710
# Training speed: 2.2/s
# Loss: 0.2103
#
# Buffer size: 397273
# Buffer update speed: 177.6/s
# Number of environment steps: 397273
# Number of training steps: 4731
# Training speed: 2.1/s
# Loss: 0.1972
#
# Buffer size: 398779
# Buffer update speed: 150.6/s
# Number of environment steps: 398779
# Number of training steps: 4755
# Training speed: 2.4/s
# Loss: 0.1902
#
# Buffer size: 401500
# Buffer update speed: 272.1/s
# Number of environment steps: 401500
# Number of training steps: 4782
# Training speed: 2.6/s
# Loss: 0.1875
#
# Buffer size: 402509
# Buffer update speed: 100.9/s
# Number of environment steps: 402509
# Number of training steps: 4809
# Training speed: 2.7/s
# Loss: 0.1815
#
# Buffer size: 404467
# Buffer update speed: 195.8/s
# Number of environment steps: 404467
# Number of training steps: 4835
# Training speed: 2.5/s
# Loss: 0.1700
#
# Buffer size: 407066
# Buffer update speed: 259.9/s
# Number of environment steps: 407066
# Number of training steps: 4868
# Training speed: 3.3/s
# Loss: 0.2168
#
# Buffer size: 408189
# Buffer update speed: 112.3/s
# Number of environment steps: 408189
# Number of training steps: 4895
# Training speed: 2.6/s
# Loss: 0.1673
#
# Buffer size: 410017
# Buffer update speed: 182.8/s
# Number of environment steps: 410017
# Number of training steps: 4918
# Training speed: 2.2/s
# Loss: 0.1749
#
# Buffer size: 413202
# Buffer update speed: 318.5/s
# Number of environment steps: 413202
# Number of training steps: 4949
# Training speed: 3.1/s
# Loss: 0.1717
#
# Buffer size: 413389
# Buffer update speed: 18.7/s
# Number of environment steps: 413389
# Number of training steps: 4970
# Training speed: 2.1/s
# Loss: 0.1543
#
# Buffer size: 416371
# Buffer update speed: 298.2/s
# Number of environment steps: 416371
# Number of training steps: 5000
# Training speed: 3.0/s
# Loss: 0.1523
#
# Buffer size: 417922
# Buffer update speed: 155.1/s
# Number of environment steps: 417922
# Number of training steps: 5028
# Training speed: 2.8/s
# Loss: 0.1826
#
# Buffer size: 419919
# Buffer update speed: 199.7/s
# Number of environment steps: 419919
# Number of training steps: 5056
# Training speed: 2.7/s
# Loss: 0.1735
#
# Buffer size: 421239
# Buffer update speed: 132.0/s
# Number of environment steps: 421239
# Number of training steps: 5076
# Training speed: 2.1/s
# Loss: 0.1528
#
# Buffer size: 422905
# Buffer update speed: 166.6/s
# Number of environment steps: 422905
# Number of training steps: 5105
# Training speed: 2.8/s
# Loss: 0.1559
#
# Buffer size: 425440
# Buffer update speed: 253.5/s
# Number of environment steps: 425440
# Average episode return: 200.0000
# Number of training steps: 5129
# Training speed: 2.4/s
# Loss: 0.1380
#
# Buffer size: 427833
# Buffer update speed: 239.3/s
# Number of environment steps: 427833
# Number of training steps: 5155
# Training speed: 2.6/s
# Loss: 0.1423
#
# Buffer size: 428945
# Buffer update speed: 111.2/s
# Number of environment steps: 428945
# Number of training steps: 5186
# Training speed: 3.1/s
# Loss: 0.1448
#
# Buffer size: 431317
# Buffer update speed: 237.2/s
# Number of environment steps: 431317
# Number of training steps: 5223
# Training speed: 3.7/s
# Loss: 0.1469
#
# Buffer size: 433353
# Buffer update speed: 203.6/s
# Number of environment steps: 433353
# Average episode return: 100.0000
# Number of training steps: 5245
# Training speed: 2.2/s
# Loss: 0.1386
#
# Buffer size: 434676
# Buffer update speed: 132.3/s
# Number of environment steps: 434676
# Number of training steps: 5280
# Training speed: 3.5/s
# Loss: 0.1142
#
# Buffer size: 437076
# Buffer update speed: 240.0/s
# Number of environment steps: 437076
# Number of training steps: 5307
# Training speed: 2.7/s
# Loss: 0.1233
#
# Buffer size: 438422
# Buffer update speed: 134.6/s
# Number of environment steps: 438422
# Average episode return: 100.0000
# Number of training steps: 5332
# Training speed: 2.5/s
# Loss: 0.1376
#
# Buffer size: 440623
# Buffer update speed: 220.1/s
# Number of environment steps: 440623
# Average episode return: 100.0000
# Number of training steps: 5358
# Training speed: 2.6/s
# Loss: 0.1183
#
# Buffer size: 442390
# Buffer update speed: 176.7/s
# Number of environment steps: 442390
# Number of training steps: 5388
# Training speed: 3.0/s
# Loss: 0.1394
#
# Buffer size: 445180
# Buffer update speed: 279.0/s
# Number of environment steps: 445180
# Average episode return: 100.0000
# Number of training steps: 5422
# Training speed: 3.3/s
# Loss: 0.1204
#
# Buffer size: 446199
# Buffer update speed: 101.9/s
# Number of environment steps: 446199
# Number of training steps: 5445
# Training speed: 2.3/s
# Loss: 0.1396
#
# Buffer size: 448702
# Buffer update speed: 250.3/s
# Number of environment steps: 448702
# Average episode return: 200.0000
# Number of training steps: 5472
# Training speed: 2.7/s
# Loss: 0.1351
#
# Buffer size: 449836
# Buffer update speed: 113.4/s
# Average episode return: 100.0000Number of environment steps: 449836
#
# Number of training steps: 5499
# Training speed: 2.7/s
# Loss: 0.1273
#
# Buffer size: 452101
# Buffer update speed: 226.5/s
# Number of environment steps: 452101
# Average episode return: 100.0000
# Number of training steps: 5517
# Training speed: 1.8/s
# Loss: 0.1407
#
# Buffer size: 453504
# Buffer update speed: 140.3/s
# Number of environment steps: 453504
# Number of training steps: 5535
# Training speed: 1.9/s
# Loss: 0.1348
#
# Buffer size: 456425
# Buffer update speed: 292.1/s
# Number of environment steps: 456425
# Average episode return: 200.0000
# Number of training steps: 5562
# Training speed: 2.6/s
# Loss: 0.1140
#
# Buffer size: 457325
# Buffer update speed: 90.0/s
# Number of environment steps: 457325
# Average episode return: 200.0000
# Number of training steps: 5583
# Training speed: 2.1/s
# Loss: 0.1333
#
# Buffer size: 459968
# Buffer update speed: 264.3/s
# Number of environment steps: 459968
# Average episode return: 100.0000
# Number of training steps: 5608
# Training speed: 2.5/s
# Loss: 0.1273
#
# Buffer size: 461214
# Buffer update speed: 124.6/s
# Number of environment steps: 461214
# Average episode return: 100.0000
# Number of training steps: 5639
#
# Training speed: 3.1/sLoss: 0.1344
#
# Buffer size: 463377
# Buffer update speed: 216.3/s
# Number of environment steps: 463377
# Average episode return: 100.0000
# Number of training steps: 5665
# Training speed: 2.6/s
# Loss: 0.1209
#
# Buffer size: 465017
# Buffer update speed: 164.0/s
# Number of environment steps: 465017
# Average episode return: 100.0000
# Number of training steps: 5703
# Training speed: 3.8/s
# Loss: 0.1098
#
# Buffer size: 466795
# Buffer update speed: 177.8/s
# Number of environment steps: 466795
# Average episode return: 100.0000
# Number of training steps: 5736
# Training speed: 3.3/s
# Loss: 0.1268
#
# Buffer size: 467995
# Buffer update speed: 135.4/s
# Number of environment steps: 468149
# Number of training steps: 5752
# Training speed: 1.6/s
# Loss: 0.1109
#
# Buffer size: 470659
# Buffer update speed: 251.0/s
# Number of environment steps: 470659
# Average episode return: 133.3333
# Number of training steps: 5775
# Training speed: 2.3/s
# Loss: 0.1215
#
# Buffer size: 472768
# Buffer update speed: 210.9/s
# Number of environment steps: 472768
# Average episode return: 333.3333
# Number of training steps: 5805
# Training speed: 3.0/s
# Loss: 0.1033
#
# Buffer size: 474155
# Buffer update speed: 138.7/s
# Number of environment steps: 474155
# Average episode return: 200.0000
# Number of training steps: 5825
# Training speed: 2.0/s
# Loss: 0.1195
#
# Buffer size: 476396
# Buffer update speed: 224.1/s
# Number of environment steps: 476396
# Average episode return: 200.0000
# Number of training steps: 5843
# Training speed: 1.8/s
# Loss: 0.1179
#
# Buffer size: 477535
# Buffer update speed: 113.9/s
# Number of environment steps: 477535
# Number of training steps: 5862
# Training speed: 1.9/s
# Loss: 0.1178
#
# Buffer size: 480195
# Buffer update speed: 266.0/s
# Number of environment steps: 480195
# Number of training steps: 5883
# Training speed: 2.1/s
# Loss: 0.1317
#
# Buffer size: 481385
# Buffer update speed: 119.0/s
# Number of environment steps: 481385
# Number of training steps: 5908
# Training speed: 2.5/s
# Loss: 0.1231
#
# Buffer size: 483233
# Buffer update speed: 184.8/s
# Number of environment steps: 483233
# Number of training steps: 5931
# Training speed: 2.3/s
# Loss: 0.1172
#
# Buffer size: 485517
# Buffer update speed: 228.4/s
# Number of environment steps: 485517
# Number of training steps: 5952
# Training speed: 2.1/s
# Loss: 0.1059
#
# Buffer size: 487056
# Buffer update speed: 153.9/s
# Number of environment steps: 487056
# Number of training steps: 5970
# Training speed: 1.8/s
# Loss: 0.1181
#
# Buffer size: 489654
# Buffer update speed: 259.8/s
# Number of environment steps: 489654
# Number of training steps: 5995
# Training speed: 2.5/s
# Loss: 0.1276
#
# Buffer size: 491235
# Buffer update speed: 158.1/s
# Number of environment steps: 491235
# Number of training steps: 6018
# Training speed: 2.3/s
# Loss: 0.1888
#
# Buffer size: 493511
# Buffer update speed: 227.6/s
# Number of environment steps: 493511
# Number of training steps: 6039
# Training speed: 2.1/s
# Loss: 0.1730
#
# Buffer size: 494984
# Buffer update speed: 147.3/s
# Number of environment steps: 494984
# Number of training steps: 6068
# Training speed: 2.9/s
# Loss: 0.1424
#
# Buffer size: 496873
# Buffer update speed: 188.9/s
# Number of environment steps: 496873
# Average episode return: 100.0000
# Number of training steps: 6096
# Training speed: 2.8/s
# Loss: 0.1665
#
# Buffer size: 499404
# Buffer update speed: 253.1/s
# Number of environment steps: 499404
# Number of training steps: 6128
# Training speed: 3.2/s
# Loss: 0.1494
#
# Buffer size: 500617
# Buffer update speed: 121.3/s
# Number of environment steps: 500617
# Average episode return: 133.3333
# Number of training steps: 6156
# Training speed: 2.8/s
# Loss: 0.1189
#
# Buffer size: 503017
# Buffer update speed: 240.0/s
# Number of environment steps: 503017
# Number of training steps: 6182
# Training speed: 2.6/s
# Loss: 0.1272
#
# Buffer size: 504217
# Buffer update speed: 120.0/s
# Number of environment steps: 504217
# Number of training steps: 6208
# Training speed: 2.6/s
# Loss: 0.1444
#
# Buffer size: 507166
# Buffer update speed: 314.1/s
# Number of environment steps: 507358
# Average episode return: 150.0000
# Number of training steps: 6238
# Training speed: 2.9/s
# Loss: 0.1509
#
# Buffer size: 508158
# Buffer update speed: 80.0/s
# Number of environment steps: 508158
# Number of training steps: 6260
# Training speed: 2.2/s
# Loss: 0.1370
#
# Buffer size: 510749
# Buffer update speed: 259.1/s
# Number of environment steps: 510749
# Average episode return: 100.0000
# Number of training steps: 6290
# Training speed: 3.0/s
# Loss: 0.1164
#
# Buffer size: 512033
# Buffer update speed: 128.4/s
# Number of environment steps: 512033
# Average episode return: 100.0000
# Number of training steps: 6311
# Training speed: 2.1/s
# Loss: 0.1130
#
# Buffer size: 514278
# Buffer update speed: 224.5/s
# Number of environment steps: 514278
# Average episode return: 200.0000
# Number of training steps: 6342
# Training speed: 3.2/s
# Loss: 0.1250
#
# Buffer size: 516278
# Buffer update speed: 200.0/s
# Number of environment steps: 516278
# Number of training steps: 6362
# Training speed: 1.9/s
# Loss: 0.1187
#
# Buffer size: 517714
# Buffer update speed: 143.6/s
# Number of environment steps: 517714
# Average episode return: 200.0000
# Number of training steps: 6391
# Training speed: 2.9/s
# Loss: 0.1282
#
# Buffer size: 519788
# Buffer update speed: 207.4/s
# Number of environment steps: 519788
# Average episode return: 125.0000
# Number of training steps: 6413
# Training speed: 2.2/s
# Loss: 0.1260
#
# Buffer size: 520988
# Buffer update speed: 120.0/s
# Number of environment steps: 520988
# Number of training steps: 6441
# Training speed: 2.8/s
# Loss: 0.1191
#
# Buffer size: 523373
# Buffer update speed: 238.5/s
# Number of environment steps: 523373
# Average episode return: 250.0000
# Number of training steps: 6466
# Training speed: 2.5/s
# Loss: 0.1244
#
# Buffer size: 525180
# Buffer update speed: 180.7/s
# Number of environment steps: 525180
# Average episode return: 200.0000
# Number of training steps: 6500
# Training speed: 3.4/s
# Loss: 0.1346
#
# Buffer size: 526903
# Buffer update speed: 172.3/s
# Number of environment steps: 526903
# Average episode return: 400.0000
# Number of training steps: 6524
# Training speed: 2.4/s
# Loss: 0.1145
#
# Buffer size: 528903
# Buffer update speed: 200.0/s
# Number of environment steps: 528903
# Number of training steps: 6545
# Training speed: 2.1/s
# Loss: 0.1059
#
# Buffer size: 531298
# Buffer update speed: 239.5/s
# Number of environment steps: 531298
# Average episode return: 200.0000
# Number of training steps: 6567
# Training speed: 2.2/s
# Loss: 0.1152
#
# Buffer size: 532340
# Buffer update speed: 104.2/s
# Number of environment steps: 532340
# Average episode return: 500.0000
# Number of training steps: 6590
# Training speed: 2.3/s
# ...
# Average episode return: 233.3333
# Number of training steps: 24545
# Training speed: 2.3/s
# Loss: 0.1357
#
# Buffer size: 1621179
# Buffer update speed: -44.6/s
# Number of environment steps: 1856073
# Average episode return: 375.0000
# Number of training steps: 24572
# Training speed: 2.8/s
# Loss: 0.1509
#
# Buffer size: 1621367
# Buffer update speed: 18.8/s
# Number of environment steps: 1857615
# Average episode return: 300.0000
# Number of training steps: 24594
# Training speed: 2.1/s
# Loss: 0.1538
#
# Buffer size: 1621431
# Buffer update speed: 6.4/s
# Number of environment steps: 1859820
# Average episode return: 250.0000
# Number of training steps: 24616
# Training speed: 2.2/s
# Loss: 0.1509
#
# Buffer size: 1621405
# Buffer update speed: -2.6/s
# Number of environment steps: 1861442
# Average episode return: 350.0000
# Number of training steps: 24635
# Training speed: 1.8/s
# Loss: 0.1428
#
# Buffer size: 1621462
# Buffer update speed: 5.7/s
# Number of environment steps: 1862769
# Average episode return: 600.0000
# Number of training steps: 24658
# Training speed: 2.3/s
# Loss: 0.1431
#
# Buffer size: 1622300
# Buffer update speed: 83.8/s
# Number of environment steps: 1865055
# Average episode return: 300.0000
# Number of training steps: 24687
# Training speed: 2.9/s
# Loss: 0.1405
#
# Buffer size: 1621851
# Buffer update speed: -44.9/s
# Number of environment steps: 1867006
# Average episode return: 342.8571
# Number of training steps: 24711
# Training speed: 2.4/s
# Loss: 0.1379
#
# Buffer size: 1621799
# Buffer update speed: -5.2/s
# Number of environment steps: 1868017
# Average episode return: 300.0000
# Number of training steps: 24734
# Training speed: 2.3/s
# Loss: 0.1504
#
# Buffer size: 1622476
# Buffer update speed: 67.7/s
# Number of environment steps: 1870573
# Average episode return: 300.0000
# Number of training steps: 24758
# Training speed: 2.4/s
# Loss: 0.1465
#
# Buffer size: 1623048
# Buffer update speed: 57.2/s
# Number of environment steps: 1872213
# Average episode return: 225.0000
# Number of training steps: 24787
# Training speed: 2.9/s
# Loss: 0.1345
#
# Buffer size: 1622642
# Buffer update speed: -40.6/s
# Number of environment steps: 1873407
# Average episode return: 350.0000
# Number of training steps: 24819
# Training speed: 3.2/s
# Loss: 0.1438
#
# Buffer size: 1622952
# Buffer update speed: 31.0/s
# Number of environment steps: 1875781
# Average episode return: 200.0000
# Number of training steps: 24844
# Training speed: 2.5/s
# Loss: 0.1646
#
# Buffer size: 1623199
# Buffer update speed: 24.7/s
# Number of environment steps: 1877314
# Average episode return: 300.0000
# Number of training steps: 24864
# Training speed: 2.0/s
# Loss: 0.1566
#
# Buffer size: 1622761
# Buffer update speed: -43.8/s
# Number of environment steps: 1879768
# Average episode return: 375.0000
# Number of training steps: 24889
# Training speed: 2.5/s
# Loss: 0.1529
#
# Buffer size: 1622623
# Buffer update speed: -37.6/s
# Number of environment steps: 1880992
# Average episode return: 250.0000
# Number of training steps: 24913
# Training speed: 2.4/s
# Loss: 0.1382
#
# Buffer size: 1623513
# Buffer update speed: 89.0/s
# Number of environment steps: 1883180
# Average episode return: 250.0000
# Number of training steps: 24945
# Training speed: 3.2/s
# Loss: 0.1401
#
# Buffer size: 1623776
# Buffer update speed: 26.3/s
# Number of environment steps: 1884828
# Average episode return: 250.0000
# Number of training steps: 24969
# Training speed: 2.4/s
# Loss: 0.1481
#
# Buffer size: 1623945
# Buffer update speed: 16.9/s
# Number of environment steps: 1887144
# Average episode return: 300.0000
# Number of training steps: 24996
# Training speed: 2.7/s
# Loss: 0.1528
#
# Buffer size: 1624081
# Buffer update speed: 13.6/s
# Number of environment steps: 1889029
# Average episode return: 200.0000
# Number of training steps: 25019
# Training speed: 2.3/s
# Loss: 0.1559
#
# Buffer size: 1624340
# Buffer update speed: 25.9/s
# Number of environment steps: 1890604
# Average episode return: 400.0000
# Number of training steps: 25049
# Training speed: 3.0/s
# Loss: 0.1405
#
# Buffer size: 1624744
# Buffer update speed: 40.4/s
# Number of environment steps: 1893562
# Average episode return: 500.0000
# Number of training steps: 25084
# Training speed: 3.5/s
# Loss: 0.1530
#
# Buffer size: 1624432
# Buffer update speed: -31.2/s
# Number of environment steps: 1894510
# Average episode return: 375.0000
# Number of training steps: 25111
# Training speed: 2.7/s
# Loss: 0.1440
#
# Buffer size: 1624661
# Buffer update speed: 22.9/s
# Number of environment steps: 1896392
# Average episode return: 300.0000
# Number of training steps: 25135
# Training speed: 2.4/s
# Loss: 0.1456
#
# Buffer size: 1626184
# Buffer update speed: 152.3/s
# Number of environment steps: 1899167
# Average episode return: 700.0000
# Number of training steps: 25167
# Training speed: 3.2/s
# Loss: 0.1428
#
# Buffer size: 1626195
# Buffer update speed: 1.1/s
# Number of environment steps: 1900365
# Average episode return: 400.0000
# Number of training steps: 25185
# Training speed: 1.8/s
# Loss: 0.1540
#
# Buffer size: 1625778
# Buffer update speed: -48.1/s
# Number of environment steps: 1902410
# Average episode return: 550.0000
# Number of training steps: 25216
# Training speed: 3.1/s
# Loss: 0.1421
#
# Buffer size: 1625807
# Buffer update speed: 9.3/s
# Number of environment steps: 1903946
# Average episode return: 150.0000
# Number of training steps: 25239
# Training speed: 2.2/s
# Loss: 0.1342
#
# Buffer size: 1626314
# Buffer update speed: 50.7/s
# Number of environment steps: 1906325
# Average episode return: 233.3333
# Number of training steps: 25264
# Training speed: 2.4/s
# Loss: 0.1357
#
# Buffer size: 1626640
# Buffer update speed: 32.6/s
# Number of environment steps: 1907472
# Average episode return: 300.0000
# Number of training steps: 25290
# Training speed: 2.6/s
# Loss: 0.1259
#
# Buffer size: 1626732
# Buffer update speed: 9.2/s
# Number of environment steps: 1909715
# Average episode return: 350.0000
# Number of training steps: 25313
# Training speed: 2.3/s
# Loss: 0.1403
#
# Buffer size: 1627128
# Buffer update speed: 39.6/s
# Number of environment steps: 1911580
# Average episode return: 366.6667
# Number of training steps: 25331
# Training speed: 1.8/s
# Loss: 0.1498
#
# Buffer size: 1627266
# Buffer update speed: 13.8/s
# Number of environment steps: 1913065
# Average episode return: 100.0000
# Number of training steps: 25349
# Training speed: 1.7/s
# Loss: 0.1336
#
# Buffer size: 1627029
# Buffer update speed: -23.7/s
# Number of environment steps: 1915637
# Average episode return: 325.0000
# Number of training steps: 25372
# Training speed: 2.3/s
# Loss: 0.1360
#
# Buffer size: 1627490
# Buffer update speed: 46.1/s
# Number of environment steps: 1917055
# Average episode return: 300.0000
# Number of training steps: 25397
# Training speed: 2.5/s
# Loss: 0.1328
#
# Buffer size: 1627924
# Buffer update speed: 43.4/s
# Number of environment steps: 1919181
# Average episode return: 433.3333
# Number of training steps: 25424
# Training speed: 2.7/s
# Loss: 0.1371
#
# Buffer size: 1627660
# Buffer update speed: 8.6/s
# Number of environment steps: 1920917
# Average episode return: 400.0000
# Number of training steps: 25445
# Training speed: 2.1/s
# Loss: 0.1242
#
# Buffer size: 1628017
# Buffer update speed: 0.7/s
# Number of environment steps: 1923151
# Average episode return: 300.0000
# Number of training steps: 25469
# Training speed: 2.4/s
# Loss: 0.1402
#
# Buffer size: 1627359
# Buffer update speed: -65.8/s
# Number of environment steps: 1924222
# Average episode return: 300.0000
# Number of training steps: 25491
# Training speed: 2.1/s
# Loss: 0.1298
#
# Buffer size: 1627888
# Buffer update speed: 52.9/s
# Number of environment steps: 1926555
# Number of training steps: 25516
# Training speed: 2.5/s
# Loss: 0.1371
#
# Buffer size: 1628290
# Buffer update speed: 40.2/s
# Number of environment steps: 1928668
# Average episode return: 350.0000
# Number of training steps: 25541
# Training speed: 2.5/s
# Loss: 0.1396
#
# Buffer size: 1628704
# Buffer update speed: 41.4/s
# Number of environment steps: 1929672
# Average episode return: 500.0000
# Number of training steps: 25569
# Training speed: 2.8/s
# Loss: 0.1327
#
# Buffer size: 1628730
# Buffer update speed: 2.6/s
# Number of environment steps: 1932278
# Average episode return: 250.0000
# Number of training steps: 25601
# Training speed: 3.2/s
# Loss: 0.1316
#
# Buffer size: 1629012
# Buffer update speed: 28.2/s
# Number of environment steps: 1933018
# Average episode return: 400.0000
# Number of training steps: 25625
# Training speed: 2.4/s
# Loss: 0.1200
#
# Buffer size: 1629090
# Buffer update speed: 7.8/s
# Number of environment steps: 1935490
# Average episode return: 300.0000
# Number of training steps: 25650
# Training speed: 2.3/s
# Loss: 0.1297
#
# Buffer size: 1629301
# Buffer update speed: 21.1/s
# Number of environment steps: 1937301
# Average episode return: 240.0000
# Number of training steps: 25672
# Training speed: 2.2/s
# Loss: 0.1264
#
# Buffer size: 1629945
# Buffer update speed: 64.4/s
# Number of environment steps: 1938901
# Number of training steps: 25701
# Training speed: 2.9/s
# Loss: 0.1461
#
# Buffer size: 1630074
# Buffer update speed: 12.9/s
# Number of environment steps: 1940688
# Average episode return: 300.0000
# Number of training steps: 25731
# Training speed: 3.0/s
# Loss: 0.1334
#
# Buffer size: 1629604
# Buffer update speed: -47.0/s
# Number of environment steps: 1943122
# Average episode return: 320.0000
# Number of training steps: 25760
# Training speed: 2.9/s
# Loss: 0.1282
#
# Buffer size: 1629555
# Buffer update speed: -4.9/s
# Number of environment steps: 1944731
# Average episode return: 366.6667
# Number of training steps: 25782
# Training speed: 2.2/s
# Loss: 0.1290
#
# Buffer size: 1629985
# Buffer update speed: 43.0/s
# Number of environment steps: 1946183
# Average episode return: 200.0000
# Number of training steps: 25803
# Training speed: 2.1/s
# Loss: 0.1366
#
# Buffer size: 1630055
# Buffer update speed: 7.0/s
# Number of environment steps: 1948310
# Average episode return: 200.0000
# Number of training steps: 25823
# Training speed: 2.0/s
# Loss: 0.1237
#
# Buffer size: 1629692
# Buffer update speed: -36.3/s
# Number of environment steps: 1950134
# Average episode return: 300.0000
# Number of training steps: 25842
# Training speed: 1.9/s
# Loss: 0.1356
#
# Buffer size: 1630168
# Buffer update speed: 47.6/s
# Number of environment steps: 1952496
# Average episode return: 333.3333
# Number of training steps: 25872
# Training speed: 2.9/s
# Loss: 0.1318
#
# Buffer size: 1630773
# Buffer update speed: 60.5/s
# Number of environment steps: 1954043
# Average episode return: 200.0000
# Number of training steps: 25894
# Training speed: 2.2/s
# Loss: 0.1322
#
# Buffer size: 1630548
# Buffer update speed: -22.5/s
#
# Number of environment steps: 1955875
# Average episode return: 260.0000
# Number of training steps: 25927
# Training speed: 3.3/s
# Loss: 0.1395
# Buffer size: 1631057
# Buffer update speed: 50.9/s
# Number of environment steps: 1957680
# Average episode return: 350.0000
# Number of training steps: 25950
# Training speed: 2.3/s
# Loss: 0.1305
#
# Buffer size: 1631263
# Buffer update speed: 20.6/s
# Number of environment steps: 1960000
# Average episode return: 400.0000
# Number of training steps: 25976
# Training speed: 2.5/s
# Loss: 0.1400
#
# Buffer size: 1631961
# Buffer update speed: 69.8/s
# Number of environment steps: 1962267
# Average episode return: 260.0000
# Number of training steps: 25997
# Training speed: 2.1/s
# Loss: 0.1324
#
# Buffer size: 1632153
# Buffer update speed: 19.2/s
# Number of environment steps: 1963707
# Average episode return: 300.0000
# Number of training steps: 26026
# Training speed: 2.9/s
# Loss: 0.1769
#
# Buffer size: 1632255
# Buffer update speed: 10.2/s
# Number of environment steps: 1965516
# Average episode return: 400.0000
# Number of training steps: 26051
# Training speed: 2.5/s
# Loss: 0.1835
#
# Buffer size: 1632026
# Buffer update speed: -22.9/s
# Number of environment steps: 1967453
# Average episode return: 300.0000
# Number of training steps: 26075
# Training speed: 2.4/s
# Loss: 0.1705
#
# Buffer size: 1632557
# Buffer update speed: 53.1/s
# Number of environment steps: 1969370
# Average episode return: 300.0000
# Number of training steps: 26097
# Training speed: 2.2/s
# Loss: 0.1742
#
# Buffer size: 1632345
# Buffer update speed: -21.2/s
# Number of environment steps: 1970758
# Average episode return: 600.0000
# Number of training steps: 26119
# Training speed: 2.2/s
# Loss: 0.1549
#
# Buffer size: 1633280
# Buffer update speed: 93.5/s
# Number of environment steps: 1973051
# Average episode return: 433.3333
# Number of training steps: 26142
# Training speed: 2.3/s
# Loss: 0.1571
#
# Buffer size: 1633446
# Buffer update speed: 16.6/s
# Number of environment steps: 1974481
# Average episode return: 325.0000
# Number of training steps: 26160
# Training speed: 1.8/s
# Loss: 0.1546
#
# Buffer size: 1633762
# Buffer update speed: 31.6/s
# Number of environment steps: 1976634
# Average episode return: 300.0000
# Number of training steps: 26183
# Training speed: 2.3/s
# Loss: 0.1638
#
# Buffer size: 1633892
# Buffer update speed: 13.0/s
# Number of environment steps: 1978142
# Average episode return: 333.3333
# Number of training steps: 26206
# Training speed: 2.3/s
# Loss: 0.1584
#
# Buffer size: 1633871
# Buffer update speed: -2.1/s
# Number of environment steps: 1979815
# Average episode return: 300.0000
# Number of training steps: 26230
# Training speed: 2.4/s
# Loss: 0.1708
#
# Buffer size: 1634187
# Buffer update speed: 31.6/s
# Number of environment steps: 1981854
# Average episode return: 250.0000
# Number of training steps: 26256
# Training speed: 2.6/s
# Loss: 0.1731
#
# Buffer size: 1634524
# Buffer update speed: 33.7/s
# Number of environment steps: 1983854
# Number of training steps: 26278
# Training speed: 2.2/s
# Loss: 0.1518
#
# Buffer size: 1634437
# Buffer update speed: -8.7/s
# Number of environment steps: 1985551
# Average episode return: 400.0000
# Number of training steps: 26300
# Training speed: 2.2/s
# Loss: 0.1582
#
# Buffer size: 1634330
# Buffer update speed: -4.0/s
# Number of environment steps: 1987437
# Average episode return: 375.0000
# Number of training steps: 26324
# Training speed: 2.4/s
# Loss: 0.1592
#
# Buffer size: 1634647
# Buffer update speed: 25.0/s
# Number of environment steps: 1989149
# Average episode return: 300.0000
# Number of training steps: 26357
# Training speed: 3.3/s
# Loss: 0.1490
#
# Buffer size: 1634974
# Buffer update speed: 32.7/s
# Number of environment steps: 1991268
# Average episode return: 333.3333
# Number of training steps: 26393
# Training speed: 3.6/s
# Loss: 0.1524
#
# Buffer size: 1635137
# Buffer update speed: 16.3/s
# Number of environment steps: 1993254
# Average episode return: 433.3333
# Number of training steps: 26422
# Training speed: 2.9/s
# Loss: 0.1639
#
# Buffer size: 1635222
# Buffer update speed: 8.5/s
# Number of environment steps: 1995134
# Average episode return: 100.0000
# Number of training steps: 26448
# Training speed: 2.6/s
# Loss: 0.1610
#
# Buffer size: 1635447
# Buffer update speed: 22.5/s
# Number of environment steps: 1997462
# Average episode return: 550.0000
# Number of training steps: 26474
# Training speed: 2.5/s
# Loss: 0.1526
#
# Buffer size: 1634800
# Buffer update speed: -64.7/s
# Number of environment steps: 1999056
# Average episode return: 450.0000
# Number of training steps: 26504
# Training speed: 3.0/s
# Loss: 0.1536
#
# Buffer size: 1635464
# Buffer update speed: 66.4/s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 28
#      25 buffer_proc = mp.Process(target=buffer.run)
#      26 buffer_proc.start()
# ---> 28 learner.run()
#      30 buffer_proc.join()
#      32 for proc in actor_procs:
#
# Cell In[9], line 64, in Learner.run(self)
#      61 data = self.batched_data.pop(0)
#      63 batch_obs, batch_last_action, batch_last_reward, batch_hidden, batch_action, batch_n_step_reward, batch_n_step_gamma, burn_in_steps, learning_steps, forward_steps, idxes, is_weights, old_ptr, env_steps = data
# ---> 64 batch_obs, batch_last_action, batch_last_reward = batch_obs.to(self.device), batch_last_action.to(self.device), batch_last_reward.to(self.device)
#      65 batch_hidden, batch_action = batch_hidden.to(self.device), batch_action.to(self.device)
#      66 batch_n_step_reward, batch_n_step_gamma = batch_n_step_reward.to(self.device), batch_n_step_gamma.to(self.device)
#
# KeyboardInterrupt:
# Number of environment steps: 2000910
# Average episode return: 300.0000
# Number of training steps: 26532
# Training speed: 2.7/s
# Loss: 0.1474
#
# Buffer size: 1635234
# Buffer update speed: -23.0/s
# Number of environment steps: 2003209
# Average episode return: 266.6667
# Number of training steps: 26532
# Training speed: 0.0/s

# %% [markdown]
# ### 3h training

# %% [markdown]
# # Test model

# %%
checkpoint = torch.load('models/r2d2/DonkeyKong-v5/26500.pth')
checkpoint
# Out:
# (OrderedDict([('feature.0.weight',
#                         -2.6738e-02,  1.5105e-01,  1.0998e-01,  1.5795e-01,  1.2000e-01,
#                          5.0445e-02,  1.1390e-01,  7.5609e-02, -4.8442e-02,  1.1683e-01,
#                         -1.1385e-01,  9.0599e-02,  1.4436e-01, -8.4182e-02,  1.1208e-01,
#                         -7.5548e-02,  8.2860e-02,  4.3376e-02,  1.4609e-01,  1.5709e-01,
#                          2.0733e-01, -5.6610e-02,  8.7924e-02,  5.0256e-02, -6.6235e-02,
#                          1.4719e-01,  1.1633e-01, -1.6897e-02, -5.0762e-02, -8.7219e-02,
#                          1.6094e-01,  1.3478e-01,  7.3796e-02,  1.7402e-01, -1.4592e-01,
#                          5.6849e-02, -3.7790e-02,  1.5430e-01,  3.4002e-02, -6.6940e-02,
#                          1.2912e-01, -7.0378e-02,  1.4527e-01, -7.1614e-02,  5.3419e-02,
#                          1.3172e-01, -3.9994e-02, -3.6450e-02, -1.0624e-01,  7.8016e-02,
#                          1.4772e-01, -3.7295e-02,  6.0601e-02, -6.6497e-02,  3.2096e-02,
#                         -1.3557e-01,  1.5522e-01, -2.0604e-02,  1.0077e-01,  5.0640e-02,
#                         -5.2882e-02,  1.3073e-01, -3.1024e-02, -2.3901e-03,  1.3464e-01,
#                          5.3329e-02, -2.4734e-02, -4.7814e-02,  5.6069e-02,  1.4564e-01,
#                          1.0400e-01, -6.5053e-02, -3.3429e-03,  9.5638e-02,  5.2169e-02,
#                          1.9152e-02,  8.9653e-02,  9.6028e-02, -7.0105e-02,  1.3594e-01,
#                          1.7913e-01,  1.5192e-01,  1.5028e-01, -2.5326e-02,  8.1679e-02,
#                          2.1312e-02, -6.1887e-02,  1.2868e-01,  2.3582e-02,  2.2825e-02,
#                         -1.0307e-01,  7.1487e-02,  1.2661e-01,  1.4197e-01,  5.7161e-03,
#                         -1.1757e-01, -3.4090e-02, -1.3654e-01, -8.7757e-02, -1.1925e-01,
#                          1.0713e-01, -5.8155e-02,  1.1655e-01,  1.4223e-01, -8.9464e-02,
#                          1.6944e-02,  1.4382e-01, -3.9739e-02, -4.3733e-02, -2.2192e-02,
#                          1.6730e-01,  1.4443e-01,  2.8410e-02,  1.7058e-01, -1.0238e-01,
#                          9.0553e-02,  3.7168e-02,  2.6274e-02,  1.2845e-01,  1.0451e-01,
#                          8.0957e-02,  6.6144e-02]], device='cuda:0')),
#               ('value.2.bias', tensor([0.0485], device='cuda:0'))]),
#  26500,
#  1997603,
#  179.56080798705418)

# %%
env = create_env(game_name, render=True)
n_observations = env.observation_space.shape
n_actions = env.action_space.n
model = Network(n_observations, n_actions)
model.load_state_dict(checkpoint[0])
obs, _ = env.reset()
state = AgentState(torch.from_numpy(obs).unsqueeze(0), n_actions)
done = False
total_reward = 0
while not done:
    with torch.no_grad():
        q_value, hidden = model(state)
    action = torch.argmax(q_value, 1).item()
    obs, reward, terminated, truncated, _, = env.step(action)
    done = terminated or truncated
    total_reward += reward
    state.update(obs, action, reward, hidden)
env.close()
print(total_reward)
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# 400.0
